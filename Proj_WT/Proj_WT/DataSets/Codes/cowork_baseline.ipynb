# %% [markdown]
# # 폴더 생성 및 기본 라이브러리 시행

# %%
import os

from google.colab import drive  
ROOT = "/content/drive" #구글 드라이브 연동
drive.mount(ROOT)

from os.path import join
CO_WORK = "MyDrive/Proj_WT" 
CW_PATH = join(ROOT, CO_WORK) #공유 폴더로 접근 경로
# Out:
# Mounted at /content/drive

# %%
#Basic
import sys
import time
import math
import random
#DataFrame
import csv
import numpy as np
import pandas as pd

# %% [markdown]
# # 드라이브 관련 명령어(기본편)
#   ## 공유한 내용을 활용하는 방법

# %% [markdown]
# ### 공유 폴더 내 디렉토리 및 파일 확인

# %%
# %cd "{CW_PATH}"
# !ls
# Out:
# /content/drive/.shortcut-targets-by-id/1TVtWvZ4DNn7V20Aj6JzSd5_iRdbjEXbG/Proj_WT
# Codes  DataSets  Papers

# %% [markdown]
# #### 코드 에러/이슈 및 베이스 라인

# %%
CODES = "Codes" #코드/마크다운 공유 및 에러 해결 목적
CODE_PATH = join(CW_PATH, CODES)
# !mkdir "{CODE_PATH}"

# %%
# %cd "{CODE_PATH}"
# !ls
# Out:
# /content/drive/.shortcut-targets-by-id/1TVtWvZ4DNn7V20Aj6JzSd5_iRdbjEXbG/Proj_WT/Codes
# '데이터 모은것'   cowork_baseline.ipynb

# %% [markdown]
# #### 논문 및 회의록

# %%
#논문 공유 폴더
PAPERS = "Papers"
PAPER_PATH = join(CW_PATH, PAPERS)
# !mkdir "{PAPER_PATH}"

# %%
# %cd "{PAPER_PATH}"
# !ls
# Out:
# /content/drive/.shortcut-targets-by-id/1TVtWvZ4DNn7V20Aj6JzSd5_iRdbjEXbG/Proj_WT/Papers
# '해외방문관광객의 목적지 선택에 대한 기후의 영향 (1).pdf'
#  논문_리뷰.ipynb
# '한국형 관광기후지수(KTCI)의 개발에 관한 연구.gdoc'
# '한국형 관광기후지수(KTCI)의 개발에 관한 연구.pdf'
# '날씨 및 요일 특성이 관광정보시스템 이용에 미치는 영향에 관한 연구.rtf'
# '기후인자가 관광수요에 미치는 영향 패널데이터 모형의 적용.rtf'
# 'Weather Go ( 웨더고) 초기 회의록(20210621).hwp'

# %%
# !pip install olefile  #hwp파일 읽는 모듈
# Out:
# ...
#      |████████████████████████████████| 112kB 8.8MB/s
# ...
#   Created wheel for olefile: filename=olefile-0.46-py2.py3-none-any.whl size=35431 sha256=198b87aae72054255ee1618608e41b6c61f63fa56df16a1178fbc4206bd69091
#   Stored in directory: /root/.cache/pip/wheels/4b/f4/11/bc4166107c27f07fd7bba707ffcb439619197638a1ac986df3
# Successfully built olefile
# ...

# %%
#hwp 파일 읽는 모듈
import olefile
f = olefile.OleFileIO(f"{PAPER_PATH}/Weather Go ( 웨더고) 초기 회의록(20210621).hwp")

ecd_txt = f.openstream("PrvText").read()
dcd_txt = ecd_txt.decode("UTF-16")

print(dcd_txt)
# Out:
# Weather Go ( 웨더고) 초기 회의록 20210621
#
# 선행연구
#
# 기후변화는 전 세계적으로 일어나고 있으며, 이는 기후의 영향을 크게 받는 관광산업에 지대한 영향을 끼친다. 기후인자 변수의 관광수요에 대한 영향력을 측정하는 것은 관광산업의 지속성장을 위해 중요하며, 나아가 국가 산업 발전에 이바지 한다는 점에서 본 연구의 의의가 있다. 본 연구는 이처럼 기후에 의한 수요 민감도가 큰 관광산업에 대한 기후 인자의 영향력을 살펴보기 위하여 패널 데이터를 이용한 분석을 실시하였으며, 본 연구의 이론적 배경 및 선행연구에 기초하여 독립변수인 기후인자를 추출하였다.
#
# 기후인자가 관광수요에 미치는 영향: 패널데이터 모형의 적용 (윤성준, 오희균, 이희찬)
#
# 최근 1년간 한국관광공사 관광정보시스템에 접속한 21,655,089명의 접속 정보를 토대로 분석한 결과 날씨 변수인 강수와 운량은 접속자 수에 유의한 양(+)의 영향을 미치는 것으로, 적설여부는 유의한 음(-)의 영향을 미치는 것으로 나타났으며, 강수는 숙박, 추천여행, 관광지 순으로, 운량은 숙박, 추천여행, 관광지, 문화시설 순으로 유의한 양(+)의 영향을 미치는 것으로 나타났습니다. 운량이 증가할수록, 관광지, 문화시설, 숙박, 추천여행 유형에 대한 접속자 수 또한 증가하였고, 적설은 관광지와 추천여행 유형에서만 영향을 미치는 것으로 나타났습니다. 이러한 결과는 실제 관광정보시스템의 접속자 수가 날씨에 영향을 받고 있다는 것을 나타내고 있으며, 관광지, 숙박, 추천여행 유형은 운량과 강수에 동시에 영향을 받는 것으로 조사되어, 날씨와 영향이 깊은 것으로 해석된다.
#
# 분석방법: 자료분석(SPSS), 일반적인 특성은 변수의 유형에 따라 T-test, ANOVA분석 실시 (유의 수준 0.05)
#
# 경영학석사학위논문 날씨 및 요일 특성이 관광정보시스템 이용에 미치는 영향에 관한 연구 (경영정보전공 김도현, 지도교수 임규건)
#
# ...

# %% [markdown]
# #### 데이터 목록

# %%
#데이터 공유 폴더
DATAS = "DataSets"
DATA_PATH = join(CW_PATH, DATAS)
# !mkdir "{DATA_PATH}"

# %%
# %cd "{DATA_PATH}"
# !ls
# Out:
# /content/drive/.shortcut-targets-by-id/1TVtWvZ4DNn7V20Aj6JzSd5_iRdbjEXbG/Proj_WT/DataSets
# 기상청_관광코스별_관광지_상세날씨  check.ipynb
# 한국관광공사_관광빅데이터	   DataLabService_api.ipynb
# api활용_참고_문서		   openapi_baseline.ipynb
# 기상청_일별_지상_종관_ASOS	   TourismResourceStatsService_api.ipynb
# AsosDalyInfoService_api.ipynb	   TourStnInfoService_api.ipynb

# %%
#다운로드한 데이터 현황
SV1 = join(DATA_PATH, "기상청_관광코스별_관광지_상세날씨")
SV2 = join(DATA_PATH, "기상청_일별_지상_종관_ASOS")
SV3 = join(DATA_PATH, "한국관광공사_관광빅데이터")

# %%
# %cd "{SV1}"
# !ls
# Out:
# /content/drive/.shortcut-targets-by-id/1TVtWvZ4DNn7V20Aj6JzSd5_iRdbjEXbG/Proj_WT/DataSets/기상청_관광코스별_관광지_상세날씨
# 시군구별관광기후지수_2017.csv  시군구별관광기후지수_2020.csv
# 시군구별관광기후지수_2018.csv  시군구별관광기후지수_2021.csv
# 시군구별관광기후지수_2019.csv

# %%
# %cd "{SV2}"
# !ls
d1920 = join(SV2, "1920")
#기상청_일별_지상_종관_ASOS(데이터 예시)
# %cd "{d1920}"
# !ls
# Out:
# /content/drive/.shortcut-targets-by-id/1TVtWvZ4DNn7V20Aj6JzSd5_iRdbjEXbG/Proj_WT/DataSets/기상청_일별_지상_종관_ASOS
# 1516  1718  1920  branch.xlsx
# /content/drive/.shortcut-targets-by-id/1TVtWvZ4DNn7V20Aj6JzSd5_iRdbjEXbG/Proj_WT/DataSets/기상청_일별_지상_종관_ASOS/1920
# 목포기상대.csv	울산기상대.csv	  전주기상지청.csv    대전지방기상청.csv
# 춘천기상대.csv	창원기상대.csv	  수도권기상청.csv    광주지방기상청.csv
# 홍성기상대.csv	인천기상대.csv	  대구지방기상청.csv  부산지방기상청.csv
# 안동기상대.csv	청주기상지청.csv  제주지방기상청.csv  강원지방기상청.csv

# %%
# %cd "{SV3}"
# !ls
# Out:
# /content/drive/.shortcut-targets-by-id/1TVtWvZ4DNn7V20Aj6JzSd5_iRdbjEXbG/Proj_WT/DataSets/한국관광공사_관광빅데이터
# locgoRegnVisitrDDList_21_04.csv  metcoRegnVisitrDDList_21_04.csv
# locgoRegnVisitrDDList_21_05.csv  metcoRegnVisitrDDList_21_05.csv
# locgoRegnVisitrDDList_21_06.csv  metcoRegnVisitrDDList_21_06.csv

# %% [markdown]
# #### 기타

# %%
# !pwd #현재 디렉토리 확인
# Out:
# /content/drive/.shortcut-targets-by-id/1TVtWvZ4DNn7V20Aj6JzSd5_iRdbjEXbG/Proj_WT/DataSets

# %%
# !ls #디렉토리 확인
# Out:
#  metcoRegnVisitrDDList_21_05.csv  'TourAPI_Guide_(DataLab)v1.0_20210527'
#  openapi_baseline.ipynb

# %% [markdown]
# ### 파일 공유 및 복사

# %%
# 개인 드라이버에 저장된 ipynb 공유
CoB_WB  = "MyDrive/Colab Notebooks" 
NB = "cowork_baseline.ipynb" #복사할 ipynb 파일명.확장자
NB_share = join(ROOT, CoB_WB, NB)
# !cp "{NB_share}" "{CODE_PATH}" #복사 명령어(복사 전 저장 필수)
# %cd "{CODE_PATH}"
# !ls
# Out:
# /content/drive/.shortcut-targets-by-id/1TVtWvZ4DNn7V20Aj6JzSd5_iRdbjEXbG/Proj_WT/Codes
# cowork_baseline.ipynb

# %%
#drive code에서 오픈한 cowork_baseline copy
# %cd "{CODE_PATH}"
NB = "cowork_baseline.ipynb" #복사할 ipynb 파일명.확장자
NB_PATH= join(CODE_PATH, NB)
CB_PATH = join(DATA_PATH, NB)

# !cp "{NB_PATH}" "{CB_PATH}"
# !mv cowork_baseline.ipynb	openapi_baseline.ipynb
# 아니면 CB라는 변수에 복사할 파일명을 작성하고, !mv 로 시작되는 명령어는 주석 처리

# %%
# 파일 업로드
# %cd "{PAPER_PATH}"

from google.colab import files
files.upload()
#현재 디렉토리(논문 공유 폴더)에 파일 업로드
# !ls #현재 디렉토리에 업로드 되었는지 확인

# %%
files.download("논문_리뷰.ipynb")
#현재 디렉토리(논문 공유 폴더)의 파일 다운로드

# %%
# read_pdf using package

# %%
# 파일 드라이브에 저장
# df #= 데이터 api로 모은 뒤, 변환한 변수
df.to_csv(f'{}')

# %% [markdown]
# # 참고__데이터&통계

# %% [markdown]
# <img src = "https://blog.kakaocdn.net/dn/1FSJ3/btqzPvL4lTF/7Wk0Df7xeOuGeQYKkdb9L1/img.png"/>
#
# [기초통계정리_데이터와 통계] https://hufs4programming.tistory.com/13

# %% [markdown]
# <img src="data:image/jpeg;base64,..."/>
#
# [확률과 통계_지수분포] https://m.blog.naver.com/PostView.nhn?blogId=mykepzzang&logNo=220843050893&referrerCode=0&searchKeyword=exponential
#
# <img src="https://mblogthumb-phinf.pstatic.net/MjAxNjExMDNfMjgw/MDAxNDc4MTAzMjU2OTc1.yjgARG869IWWmWAy2IgGUfn0DFYs-HEXs_HND021XUkg._YsI9zZRLRK1QCCHA9jwGKRXLMe4shK7r8TuLlEVNCYg.JPEG.mykepzzang/%ED%99%95%EB%A5%A0%EA%B3%BC%ED%86%B5%EA%B3%84.jpg?type=w2"/>
#
# [확률과 통계_카이제곱분포] https://m.blog.naver.com/PostView.naver?isHttpsRedirect=true&blogId=mykepzzang&logNo=220852102307

# %% [markdown]
# <img src="https://mblogthumb-phinf.pstatic.net/20150629_95/iamredspike_1435564549017IR1R5_JPEG/%25EC%25BA%25A1%25EC%25B2%2598.JPG?type=w800"/>
#
# [확률과 분포] https://m.blog.naver.com/PostView.naver?isHttpsRedirect=true&blogId=iamredspike&logNo=220405014726

# %% [markdown]
# <img src = "https://mblogthumb-phinf.pstatic.net/20160424_30/hisukdory_1461485123531oUolG_PNG/4E69388D-706A-4704-8474-E3ACEEE13418.png?type=w420"/>

# %% [markdown]
# <img src = "https://upload.wikimedia.org/wikipedia/commons/thumb/a/af/ProbOnto2.5.jpg/600px-ProbOnto2.5.jpg"/>

# %% [markdown]
# ## 통계적 기법 분야 연구 리뷰
#
# * Probability Models – Estimation
#
# <img alt="figure1" src="https://www.jksqm.org/upload//thumbnails/jksqm-44-2-221f1.gif"/>
#
# * Probability Models – Applications in Probability Models
#
# <img alt="figure2" src="https://www.jksqm.org/upload//thumbnails/jksqm-44-2-221f2.gif"/>
#
# * Bayesian Analysis
#
# <img alt="figure3" src="https://www.jksqm.org/upload//thumbnails/jksqm-44-2-221f3.gif"/>
#
# * Nonparametric Analysis
#
# <img alt="figure4" src="https://www.jksqm.org/upload//thumbnails/jksqm-44-2-221f4.gif"/>
#
# * Regression Analysis
#
# <img alt="figure5" src="https://www.jksqm.org/upload//thumbnails/jksqm-44-2-221f5.gif"/>
#
# * Time Series Analysis and Forecasting
#
# <img alt="figure6" src="https://www.jksqm.org/upload//thumbnails/jksqm-44-2-221f6.gif"/>
#
# * Data Analysis Applications – Data Mining and Statistical Package Development
#
# <img alt="figure7" src="https://www.jksqm.org/upload//thumbnails/jksqm-44-2-221f7.gif"/>
#
# * Data Analysis Applications – Applications in Statistical Methods
#
# <img alt="figure8" src="https://www.jksqm.org/upload//thumbnails/jksqm-44-2-221f8.gif"/>
#
# [link] https://www.jksqm.org/m/journal/view.php?number=765
