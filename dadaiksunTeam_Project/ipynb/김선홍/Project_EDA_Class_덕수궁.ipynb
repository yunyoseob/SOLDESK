# %% [markdown]
# <a href="https://colab.research.google.com/github/seonhong416/dadaiksunTeamProject/blob/main/ipynb/%EA%B9%80%EC%84%A0%ED%99%8D/Project_EDA_Class_%EB%8D%95%EC%88%98%EA%B6%81.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !apt-get update -qq
# !apt-get install fonts-nanum* -qq
import matplotlib.font_manager as fm
for fontInfo in fm.fontManager.ttflist :
  if 'Nanum' in fontInfo.name :
    print(fontInfo.name+ " = " + fontInfo.fname)
# Out:
# NanumSquareRound = /usr/share/fonts/truetype/nanum/NanumSquareRoundB.ttf
# NanumSquareRound = /usr/share/fonts/truetype/nanum/NanumSquareRoundL.ttf
# NanumGothicCoding = /usr/share/fonts/truetype/nanum/NanumGothicCoding-Bold.ttf
# NanumBarunpen = /usr/share/fonts/truetype/nanum/NanumBarunpenR.ttf
# NanumGothic = /usr/share/fonts/truetype/nanum/NanumGothicExtraBold.ttf
# Nanum Brush Script = /usr/share/fonts/truetype/nanum/NanumBrush.ttf
# NanumMyeongjo Eco = /usr/share/fonts/truetype/nanum/NanumMyeongjoEco.ttf
# NanumSquare = /usr/share/fonts/truetype/nanum/NanumSquareEB.ttf
# NanumGothicCoding = /usr/share/fonts/truetype/nanum/NanumGothicCoding.ttf
# NanumBarunpen = /usr/share/fonts/truetype/nanum/NanumBarunpenB.ttf
# NanumGothic = /usr/share/fonts/truetype/nanum/NanumGothicBold.ttf
# NanumGothic Eco = /usr/share/fonts/truetype/nanum/NanumGothicEco.ttf
# NanumBarunGothic = /usr/share/fonts/truetype/nanum/NanumBarunGothicUltraLight.ttf
# ...

# %%
import matplotlib.font_manager as fm
fm._rebuild()

# %%
# class EDA :
  
#   def __init__(self, data = None):
#     self.data = data

#   def summer_feature(self):
#     H = self.data['평균 상대습도(%)']
#     T = self.data['평균 기온(°C)'].apply(lambda x:32 + (1.8 * x))
#     temperature = -42.379 + (2.04901523*T) + (10.14333127 * H) - (0.22475541 * T * H) - (6.83783 * (10 ** -3) * (T ** 2)) - (5.481717 * (10 ** -2)*(H**2)) + (1.22874 * (10 ** -3) * (T ** 2) * H) + (8.5282 * (10 ** -4) * T * (H **2)) - (1.99 * (10**-6) * (T**2) * (H**2))    
#     self.data['여름철 체감온도'] = temperature
#     return self.data
  
#   # 겨울철 체감온도
#   def winter_feature(self):
#     T = self.data['평균 기온(°C)'].apply(lambda x:32 + (1.8*x))
#     V = self.data['평균 풍속(m/s)']
#     temperature = 13.12 + (0.6215 * T) - (11.37 * 0.16 ** V) + (0.3965 *V *0.16**T)
#     self.data['겨울철 체감온도'] = temperature
#     return self.data
#   # 불쾌지수 구하기
#   def 불쾌지수(self):
#     T = self.data['평균 기온(°C)']
#     H = self.data['평균 상대습도(%)']
#     불쾌지수 = (9/5 * T) - (0.55 * (1 - H/100) * ((9/5 * T) - 26)) + 32
#     self.data['불쾌지수'] = 불쾌지수
    
#     return self.data
  
#   def final_dataframe(self):
#     df1=EDA(self.data).summer_feature()
#     df2=EDA(df1).winter_feature()
#     df3=EDA(df2).불쾌지수()
#     return df3

#   def add_season(self) :
#     df = EDA(self.data).final_dataframe()

#     df.loc[(df['month'] == 12 )|(df['month'] == 1 )|(df['month'] == 2 ), 'season'] = 4
#     df.loc[(df['month'] == 3 )|(df['month'] == 4 )|(df['month'] == 5 ), 'season'] = 1
#     df.loc[(df['month'] == 6 )|(df['month'] == 7 )|(df['month'] == 8 ), 'season'] = 2
#     df.loc[(df['month'] == 9 )|(df['month'] == 10 )|(df['month'] == 11 ), 'season'] = 3
#     df['season'] = df.season.astype('int64')
#     return df

#   def weather_dist(self) : # 날씨 분포
#     for i in self.data.columns[2:-1] :
#       fig, ax = plt.subplots(figsize = (10, 5))
#       sns.distplot(self.data[i])
#       plt.rc('font', family='NanumGothic') 
#       plt.title(f'{i}에 대한 분포')
  
#   def make_season_data(self,change_featurename = '타겟이름') : # 계절 binning 후 계절별 dataframe 만들기
    

#     spring = self.data.loc[(self.data['season'] == 1)].drop(['여름철 체감온도', '겨울철 체감온도'], axis = 1).rename(columns = {change_featurename : 'target'})
#     summer = self.data.loc[(self.data['season'] == 2)].drop('겨울철 체감온도', axis = 1).rename(columns = {change_featurename : 'target'})
#     fall = self.data.loc[(self.data['season'] == 3)].drop(['여름철 체감온도', '겨울철 체감온도'], axis = 1).rename(columns = {change_featurename : 'target'})
#     winter = self.data.loc[(self.data['season'] == 4)].drop('여름철 체감온도', axis = 1).rename(columns = {change_featurename : 'target'})
#     return spring, summer, fall, winter
  
#   def season_dist(self,remove_feature = '관광지이름') :
#     df = self.data.drop(remove_feature, axis = 1)
#     for i in df.columns[2:-1] :
#       fig, ax = plt.subplots(figsize = (10, 5))
#       sns.distplot(self.data[i])
#       plt.rc('font', family='NanumGothic') 
#       plt.title(f'{i}에 대한 분포')
  
#   def check_statsmodels(self,remove_feature = '관광지이름') :
#     a = EDA(EDA(self.data).add_season()).make_season_data(remove_feature)
#     for i in a :
#       X = i.drop(['date', 'target', 'season'], axis = 1)
#       y = i['target']
#       X_constant = sm.add_constant(X)
#       model = sm.OLS(y, X_constant)
#       lin_reg = model.fit()
#       print(lin_reg.summary())
#       print('@'*100)

# %%
# import statsmodels.api as sm
# import pandas as pd
# import numpy as np
# import matplotlib.pyplot as plt
# import seaborn as sns

# 덕수궁 = pd.read_csv('/content/drive/MyDrive/project/관광지별 데이터/덕수궁.csv').drop('Unnamed: 0', axis = 1)
# 덕수궁
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm
#        date  month  최고 기온(°C)  ...  최대 풍속(m/s)  합계 일사량(MJ/m2)     덕수궁
# 0    201101      1  -3.406452  ...    5.593548       9.951290   92135
# 1    201102      2   5.864286  ...    5.239286      10.827857  132920
# 2    201103      3   8.345161  ...    6.877419      16.342258   64869
# 3    201104      4  15.596667  ...    6.650000      16.832333   85548
# 4    201105      5  22.983871  ...    6.235484      17.091935  103100
# ..      ...    ...        ...  ...         ...            ...     ...
# 103  201908      8  31.635484  ...    3.819355      16.766897  149905
# 104  201909      9  27.100000  ...    4.253333      12.892667  181790
# 105  201910     10  21.767742  ...    4.412903      12.755806  280107
# ...

# %%
# 덕수궁.describe()
# Out:
#                 date       month  ...  합계 일사량(MJ/m2)            덕수궁
# count     108.000000  108.000000  ...     108.000000     108.000000
# mean   201506.500000    6.500000  ...      12.660288  106036.601852
# std       259.425804    3.468146  ...       4.123344   59314.225222
# min    201101.000000    1.000000  ...       4.893226   36900.000000
# 25%    201303.750000    3.750000  ...       9.407403   66180.000000
# 50%    201506.500000    6.500000  ...      12.505387   98479.500000
# 75%    201709.250000    9.250000  ...      15.388417  128560.500000
# max    201912.000000   12.000000  ...      22.625484  493927.000000
#
# [8 rows x 13 columns]

# %%
# 덕수궁.loc[덕수궁['평균 기온(°C)'] <= 3.194240, '온도_bin'] = 0
# 덕수궁.loc[(덕수궁['평균 기온(°C)'] > 3.194240) & (덕수궁['평균 기온(°C)'] <= 14.015000), '온도_bin'] = 1
# 덕수궁.loc[(덕수궁['평균 기온(°C)'] > 14.015000) & (덕수궁['평균 기온(°C)'] <= 22.538333	), '온도_bin'] = 2
# 덕수궁.loc[덕수궁['평균 기온(°C)'] > 22.538333, '온도_bin'] = 3
# 덕수궁
# Out:
#        date  month  최고 기온(°C)  ...  합계 일사량(MJ/m2)     덕수궁  온도_bin
# 0    201101      1  -3.406452  ...       9.951290   92135     0.0
# 1    201102      2   5.864286  ...      10.827857  132920     0.0
# 2    201103      3   8.345161  ...      16.342258   64869     1.0
# 3    201104      4  15.596667  ...      16.832333   85548     1.0
# 4    201105      5  22.983871  ...      17.091935  103100     2.0
# ..      ...    ...        ...  ...            ...     ...     ...
# 103  201908      8  31.635484  ...      16.766897  149905     3.0
# 104  201909      9  27.100000  ...      12.892667  181790     3.0
# 105  201910     10  21.767742  ...      12.755806  280107     2.0
# 106  201911     11  12.933333  ...       9.476000  222529     1.0
# 107  201912     12   5.274194  ...       7.201613  112314     0.0
#
# [108 rows x 14 columns]

# %%
# 덕수궁_0 = 덕수궁.loc[덕수궁['온도_bin'] == 0]
# 덕수궁_1 = 덕수궁.loc[덕수궁['온도_bin'] == 1]
# 덕수궁_2 = 덕수궁.loc[덕수궁['온도_bin'] == 2]
# 덕수궁_3 = 덕수궁.loc[덕수궁['온도_bin'] == 3]
# 덕수궁_0
# Out:
#        date  month  최고 기온(°C)  ...  합계 일사량(MJ/m2)     덕수궁  온도_bin
# 0    201101      1  -3.406452  ...       9.951290   92135     0.0
# 1    201102      2   5.864286  ...      10.827857  132920     0.0
# 11   201112     12   2.851613  ...       6.962258   52140     0.0
# 12   201201      1   1.338710  ...       7.564516   40041     0.0
# 13   201202      2   2.968966  ...      11.215517   36900     0.0
# 23   201212     12  -0.519355  ...       6.784516   44855     0.0
# 24   201301      1   0.335484  ...       7.023548   46980     0.0
# 25   201302      2   2.775000  ...      10.588571   46825     0.0
# 35   201312     12   3.525806  ...       6.529677   99301     0.0
# 36   201401      1   3.541935  ...       7.268065  111450     0.0
# 37   201402      2   6.603571  ...       9.585714   93247     0.0
# 47   201412     12   1.496774  ...       7.409032   44272     0.0
# 48   201501      1   3.583871  ...       7.904839   54159     0.0
# ...

# %%
# EDA(덕수궁_0).weather_dist()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %%
# EDA(덕수궁_1).weather_dist()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %%
# EDA(덕수궁_2).weather_dist()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %%
# EDA(덕수궁_3).weather_dist()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %%
# 덕수궁_0 = EDA(덕수궁_0).final_dataframe()
# 덕수궁_0
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # Remove the CWD from sys.path while we load stuff.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
# 덕수궁_1 = EDA(덕수궁_1).final_dataframe()
# 덕수궁_2 = EDA(덕수궁_2).final_dataframe()
# 덕수궁_3 = EDA(덕수궁_3).final_dataframe()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # Remove the CWD from sys.path while we load stuff.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
# 덕수궁_0 = 덕수궁_0.rename(columns = {'덕수궁' : 'target'})
# 덕수궁_1 = 덕수궁_1.rename(columns = {'덕수궁' : 'target'})
# 덕수궁_2 = 덕수궁_2.rename(columns = {'덕수궁' : 'target'})
# 덕수궁_3 = 덕수궁_3.rename(columns = {'덕수궁' : 'target'})
# 덕수궁_0
# Out:
#        date  month  최고 기온(°C)  ...    여름철 체감온도   겨울철 체감온도       불쾌지수
# 0    201101      1  -3.406452  ...  219.748397  24.903816  28.955175
# 1    201102      2   5.864286  ...  149.419352  34.268870  40.059503
# 11   201112     12   2.851613  ...  159.546683  31.939538  37.946869
# 12   201201      1   1.338710  ...  171.537869  29.780329  35.707644
# 13   201202      2   2.968966  ...  155.712604  30.660864  37.594935
# 23   201212     12  -0.519355  ...  195.556022  28.322703  32.482435
# 24   201301      1   0.335484  ...  189.268112  29.083221  33.418346
# 25   201302      2   2.775000  ...  166.398713  31.563812  36.969328
# 35   201312     12   3.525806  ...  163.930976  32.660795  37.439889
# 36   201401      1   3.541935  ...  157.654905  32.116785  38.254378
# 37   201402      2   6.603571  ...  141.766935  35.084261  41.421184
# 47   201412     12   1.496774  ...  183.641148  29.680630  34.263916
# 48   201501      1   3.583871  ...  166.954589  31.872766  36.960124
# ...

# %%
# 덕수궁_0 = 덕수궁_0.drop('온도_bin', axis = 1)
# 덕수궁_1 = 덕수궁_1.drop('온도_bin', axis = 1)
# 덕수궁_2 = 덕수궁_2.drop('온도_bin', axis = 1)
# 덕수궁_3 = 덕수궁_3.drop('온도_bin', axis = 1)

# %%
# 덕수궁_0.to_csv('덕수궁_0.csv', index = False)
# 덕수궁_1.to_csv('덕수궁_1.csv', index = False)
# 덕수궁_2.to_csv('덕수궁_2.csv', index = False)
# 덕수궁_3.to_csv('덕수궁_3.csv', index = False)

# %%
# EDA(덕수궁).weather_dist()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %%
# EDA(덕수궁).add_season()
# Out:
#        date  month  최고 기온(°C)  ...   겨울철 체감온도       불쾌지수  season
# 0    201101      1  -3.406452  ...  24.903816  28.955175       4
# 1    201102      2   5.864286  ...  34.268870  40.059503       4
# 2    201103      3   8.345161  ...  37.031251  43.749745       1
# 3    201104      4  15.596667  ...  44.970648  52.983263       1
# 4    201105      5  22.983871  ...  52.998268  62.764312       1
# ..      ...    ...        ...  ...        ...        ...     ...
# 103  201908      8  31.635484  ...  62.809141  76.969814       2
# 104  201909      9  27.100000  ...  58.131085  69.939001       3
# 105  201910     10  21.767742  ...  51.092425  60.746122       3
# 106  201911     11  12.933333  ...  41.273282  48.640948       3
# 107  201912     12   5.274194  ...  34.361084  39.997827       4
#
# [108 rows x 18 columns]

# %%
# df = EDA(덕수궁).add_season()

# %%
# 봄, 여름, 가을, 겨울 = EDA(df).make_season_data('덕수궁')
# 봄
# Out:
#        date  month  최고 기온(°C)  최소 상대습도(%)  ...  target  온도_bin       불쾌지수  season
# 2    201103      3   8.345161   25.258065  ...   64869     1.0  43.749745       1
# 3    201104      4  15.596667   28.666667  ...   85548     1.0  52.983263       1
# 4    201105      5  22.983871   32.161290  ...  103100     2.0  62.764312       1
# 14   201203      3   9.522581   28.419355  ...   40244     1.0  45.621998       1
# 15   201204      4  17.886667   30.133333  ...   66246     1.0  55.168211       1
# 16   201205      5  25.148387   26.838710  ...   89515     2.0  64.808057       1
# 26   201303      3  10.835484   25.258065  ...   77718     1.0  45.927912       1
# 27   201304      4  14.980000   28.366667  ...   96402     1.0  52.033989       1
# 28   201305      5  23.587097   35.870968  ...  103001     2.0  63.221612       1
# 38   201403      3  13.058065   33.032258  ...  144903     1.0  48.808688       1
# ...

# %%
# 여름
# Out:
#        date  month  최고 기온(°C)  최소 상대습도(%)  ...  온도_bin   여름철 체감온도       불쾌지수  season
# 5    201106      6  26.576667   46.233333  ...     2.0  75.030501  69.064413       2
# 6    201107      7  27.996774   62.419355  ...     3.0  77.605161  74.208803       2
# 7    201108      8  29.451613   56.290323  ...     3.0  80.764571  75.514900       2
# 17   201206      6  29.716667   33.000000  ...     3.0  77.784233  71.044963       2
# 18   201207      7  29.025806   55.935484  ...     3.0  79.760835  74.901730       2
# 19   201208      8  30.851613   51.000000  ...     3.0  84.021218  76.812892       2
# 29   201306      6  29.236667   39.700000  ...     3.0  77.962307  72.002492       2
# 30   201307      7  28.335484   63.548387  ...     3.0  80.167425  75.660306       2
# 31   201308      8  31.087097   48.935484  ...     3.0  86.025041  77.831492       2
# 41   201406      6  27.770000   49.066667  ...     3.0  75.058888  71.193674       2
# ...

# %%
# 겨울
# Out:
#        date  month  최고 기온(°C)  최소 상대습도(%)  ...  온도_bin   겨울철 체감온도       불쾌지수  season
# 0    201101      1  -3.406452   35.129032  ...     0.0  24.903816  28.955175       4
# 1    201102      2   5.864286   32.000000  ...     0.0  34.268870  40.059503       4
# 11   201112     12   2.851613   31.677419  ...     0.0  31.939538  37.946869       4
# 12   201201      1   1.338710   30.548387  ...     0.0  29.780329  35.707644       4
# 13   201202      2   2.968966   23.620690  ...     0.0  30.660864  37.594935       4
# 23   201212     12  -0.519355   38.677419  ...     0.0  28.322703  32.482435       4
# 24   201301      1   0.335484   38.548387  ...     0.0  29.083221  33.418346       4
# 25   201302      2   2.775000   30.285714  ...     0.0  31.563812  36.969328       4
# 35   201312     12   3.525806   39.677419  ...     0.0  32.660795  37.439889       4
# 36   201401      1   3.541935   29.483871  ...     0.0  32.116785  38.254378       4
# ...

# %%
# EDA(봄).season_dist('target')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %%
# EDA(덕수궁).check_statsmodels('덕수궁')
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                 target   R-squared:                       0.706
# Model:                            OLS   Adj. R-squared:                  0.411
# Method:                 Least Squares   F-statistic:                     2.397
# Date:                Wed, 14 Jul 2021   Prob (F-statistic):             0.0639
# Time:                        12:33:42   Log-Likelihood:                -311.04
# No. Observations:                  27   AIC:                             650.1
# Df Residuals:                      13   BIC:                             668.2
# Df Model:                          13
# Covariance Type:            nonrobust
# ...
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const          2.564e+06   1.84e+06      1.397      0.186    -1.4e+06    6.53e+06
# ...

# %%
# 봄.to_csv('덕수궁_봄.csv')
# 여름.to_csv('덕수궁_여름.csv')
# 가을.to_csv('덕수궁_가을.csv')
# 겨울.to_csv('덕수궁_겨울.csv')

# %%
EDA(덕수궁).final_dataframe().describe()
# Out:
#                 date       month  ...        불쾌지수      season
# count     108.000000  108.000000  ...  108.000000  108.000000
# mean   201506.500000    6.500000  ...   56.500441    2.500000
# std       259.425804    3.468146  ...   14.511488    1.123246
# min    201101.000000    1.000000  ...   28.955175    1.000000
# 25%    201303.750000    3.750000  ...   43.167605    1.750000
# 50%    201506.500000    6.500000  ...   57.407167    2.500000
# 75%    201709.250000    9.250000  ...   69.507061    3.250000
# max    201912.000000   12.000000  ...   78.769758    4.000000
#
# [8 rows x 18 columns]

# %%
덕수궁
# Out:
#        date  month  최고 기온(°C)  ...   겨울철 체감온도       불쾌지수  season
# 0    201101      1  -3.406452  ...  24.903816  28.955175       4
# 1    201102      2   5.864286  ...  34.268870  40.059503       4
# 2    201103      3   8.345161  ...  37.031251  43.749745       1
# 3    201104      4  15.596667  ...  44.970648  52.983263       1
# 4    201105      5  22.983871  ...  52.998268  62.764312       1
# ..      ...    ...        ...  ...        ...        ...     ...
# 103  201908      8  31.635484  ...  62.809141  76.969814       2
# 104  201909      9  27.100000  ...  58.131085  69.939001       3
# 105  201910     10  21.767742  ...  51.092425  60.746122       3
# 106  201911     11  12.933333  ...  41.273282  48.640948       3
# 107  201912     12   5.274194  ...  34.361084  39.997827       4
#
# [108 rows x 18 columns]

# %%
dddd = pd.get_dummies(덕수궁['month'])
덕수궁 = pd.concat([덕수궁, dddd], axis = 1)
덕수궁 = 덕수궁.rename(columns = {1 : '1월', 2: '2월', 3:'3월', 4: '4월', 5:'5월', 6 : '6월', 7 : '7월', 8:'8월', 9: '9월', 10 : '10월', 11 : '11월', 12 :'12월'})
덕수궁
# Out:
#        date  month  최고 기온(°C)  최소 상대습도(%)  평균 기온(°C)  ...  8월  9월  10월  11월  12월
# 0    201101      1  -3.406452   35.129032  -7.183871  ...   0   0    0    0    0
# 1    201102      2   5.864286   32.000000   1.221429  ...   0   0    0    0    0
# 2    201103      3   8.345161   25.258065   3.616129  ...   0   0    0    0    0
# 3    201104      4  15.596667   28.666667  10.720000  ...   0   0    0    0    0
# 4    201105      5  22.983871   32.161290  17.925806  ...   0   0    0    0    0
# ..      ...    ...        ...         ...        ...  ...  ..  ..  ...  ...  ...
# 103  201908      8  31.635484   44.645161  27.190323  ...   1   0    0    0    0
# 104  201909      9  27.100000   44.133333  22.643333  ...   0   1    0    0    0
# 105  201910     10  21.767742   38.935484  16.370968  ...   0   0    1    0    0
# 106  201911     11  12.933333   33.133333   7.580000  ...   0   0    0    1    0
# 107  201912     12   5.274194   37.129032   1.416129  ...   0   0    0    0    1
#
# ...

# %% [markdown]
# 여름철 체감온도, 겨울철 체감온도, 불쾌지수 --> 수치가 이상해서 사용하지 못할 것으로 판단
#
# 온도 binning 후 더미화, 월 더미화 해볼 것

# %%
class EDA :
  
  def __init__(self, data = None):
    self.data = data
    
  def binning_tp(self) :
    df = self.data
    df.loc[df['최고 기온(°C)'] <= df['최고 기온(°C)'].quantile(0.25), 'tp_1'] = 0
    df.loc[(df['최고 기온(°C)'] > df['최고 기온(°C)'].quantile(0.25)) & (df['최고 기온(°C)'] <= df['최고 기온(°C)'].quantile(0.5)), 'tp_1'] = 1
    df.loc[(df['최고 기온(°C)'] > df['최고 기온(°C)'].quantile(0.5)) & (df['최고 기온(°C)'] <= df['최고 기온(°C)'].quantile(0.75)), 'tp_1'] = 2
    df.loc[df['최고 기온(°C)'] > df['최고 기온(°C)'].quantile(0.75), 'tp_1'] = 3
    
    df.loc[df['평균 기온(°C)'] <= df['평균 기온(°C)'].quantile(0.25), 'tp_2'] = 0
    df.loc[(df['평균 기온(°C)'] > df['평균 기온(°C)'].quantile(0.25)) & (df['평균 기온(°C)'] <= df['평균 기온(°C)'].quantile(0.5)), 'tp_2'] = 1
    df.loc[(df['평균 기온(°C)'] > df['평균 기온(°C)'].quantile(0.5)) & (df['평균 기온(°C)'] <= df['평균 기온(°C)'].quantile(0.75)), 'tp_2'] = 2
    df.loc[df['평균 기온(°C)'] > df['평균 기온(°C)'].quantile(0.75), 'tp_2'] = 3

    return df

  def dummies(self) :
    df = EDA(self.data).binning_tp()

    # 최고온도 더미화
    df_tp_1 = pd.get_dummies(df['tp_1'])
    df = pd.concat([df, df_tp_1], axis = 1)
    df = df.rename(columns = {0 : 'tp_1_0', 1 : 'tp_1_1', 2 : 'tp_1_2', 3 : 'tp_1_3'})
    df = df.drop('tp_1', axis= 1)
    
    #평균온도 더미화
    df_tp_2 = pd.get_dummies(df['tp_2'])
    df = pd.concat([df, df_tp_2], axis = 1)
    df = df.rename(columns = {0 : 'tp_2_0', 1 : 'tp_2_1', 2 : 'tp_2_2', 3 : 'tp_2_3'})
    df = df.drop('tp_2', axis= 1)
    
    return df

  def add_season(self, change_featurename = '타겟이름') :
    df = self.data.rename(columns = {change_featurename : 'target'})
    df.loc[(df['month'] == 12 )|(df['month'] == 1 )|(df['month'] == 2 ), 'season'] = 4
    df.loc[(df['month'] == 3 )|(df['month'] == 4 )|(df['month'] == 5 ), 'season'] = 1
    df.loc[(df['month'] == 6 )|(df['month'] == 7 )|(df['month'] == 8 ), 'season'] = 2
    df.loc[(df['month'] == 9 )|(df['month'] == 10 )|(df['month'] == 11 ), 'season'] = 3
    return df

  # def weather_dist(self) : # 날씨 분포
  #   for i in self.data.columns[2:-1] :
  #     fig, ax = plt.subplots(figsize = (10, 5))
  #     sns.distplot(self.data[i])
  #     plt.rc('font', family='NanumGothic') 
  #     plt.title(f'{i}에 대한 분포')
  
  def make_season_data(self) : # 계절 binning 후 계절별 dataframe 만들기
    

    spring = self.data.loc[(self.data['season'] == 1)].drop(['month', 'season'], axis = 1)
    summer = self.data.loc[(self.data['season'] == 2)].drop(['month', 'season'], axis = 1)
    fall = self.data.loc[(self.data['season'] == 3)].drop(['month', 'season'], axis = 1)
    winter = self.data.loc[(self.data['season'] == 4)].drop(['month', 'season'], axis = 1)
    return spring, summer, fall, winter
  
  # def season_dist(self,remove_feature = '관광지이름') :
  #   df = self.data.drop(remove_feature, axis = 1)
  #   for i in df.columns[2:-1] :
  #     fig, ax = plt.subplots(figsize = (10, 5))
  #     sns.distplot(self.data[i])
  #     plt.rc('font', family='NanumGothic') 
  #     plt.title(f'{i}에 대한 분포')
  
  def check_statsmodels(self) :
    df = self.data
    X = df.drop(['date', 'target'], axis =1)
    y = df['target']
    X_constant = sm.add_constant(X)
    model = sm.OLS(y, X_constant)
    lin_reg = model.fit()
    print(lin_reg.summary())

# %%
def check_distribution(data, column_list) :
  for i in column_list :
    fig, ax = plt.subplots(figsize = (10,5))
    sns.distplot(data[i])
    plt.rc('font', family='NanumGothic') 
    plt.title(f'{i}에 대한 분포')

# %%
덕수궁 = pd.read_csv('/content/drive/MyDrive/project/관광지별 데이터/덕수궁.csv').drop('Unnamed: 0', axis = 1)

# %%
덕수궁
# Out:
#        date  month  최고 기온(°C)  ...  최대 풍속(m/s)  합계 일사량(MJ/m2)     덕수궁
# 0    201101      1  -3.406452  ...    5.593548       9.951290   92135
# 1    201102      2   5.864286  ...    5.239286      10.827857  132920
# 2    201103      3   8.345161  ...    6.877419      16.342258   64869
# 3    201104      4  15.596667  ...    6.650000      16.832333   85548
# 4    201105      5  22.983871  ...    6.235484      17.091935  103100
# ..      ...    ...        ...  ...         ...            ...     ...
# 103  201908      8  31.635484  ...    3.819355      16.766897  149905
# 104  201909      9  27.100000  ...    4.253333      12.892667  181790
# 105  201910     10  21.767742  ...    4.412903      12.755806  280107
# 106  201911     11  12.933333  ...    4.533333       9.476000  222529
# 107  201912     12   5.274194  ...    4.400000       7.201613  112314
#
# [108 rows x 13 columns]

# %%
덕수궁.columns
# Out:
# Index(['date', 'month', '최고 기온(°C)', '최소 상대습도(%)', '평균 기온(°C)', '평균 상대습도(%)',
#        '일강수량(mm)', '평균 풍속(m/s)', '합계 일조 시간(hr)', '0.5m 지중온도(°C)', '최대 풍속(m/s)',
#        '합계 일사량(MJ/m2)', '덕수궁'],
#       dtype='object')

# %%
check_distribution(덕수궁, ['최고 기온(°C)', '최소 상대습도(%)', '평균 기온(°C)', '평균 상대습도(%)',
       '일강수량(mm)', '평균 풍속(m/s)', '합계 일조 시간(hr)', '0.5m 지중온도(°C)', '최대 풍속(m/s)',
       '합계 일사량(MJ/m2)'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %%
df = EDA(덕수궁).add_season('덕수궁')
df
# Out:
#        date  month  최고 기온(°C)  ...  합계 일사량(MJ/m2)  target  season
# 0    201101      1  -3.406452  ...       9.951290   92135     4.0
# 1    201102      2   5.864286  ...      10.827857  132920     4.0
# 2    201103      3   8.345161  ...      16.342258   64869     1.0
# 3    201104      4  15.596667  ...      16.832333   85548     1.0
# 4    201105      5  22.983871  ...      17.091935  103100     1.0
# ..      ...    ...        ...  ...            ...     ...     ...
# 103  201908      8  31.635484  ...      16.766897  149905     2.0
# 104  201909      9  27.100000  ...      12.892667  181790     3.0
# 105  201910     10  21.767742  ...      12.755806  280107     3.0
# 106  201911     11  12.933333  ...       9.476000  222529     3.0
# 107  201912     12   5.274194  ...       7.201613  112314     4.0
#
# [108 rows x 14 columns]

# %%
df = EDA(df).dummies() # 최고기온과 평균기온 binning 후 더미화 해주기

# %%
df
# Out:
#        date  month  최고 기온(°C)  최소 상대습도(%)  ...  tp_2_0  tp_2_1  tp_2_2  tp_2_3
# 0    201101      1  -3.406452   35.129032  ...       1       0       0       0
# 1    201102      2   5.864286   32.000000  ...       1       0       0       0
# 2    201103      3   8.345161   25.258065  ...       0       1       0       0
# 3    201104      4  15.596667   28.666667  ...       0       1       0       0
# 4    201105      5  22.983871   32.161290  ...       0       0       1       0
# ..      ...    ...        ...         ...  ...     ...     ...     ...     ...
# 103  201908      8  31.635484   44.645161  ...       0       0       0       1
# 104  201909      9  27.100000   44.133333  ...       0       0       0       1
# 105  201910     10  21.767742   38.935484  ...       0       0       1       0
# 106  201911     11  12.933333   33.133333  ...       0       1       0       0
# 107  201912     12   5.274194   37.129032  ...       1       0       0       0
#
# [108 rows x 22 columns]

# %%
봄, 여름, 가을, 겨울 = EDA(df).make_season_data() # 계절별로 데이터 프레임 생성

봄
# Out:
#        date  최고 기온(°C)  최소 상대습도(%)  평균 기온(°C)  ...  tp_2_0  tp_2_1  tp_2_2  tp_2_3
# 2    201103   8.345161   25.258065   3.616129  ...       0       1       0       0
# 3    201104  15.596667   28.666667  10.720000  ...       0       1       0       0
# 4    201105  22.983871   32.161290  17.925806  ...       0       0       1       0
# 14   201203   9.522581   28.419355   5.090323  ...       0       1       0       0
# 15   201204  17.886667   30.133333  12.340000  ...       0       1       0       0
# 16   201205  25.148387   26.838710  19.732258  ...       0       0       1       0
# 26   201303  10.835484   25.258065   5.135484  ...       0       1       0       0
# 27   201304  14.980000   28.366667  10.006667  ...       0       1       0       0
# 28   201305  23.587097   35.870968  18.222581  ...       0       0       1       0
# 38   201403  13.058065   33.032258   7.890323  ...       0       1       0       0
# ...

# %%
EDA(봄).check_statsmodels()
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                 target   R-squared:                       0.671
# Model:                            OLS   Adj. R-squared:                  0.388
# Method:                 Least Squares   F-statistic:                     2.376
# Date:                Wed, 14 Jul 2021   Prob (F-statistic):             0.0625
# Time:                        16:17:32   Log-Likelihood:                -312.55
# No. Observations:                  27   AIC:                             651.1
# Df Residuals:                      14   BIC:                             667.9
# Df Model:                          12
# Covariance Type:            nonrobust
# ...
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const          6.171e+04   1.14e+05      0.542      0.596   -1.82e+05    3.06e+05
# ...

# %%
EDA(여름).check_statsmodels()
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                 target   R-squared:                       0.654
# Model:                            OLS   Adj. R-squared:                  0.400
# Method:                 Least Squares   F-statistic:                     2.576
# Date:                Wed, 14 Jul 2021   Prob (F-statistic):             0.0453
# Time:                        16:17:37   Log-Likelihood:                -302.82
# No. Observations:                  27   AIC:                             629.6
# Df Residuals:                      15   BIC:                             645.2
# Df Model:                          11
# Covariance Type:            nonrobust
# ...
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const          3.377e+05   1.65e+05      2.046      0.059   -1.41e+04    6.89e+05
# ...

# %%
EDA(가을).check_statsmodels()
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                 target   R-squared:                       0.543
# Model:                            OLS   Adj. R-squared:                  0.011
# Method:                 Least Squares   F-statistic:                     1.020
# Date:                Wed, 14 Jul 2021   Prob (F-statistic):              0.492
# Time:                        16:17:37   Log-Likelihood:                -332.52
# No. Observations:                  27   AIC:                             695.0
# Df Residuals:                      12   BIC:                             714.5
# Df Model:                          14
# Covariance Type:            nonrobust
# ...
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const          1.779e+05   3.71e+05      0.479      0.640   -6.31e+05    9.87e+05
# ...

# %%
EDA(겨울).check_statsmodels()
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                 target   R-squared:                       0.629
# Model:                            OLS   Adj. R-squared:                  0.397
# Method:                 Least Squares   F-statistic:                     2.712
# Date:                Wed, 14 Jul 2021   Prob (F-statistic):             0.0366
# Time:                        16:17:37   Log-Likelihood:                -302.34
# No. Observations:                  27   AIC:                             626.7
# Df Residuals:                      16   BIC:                             640.9
# Df Model:                          10
# Covariance Type:            nonrobust
# ...
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# 최고 기온(°C)     -1.818e+04   1.81e+04     -1.002      0.331   -5.66e+04    2.03e+04
# ...

# %%
EDA(df).check_statsmodels()
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                 target   R-squared:                       0.497
# Model:                            OLS   Adj. R-squared:                  0.402
# Method:                 Least Squares   F-statistic:                     5.223
# Date:                Wed, 14 Jul 2021   Prob (F-statistic):           8.41e-08
# Time:                        16:17:38   Log-Likelihood:                -1302.7
# No. Observations:                 108   AIC:                             2641.
# Df Residuals:                      90   BIC:                             2690.
# Df Model:                          17
# Covariance Type:            nonrobust
# ...
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const          1.035e+05   8.55e+04      1.211      0.229   -6.64e+04    2.73e+05
# ...

# %%
df.to_csv('덕수궁.csv', index = False)
봄.to_csv('덕수궁_봄.csv', index = False)
여름.to_csv('덕수궁_여름.csv', index = False)
가을.to_csv('덕수궁_가을.csv', index = False)
겨울.to_csv('덕수궁_겨울.csv', index = False)
