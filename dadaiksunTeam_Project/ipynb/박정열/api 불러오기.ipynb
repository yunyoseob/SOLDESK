# %% [markdown]
# # 폴더 생성 및 기본 라이브러리 시행

# %%
# 구글 드라이브에 연동 그리고 공유폴더의 접근
import os

from google.colab import drive
root = '/content/drive'
drive.mount(root)

co_work = '/MyDrive/sd솔데스크/팀 프로젝트/Proj_WT'
cw_path = root + co_work

print(cw_path)
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive/sd솔데스크/팀 프로젝트/Proj_WT

# %%
# 코드 공유 폴더
codes = '/Codes'
code_path = cw_path + codes
print(code_path)

# 논문 공유 폴더
papers = '/Papers'
papers_path = cw_path + papers
print(papers_path)

# 데이터 공유 폴더
data = '/DataSets'
data_path = cw_path + data
print(data_path)
# Out:
# /content/drive/MyDrive/sd솔데스크/팀 프로젝트/Proj_WT/Codes
# /content/drive/MyDrive/sd솔데스크/팀 프로젝트/Proj_WT/Papers
# /content/drive/MyDrive/sd솔데스크/팀 프로젝트/Proj_WT/DataSets

# %%
# 기본적인 모듈
import sys
import time
import math
import random

# DataFrame
import csv
import numpy as np
import pandas as pd

# %% [markdown]
# # 드라이브 관련 명령어(기본편)
#
# ## 공유한 내용을 활용하는 방법

# %%
# 팀 프로젝트 경로로 변경
# %cd "{cw_path}"
# !ls

# 팀 프로젝트의 code가 있는 곳으로 경로 변경
# %cd '{code_path}'
# !ls

# 팀 프로젝트의 논문이 있는 곳으로 경로 변경
# %cd '{papers_path}'
# !ls

# 팀 프로젝트의 데이터가 있는 곳으로 경로 변경
# %cd "{data_path}"
# !ls
# Out:
# /content/drive/.shortcut-targets-by-id/1TVtWvZ4DNn7V20Aj6JzSd5_iRdbjEXbG/Proj_WT
# Codes  DataSets  Papers
# /content/drive/.shortcut-targets-by-id/1TVtWvZ4DNn7V20Aj6JzSd5_iRdbjEXbG/Proj_WT/Codes
# cowork_baseline.ipynb
# /content/drive/.shortcut-targets-by-id/1TVtWvZ4DNn7V20Aj6JzSd5_iRdbjEXbG/Proj_WT/Papers
# '해외방문관광객의 목적지 선택에 대한 기후의 영향 (1).pdf'
#  논문_리뷰.ipynb
# '한국형 관광기후지수(KTCI)의 개발에 관한 연구.gdoc'
# '한국형 관광기후지수(KTCI)의 개발에 관한 연구.pdf'
# '날씨 및 요일 특성이 관광정보시스템 이용에 미치는 영향에 관한 연구.rtf'
# '기후인자가 관광수요에 미치는 영향 패널데이터 모형의 적용.rtf'
# /content/drive/.shortcut-targets-by-id/1TVtWvZ4DNn7V20Aj6JzSd5_iRdbjEXbG/Proj_WT/DataSets
# 기상청_관광코스별_관광지_상세날씨  DataLabService_api.ipynb
# api활용_참고_문서		   locgoRegnVisitrDDList
# 기상청_일별_지상_종관_ASOS	   metcoRegnVisitrDDList
# ...

# %%
# 현재 디렉토리 확인
# !pwd
# Out:
# /content/drive/.shortcut-targets-by-id/1TVtWvZ4DNn7V20Aj6JzSd5_iRdbjEXbG/Proj_WT/DataSets

# %%
# 디렉토리 확인
# !ls
# Out:
# 기상청_관광코스별_관광지_상세날씨  DataLabService_api.ipynb
# api활용_참고_문서		   locgoRegnVisitrDDList
# 기상청_일별_지상_종관_ASOS	   metcoRegnVisitrDDList
# AsosDalyInfoService_api.ipynb	   openapi_baseline.ipynb
# check.ipynb			   TourStnInfoService_api.ipynb

# %%
# 개인 드라이버에 저장된 ipynb 공유
colab_private = '/MyDrive/bulabula'
colab_ipynb = '/bulabula.ipynb'

share = root + colab_private + colab_ipynb
# !cp '{share}' '{code_path}' # 복사 명령어(복사 전 저장 필수)

# %cd '{code_path}'
# !ls
# Out:
# cp: cannot stat '/content/drive/MyDrive/bulabula/bulabula.ipynb': No such file or directory
# /content/drive/.shortcut-targets-by-id/1TVtWvZ4DNn7V20Aj6JzSd5_iRdbjEXbG/Proj_WT/Codes
# cowork_baseline.ipynb

# %%
# drive code에서 오픈한 cowork_baseline copy
# %cd '{code_path}'

# %%
# !pip install xmltodict

# %%
from urllib.request import Request, urlopen
from urllib.parse import urlencode, quote_plus
import xmltodict
import json

encoding_key = 'h60jLQ4JPWBPniY%2FDdRGUNPlNWdBVthHbtzGoDV0lHuMWxPccxAVVALvc5uiFeLyKSGs72GFvJluiEqMzfDNhQ%3D%3D'
decoding_key = 'h60jLQ4JPWBPniY/DdRGUNPlNWdBVthHbtzGoDV0lHuMWxPccxAVVALvc5uiFeLyKSGs72GFvJluiEqMzfDNhQ=='
numOfRows = 10
pageNo = 1
MobileApp = 'AppTest'
MobileOS = 'ETC'
startYmd = '20210513'
endYmd = '20210513'

url = f"http://api.visitkorea.or.kr/openapi/service/rest/DataLabService/metcoRegnVisitrDDList?ServiceKey={encoding_key}&pageNo={pageNo}&numOfRows={numOfRows}&MobileOS={MobileOS}&MobileApp={MobileApp}&startYmd={startYmd}&endYmd={endYmd}"
req = Request(url)
resp_body = urlopen(req).read()
# print(resp_body)#type : bytes
# json_str = resp_body.decode("UTF-8")  #bytes to str
# print(json_str, '\n',type(json_str))
# xml_parse = xmltodict.parse(json_str) #xmlr to json dict
# print(xml_parse, '\n',type(xml_parse))
# json_obj = json.loads(json.dumps(xml_parse))  #convert json
# print(json_obj, '\n',type(json_obj))
# apt = pd.json_normalize(json_obj['response']['body']['items']['item'])  #make dataframe

# %%
from urllib.request import Request, urlopen
from urllib.parse import urlencode, quote_plus
import xmltodict
import json
encoding_key = 'h60jLQ4JPWBPniY%2FDdRGUNPlNWdBVthHbtzGoDV0lHuMWxPccxAVVALvc5uiFeLyKSGs72GFvJluiEqMzfDNhQ%3D%3D'
numOfRows = 10
pageNo = 1
# encoding_key = 'yRxjHtUyF3aadfyII7o4rlbGO0QK4kY2Uf46AoDzfvoCgVT6wHHceyMx%2Be1DZvcYHLAl4h2ANO02EFyWxkd%2FHA%3D%3D'
MobileApp = 'AppTest'
MobileOS = 'ETC'
startYmd = '20210513'
endYmd = '20210513'
url = f"http://api.visitkorea.or.kr/openapi/service/rest/DataLabService/metcoRegnVisitrDDList?ServiceKey={encoding_key}&numOfRows={numOfRows}&MobileOS={MobileOS}&pageNo={pageNo}&MobileApp={MobileApp}&startYmd={startYmd}&endYmd={endYmd}"
req = Request(url)
resp_body = urlopen(req).read()
print(resp_body)#type : bytes
# Out:
# b'<?xml version="1.0" encoding="UTF-8" standalone="yes"?><response><header><resultCode>0000</resultCode><resultMsg>OK</resultMsg></header><body><items><item><areaCode>11</areaCode><areaNm>\xec\x84\x9c\xec\x9a\xb8\xed\x8a\xb9\xeb\xb3\x84\xec\x8b\x9c</areaNm><baseYmd>20210513</baseYmd><daywkDivCd>4</daywkDivCd><daywkDivNm>\xeb\xaa\xa9\xec\x9a\x94\xec\x9d\xbc</daywkDivNm><touDivCd>1</touDivCd><touDivNm>\xed\x98\x84\xec\xa7\x80\xec\x9d\xb8(a)</touDivNm><touNum>4828435.5</touNum></item><item><areaCode>11</areaCode><areaNm>\xec\x84\x9c\xec\x9a\xb8\xed\x8a\xb9\xeb\xb3\x84\xec\x8b\x9c</areaNm><baseYmd>20210513</baseYmd><daywkDivCd>4</daywkDivCd><daywkDivNm>\xeb\xaa\xa9\xec\x9a\x94\xec\x9d\xbc</daywkDivNm><touDivCd>2</touDivCd><touDivNm>\xec\x99\xb8\xec\xa7\x80\xec\x9d\xb8(b)</touDivNm><touNum>1255828</touNum></item><item><areaCode>11</areaCode><areaNm>\xec\x84\x9c\xec\x9a\xb8\xed\x8a\xb9\xeb\xb3\x84\xec\x8b\x9c</areaNm><baseYmd>20210513</baseYmd><daywkDivCd>4</daywkDivCd><daywkDivNm>\xeb\xaa
# ...

# %%
url = 'http://api.visitkorea.or.kr/openapi/service/rest/DataLabService/metcoRegnVisitrDDList'
queryParams = '?' + urlencode({ quote_plus('ServiceKey') : f'{encoding_key}', quote_plus('pageNo') : f'{pageNo}', quote_plus('numOfRows') : f'{numOfRows}', quote_plus('MobileOS') : f'{MobileOS}', quote_plus('MobileApp') : f'{MobileApp}', quote_plus('startYmd') : f'{startYmd}', quote_plus('endYmd') : f'{endYmd}' })

request = Request(url + queryParams)
request.get_method = lambda: 'GET'
response_body = urlopen(request).read()
print(response_body)
# Out:
# b'<?xml version="1.0" encoding="UTF-8" standalone="yes"?><response><header><responseTime>2021-06-21T08:48:27.056+09:00</responseTime><resultCode>30</resultCode><resultMsg>SERVICE KEY IS NOT REGISTERED ERROR.</resultMsg></header></response>'

# %%
# 아파트 거래 실거래 이건 됩니다!!
from urllib.request import Request, urlopen
from urllib.parse import urlencode, quote_plus
import xmltodict
import json
import pandas as pd

encoding_key = 'h60jLQ4JPWBPniY%2FDdRGUNPlNWdBVthHbtzGoDV0lHuMWxPccxAVVALvc5uiFeLyKSGs72GFvJluiEqMzfDNhQ%3D%3D'
decoding_key = 'h60jLQ4JPWBPniY/DdRGUNPlNWdBVthHbtzGoDV0lHuMWxPccxAVVALvc5uiFeLyKSGs72GFvJluiEqMzfDNhQ=='
numOfRows = 10
pageNo = 1
MobileApp = 'AppTest'
MobileOS = 'ETC'
startYmd = '20210513'
endYmd = '20210513'
LAWD_CD = '11110'
DEAL_YMD = '201512'
serviceKey = 'h60jLQ4JPWBPniY%2FDdRGUNPlNWdBVthHbtzGoDV0lHuMWxPccxAVVALvc5uiFeLyKSGs72GFvJluiEqMzfDNhQ%3D%3D'
url = f"http://openapi.molit.go.kr:8081/OpenAPI_ToolInstallPackage/service/rest/RTMSOBJSvc/getRTMSDataSvcAptTrade?serviceKey={serviceKey}&LAWD_CD={LAWD_CD}&DEAL_YMD={DEAL_YMD}"
req = Request(url)
resp_body = urlopen(req).read()
print(resp_body)
json_str = resp_body.decode("UTF-8")  #bytes to str
print(json_str, '\n',type(json_str))
xml_parse = xmltodict.parse(json_str) #xmlr to json dict
print(xml_parse, '\n',type(xml_parse))
json_obj = json.loads(json.dumps(xml_parse))  #convert json
print(json_obj, '\n',type(json_obj))
apt = pd.json_normalize(json_obj['response']['body']['items']['item'])
print(apt)
# Out:
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# /usr/lib/python3.7/urllib/request.py in do_open(self, http_class, req, **http_conn_args)
#    1349                 h.request(req.get_method(), req.selector, req.data, headers,
# -> 1350                           encode_chunked=req.has_header('Transfer-encoding'))
#    1351             except OSError as err: # timeout error
#
# /usr/lib/python3.7/http/client.py in request(self, method, url, body, headers, encode_chunked)
#    1276         """Send a complete request to the server."""
# -> 1277         self._send_request(method, url, body, headers, encode_chunked)
#    1278
#
# /usr/lib/python3.7/http/client.py in _send_request(self, method, url, body, headers, encode_chunked)
#    1322             body = _encode(body, 'body')
# -> 1323         self.endheaders(body, encode_chunked=encode_chunked)
#    1324
#
# ...

# %%
seviceKey = 'h60jLQ4JPWBPniY/DdRGUNPlNWdBVthHbtzGoDV0lHuMWxPccxAVVALvc5uiFeLyKSGs72GFvJluiEqMzfDNhQ=='
# encoding_key = 'h60jLQ4JPWBPniY%2FDdRGUNPlNWdBVthHbtzGoDV0lHuMWxPccxAVVALvc5uiFeLyKSGs72GFvJluiEqMzfDNhQ%3D%3D'
numOfRows = '10'
pageNo = '1'
dataCd = 'ASOS'
dateCd = 'DAY'
startDt = '20091201'
endDt = '20100102'
stnlds = '108'
url = f'http://apis.data.go.kr/1360000/AsosDalyInfoService/getWthrDataList?serviceKey={serviceKey}&numOfRows={numOfRows}&pageNo={pageNo}&dataCd={dataCd}&dateCd={dateCd}&startDt={startDt}&endDt={endDt}&stnIds={stnlds}'
req = Request(url)
resp_body = urlopen(req).read()
# print(resp_body)
json_str = resp_body.decode("UTF-8")  #bytes to str
print(json_str, '\n',type(json_str))
xml_parse = xmltodict.parse(json_str) #xmlr to json dict
print(xml_parse, '\n',type(xml_parse))
json_obj = json.loads(json.dumps(xml_parse))  #convert json
print(json_obj, '\n',type(json_obj))
apt = pd.json_normalize(json_obj['response']['body']['items']['item'])
# Out:
# <?xml version="1.0" encoding="UTF-8"?>
# ...

# %%
apt
# Out:
#   stnId stnNm  ...                                               iscs sumFogDur
# 0   108    서울  ...  -{연무}-{연무}{강도0}0300-{연무}{강도0}0600-{연무}{강도0}090...      None
# 1   108    서울  ...  -{박무}-{박무}{강도1}0300-{박무}{강도1}0600-{박무}{강도0}090...      None
# 2   108    서울  ...  -{연무}-0109. {박무}0109-{박무}{강도1}0300-{박무}{강도0}06...      None
# 3   108    서울  ...  -{박무}-{박무}{강도0}0300-{박무}{강도0}0600-{박무}{강도0}090...      None
# 4   108    서울  ...  -{연무}-{연무}{강도0}0300-0305. {박무}0305-{박무}{강도0}06...      None
# 5   108    서울  ...                                               None      None
# 6   108    서울  ...                                               None      None
# 7   108    서울  ...  {박무}0505-{박무}{강도0}0600-0640. {박무}1130-{박무}{강도0...      None
# 8   108    서울  ...  {박무}0340-{박무}{강도0}0600-{박무}{강도1}0900-1030. {연무...      None
# 9   108    서울  ...  {비}0725-0840. {비}0955-{비}{강도0}1200-{비}{강도0}150...      None
#
# [10 rows x 62 columns]

# %%
data = pd.read_excel('/content/drive/MyDrive/sd솔데스크/팀 프로젝트/통합 문서1.xlsx')
data['지점'] = data['지점'].astype('str')
data[data['관리관서'] == '인천기상대']
# Out:
#      지점 지점명   관리관서
# 46  201  강화  인천기상대

# %%
data = pd.read_excel('/content/drive/MyDrive/sd솔데스크/팀 프로젝트/통합 문서1.xlsx')
data['지점'] = data['지점'].astype('str')

관리관서 = data.관리관서.unique()
# print(관리관서)

관리관서별데이터 = []
for j in 관리관서:
  기상청 = {}
  for i in data.index:
    if data.loc[i,'관리관서'] == j:
      기상청[data.loc[i,'지점명']] = data.loc[i,'지점']
    
  관리관서별데이터.append(기상청)

강원지방기상청 = 관리관서별데이터[0]
춘천기상대 = 관리관서별데이터[1]
수도권기상청 = 관리관서별데이터[2]
대구지방기상청 = 관리관서별데이터[3]
청주기상지청 = 관리관서별데이터[4]
홍성기상대 = 관리관서별데이터[5]
안동기상대 = 관리관서별데이터[6]
대전지방기상청 = 관리관서별데이터[7]
전주기상지청 = 관리관서별데이터[8]
울산기상대 = 관리관서별데이터[9]
창원기상대 = 관리관서별데이터[10]
광주지방기상청 = 관리관서별데이터[11]
부산지방기상청 = 관리관서별데이터[12]
목포기상대 = 관리관서별데이터[13]
제주지방기상청 = 관리관서별데이터[14]
인천기상대 = 관리관서별데이터[15]

id = [강원지방기상청, 춘천기상대, 수도권기상청, 대구지방기상청, 청주기상지청, 홍성기상대,
      안동기상대, 대전지방기상청, 전주기상지청, 울산기상대, 창원기상대, 광주지방기상청,
      부산지방기상청, 목포기상대, 제주지방기상청, 인천기상대]

# %%
for i in 관리관서:
  print(i)
# Out:
# 강원지방기상청
# 춘천기상대
# 수도권기상청
# 대구지방기상청
# 청주기상지청
# 홍성기상대
# 안동기상대
# 대전지방기상청
# 전주기상지청
# 울산기상대
# 창원기상대
# 광주지방기상청
# 부산지방기상청
# 목포기상대
# 제주지방기상청
# 인천기상대

# %%
from tqdm import tqdm
import datetime as dt

seviceKey = 'h60jLQ4JPWBPniY/DdRGUNPlNWdBVthHbtzGoDV0lHuMWxPccxAVVALvc5uiFeLyKSGs72GFvJluiEqMzfDNhQ=='
# encoding_key = 'h60jLQ4JPWBPniY%2FDdRGUNPlNWdBVthHbtzGoDV0lHuMWxPccxAVVALvc5uiFeLyKSGs72GFvJluiEqMzfDNhQ%3D%3D'
numOfRows = '100'
pageNo = '1'
dataCd = 'ASOS'
dateCd = 'DAY'
for j,i in zip(관리관서,id):
  데이터 = pd.DataFrame([])

  for name, area in tqdm(i.items()):
    startDt = '20170101'
    endDt = '20181231'
    while int(startDt)- int(endDt) <= 0:
      # 데이터 읽어오기
      url = f'http://apis.data.go.kr/1360000/AsosDalyInfoService/getWthrDataList?serviceKey={serviceKey}&numOfRows={numOfRows}&pageNo={pageNo}&dataCd={dataCd}&dateCd={dateCd}&startDt={startDt}&endDt={endDt}&stnIds={i[name]}'
      req = Request(url)
      resp_body = urlopen(req).read()
      json_str = resp_body.decode("UTF-8")  #bytes to str
      xml_parse = xmltodict.parse(json_str) #xmlr to json dict
      json_obj = json.loads(json.dumps(xml_parse))  #convert json
      try:
        apt = pd.json_normalize(json_obj['response']['body']['items']['item'])
        데이터 = pd.concat([데이터,apt], axis = 0)
      except:
        pass

      # 시간을 변경해 가면서 데이터 쌓아주기
      startDt = pd.to_datetime(startDt) + dt.timedelta(days = 100)
      startDt = startDt.strftime('%Y%m%d')

  데이터.to_csv(f'/content/drive/MyDrive/sd솔데스크/팀 프로젝트/데이터/{j}.csv')
# Out:
#   0%|          | 0/11 [00:00<?, ?it/s]
#
#
#
#
#   9%|▉         | 1/11 [00:12<02:02, 12.26s/it]
#
#
#
#
#  18%|█▊        | 2/11 [00:26<01:56, 12.92s/it]
#
#
#
#
#  27%|██▋       | 3/11 [00:40<01:44, 13.03s/it]
#
#
#
#
#  36%|███▋      | 4/11 [00:57<01:39, 14.23s/it]
#
#
#
#
#  45%|████▌     | 5/11 [01:10<01:23, 13.87s/it]
#
#
#
#
#  55%|█████▍    | 6/11 [01:22<01:06, 13.30s/it]
#
#
#
#
#  64%|██████▎   | 7/11 [01:35<00:52, 13.23s/it]
#
#
#
#
#  73%|███████▎  | 8/11 [01:48<00:39, 13.27s/it]
#
#
#
#
#  82%|████████▏ | 9/11 [02:01<00:26, 13.20s/it]
#
#
#
#
#  91%|█████████ | 10/11 [02:14<00:13, 13.15s/it]
#
#
#
#
# 100%|██████████| 11/11 [02:27<00:00, 13.39s/it]
#
#
#
#
#
#   0%|          | 0/3 [00:00<?, ?it/s]
#
#
#
#
#  33%|███▎      | 1/3 [00:13<00:26, 13.47s/it]
#
#
#
#
#  67%|██████▋   | 2/3 [00:25<00:12, 12.99s/it]
#
#
#
#
# 100%|██████████| 3/3 [00:38<00:00, 12.93s/it]
#
#
#
#
#
#   0%|          | 0/8 [00:00<?, ?it/s]
#
#
#
#
#  12%|█▎        | 1/8 [00:13<01:37, 13.88s/it]
#
#
#
# ...

# %%
# for of, br in zip(office[:6], branch[:6]):
#     print(f'{StDt[:4]}년도 {of} 데이터 수집을 시작합니다.')
#     # locals()[f'{of}_df'] = pd.DataFrame()
#     # locals()[f'{of}_NoData'] = []
#     for name, code in br.items():
#         try:
#             url = f"http://apis.data.go.kr/1360000/{SERVICE}/{STYPE}?serviceKey={KEY}&pageNo={PG_NO}&numOfRows={NoRows}&dataType={Dtype[1]}&dataCd={DCd}&dateCd={DtCd}&startDt={StDt}&endDt={EdDt}&stnIds={code}"
#             print(f'\t지점 {name} 데이터 수집을 시작합니다.')
#             resp = requests.get(url)
#             time.sleep(random.randint(2,10))
#             origin = resp.json()
#             if origin['response']['body']['totalCount']=="0":
#                 print(f"They don't have Data at {name}")
#                 locals()[f'{of}_NoData'].append(name)
#             else:
#                 NoRows = origin['response']['body']['totalCount']
#                 url = f"http://apis.data.go.kr/1360000/{SERVICE}/{STYPE}?serviceKey={KEY}&pageNo={PG_NO}&numOfRows={NoRows}&dataType={Dtype[1]}&dataCd={DCd}&dateCd={DtCd}&startDt={StDt}&endDt={EdDt}&stnIds={code}"
#                 resp = requests.get(url)
#                 time.sleep(random.randint(2,15))
#                 origin = resp.json()
#                 locals()[f'{of}_df'] = pd.concat([locals()[f'{of}_df'], pd.json_normalize(origin['response']['body']['items']['item'])])
#                 print(f'\t지점 {name} 데이터 수집이 완료되었습니다.')
#         except:
#             pass
#     print(f'{StDt[:4]}년도 {of} 데이터 수집이 완료되었습니다')

# %% [markdown]
# # 한국문화관광연구원_관광자원통계서비스

# %%
from urllib.request import Request, urlopen
from urllib.parse import urlencode, quote_plus
import xmltodict
import json
import pandas as pd

serviceKey = "yRxjHtUyF3aadfyII7o4rlbGO0QK4kY2Uf46AoDzfvoCgVT6wHHceyMx%2Be1DZvcYHLAl4h2ANO02EFyWxkd%2FHA%3D%3D"
YM = '201501'
SIDO = '부산광역시'
GUNGU = '해운대구'
RES_NM = '부산시립미술관'
url = u'http://openapi.tour.go.kr/openapi/service/TourismResourceStatsService/getPchrgTrrsrtVisitorList?serviceKey={serviceKey}&YM={YM}&SIDO={SIDO}&GUNGU={GUNGU}&RES_NM={RES_NM}'
# url=url.encode('cp949')
req = Request(url)
resp_body = urlopen(req).read()
json_str = resp_body.decode("UTF-8")  #bytes to str
xml_parse = xmltodict.parse(json_str) #xmlr to json dict
json_obj = json.loads(json.dumps(xml_parse))  #convert json
print(json_obj)
# Out:
# {'response': {'header': {'responseTime': '2021-06-23T00:37:38.386+09:00', 'resultCode': '30', 'resultMsg': 'SERVICE KEY IS NOT REGISTERED ERROR.'}}}

# %% [markdown]
# # 출입국관광통계서비스

# %%
from urllib.request import Request, urlopen
from urllib.parse import urlencode, quote_plus
import xmltodict
import json
import pandas as pd

serviceKey = 'h60jLQ4JPWBPniY%2FDdRGUNPlNWdBVthHbtzGoDV0lHuMWxPccxAVVALvc5uiFeLyKSGs72GFvJluiEqMzfDNhQ%3D%3D'
YM = '201501'
NAT_CD = '100'
ED_CD = 'D'

url = f'http://openapi.tour.go.kr/openapi/service/EdrcntTourismStatsService/getEdrcntTourismStatsList?serviceKey={serviceKey}&YM={YM}&NAT_CD={NAT_CD}&ED_CD={ED_CD}'
req = Request(url)
resp_body = urlopen(req).read()
json_str = resp_body.decode("UTF-8")  #bytes to str
xml_parse = xmltodict.parse(json_str) #xmlr to json dict
json_obj = json.loads(json.dumps(xml_parse))  #convert json
print(json_obj)
# Out:
# {'response': {'header': {'responseTime': '2021-06-23T01:00:18.819+09:00', 'resultCode': '20', 'resultMsg': 'SERVICE ACCESS DENIED ERROR.'}}}

# %% [markdown]
# # 기상특보목록조회

# %%
import numpy as np
import pandas as pd

serviceKey = 'h60jLQ4JPWBPniY%2FDdRGUNPlNWdBVthHbtzGoDV0lHuMWxPccxAVVALvc5uiFeLyKSGs72GFvJluiEqMzfDNhQ%3D%3D'
numOfRows = '10'
pageNo = '1'
dataType='XML'
stnld ='108'
fromTmFc = '20150101'
toTmFc = '20150101'
마지막날 = '20201231'
데이터 = pd.DataFrame([])
while (int(fromTmFc)-int(마지막날))<=0: 
  url = f'http://apis.data.go.kr/1360000/WthrWrnInfoService/getWthrWrnList?serviceKey={serviceKey}&numOfRows={numOfRows}&pageNo={pageNo}&dataType={dataType}&stnld={stnld}&fromTmFc={fromTmFc}&toTmFc={toTmFc}'
  req = Request(url)
  resp_body = urlopen(req).read()
  json_str = resp_body.decode("UTF-8")  #bytes to str
  xml_parse = xmltodict.parse(json_str) #xmlr to json dict
  json_obj = json.loads(json.dumps(xml_parse))  #convert json
  print(json_obj)
  try:
    apt = pd.json_normalize(json_obj['response']['body']['items']['item'])
    데이터 = pd.concat([데이터,apt], axis = 0)
  except:
    pass

  fromTmFc = pd.to_datetime(fromTmFc) + dt.timedelta(days = 10)
  fromTmFc = fromTmFc.strftime('%Y%m%d')

print(데이터)
# Out:
# {'response': {'header': {'resultCode': '99', 'resultMsg': '최대 조회 기간은 오늘 기준으로 6일 전까지입니다.'}}}
# {'response': {'header': {'resultCode': '99', 'resultMsg': '최대 조회 기간은 오늘 기준으로 6일 전까지입니다.'}}}
# {'response': {'header': {'resultCode': '99', 'resultMsg': '최대 조회 기간은 오늘 기준으로 6일 전까지입니다.'}}}
# {'response': {'header': {'resultCode': '99', 'resultMsg': '최대 조회 기간은 오늘 기준으로 6일 전까지입니다.'}}}
# {'response': {'header': {'resultCode': '99', 'resultMsg': '최대 조회 기간은 오늘 기준으로 6일 전까지입니다.'}}}
# {'response': {'header': {'resultCode': '99', 'resultMsg': '최대 조회 기간은 오늘 기준으로 6일 전까지입니다.'}}}
# {'response': {'header': {'resultCode': '99', 'resultMsg': '최대 조회 기간은 오늘 기준으로 6일 전까지입니다.'}}}
# {'response': {'header': {'resultCode': '99', 'resultMsg': '최대 조회 기간은 오늘 기준으로 6일 전까지입니다.'}}}
# {'response': {'header': {'resultCode': '99', 'resultMsg': '최대 조회 기간은 오늘 기준으로 6일 전까지입니다.'}}}
# {'response': {'header': {'resultCode': '99', 'resultMsg': '최대 조회 기간은 오늘 기준으로 6일 전까지입니다.'}}}
# ...

# %%
fromTmFc = '20210621'
toTmFc = '20210621'

url = f'http://apis.data.go.kr/1360000/WthrWrnInfoService/getWthrWrnList?serviceKey={serviceKey}&numOfRows={numOfRows}&pageNo={pageNo}&dataType={dataType}&stnld={stnld}&fromTmFc={fromTmFc}&toTmFc={toTmFc}'
req = Request(url)
resp_body = urlopen(req).read()
print(resp_body)
json_str = resp_body.decode("UTF-8")  #bytes to str
print(json_str)
xml_parse = xmltodict.parse(json_str) #xmlr to json dict
json_obj = json.loads(json.dumps(xml_parse))  #convert json
print(json_obj)
# Out:
# b'<?xml version="1.0" encoding="UTF-8"?>\r\n<response><header><resultCode>00</resultCode><resultMsg>NORMAL_SERVICE</resultMsg></header><body><dataType>XML</dataType><items><item><stnId>143</stnId><title>[\xed\x8a\xb9\xeb\xb3\xb4] \xec\xa0\x9c06-8\xed\x98\xb8 : 2021.06.21.15:30 / \xed\x92\x8d\xeb\x9e\x91\xec\xa3\xbc\xec\x9d\x98\xeb\xb3\xb4 \xeb\xb0\x9c\xed\x91\x9c (*)</title><tmFc>202106211530</tmFc><tmSeq>8</tmSeq></item><item><stnId>108</stnId><title>[\xed\x8a\xb9\xeb\xb3\xb4] \xec\xa0\x9c06-47\xed\x98\xb8 : 2021.06.21.15:30 / \xed\x92\x8d\xeb\x9e\x91\xec\xa3\xbc\xec\x9d\x98\xeb\xb3\xb4 \xeb\xb0\x9c\xed\x91\x9c (*)</title><tmFc>202106211530</tmFc><tmSeq>47</tmSeq></item><item><stnId>108</stnId><title>[\xed\x8a\xb9\xeb\xb3\xb4] \xec\xa0\x9c06-46\xed\x98\xb8 : 2021.06.21.10:00 / \xed\x92\x8d\xeb\x9e\x91\xec\xa3\xbc\xec\x9d\x98\xeb\xb3\xb4 \xeb\xb0\x9c\xed\x91\x9c (*)</title><tmFc>202106211000</tmFc><tmSeq>46</tmSeq></item><item><stnId>105</stnId><title>[\xed\x8a\xb9\xeb\xb3\xb4] \xec\
# ...
