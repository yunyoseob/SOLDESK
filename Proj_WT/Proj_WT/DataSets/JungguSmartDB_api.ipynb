# %% [markdown]
# # 드라이브 연동

# %%
import os

from google.colab import drive  
ROOT = "/content/drive" #구글 드라이브 연동
drive.mount(ROOT)

from os.path import join  
CO_WORK = "MyDrive/Proj_WT" 
CW_PATH = join(ROOT, CO_WORK) #공유 폴더로 접근 경로

CODES = "Codes" #코드/마크다운 공유 및 에러 해결 목적
CODE_PATH = join(CW_PATH, CODES)
# !mkdir "{CODE_PATH}"

PAPERS = "Papers" #논문 공유 폴더
PAPER_PATH = join(CW_PATH, PAPERS)
# !mkdir "{PAPER_PATH}"

DATAS = "DataSets"  #데이터 공유 폴더
DATA_PATH = join(CW_PATH, DATAS)
# !mkdir "{DATA_PATH}"

# %cd "{DATA_PATH}"
# !ls
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive/Proj_WT/DataSets
# 기상청_관광코스별_관광지_상세날씨  DataLabService_api.ipynb
# 한국관광공사_관광빅데이터	   JungguSmartDB_api.ipynb
# api활용_참고_문서		   openapi_baseline.ipynb
# 기상청_일별_지상_종관_ASOS	   TourismResourceStatsService_api.ipynb
# AsosDalyInfoService_api.ipynb	   TourStnInfoService_api.ipynb
# check.ipynb

# %%
SV = join(DATA_PATH, "기상청_일별_지상_종관_ASOS")
# !mkdir "{SV}"
# %cd "{SV}"
# !ls
# Out:
# /content/drive/MyDrive/Proj_WT/DataSets/기상청_일별_지상_종관_ASOS
# 데이터			    청주기상지청_2019_2020.csv
# 목포기상대_2019_2020.csv    전주기상지청_2019_2020.csv
# 춘천기상대_2019_2020.csv    대구지방기상청_2019_2020.csv
# 홍성기상대_2019_2020.csv    제주지방기상청_2019_2020.csv
# 안동기상대_2019_2020.csv    대전지방기상청_2019_2020.csv
# 울산기상대_2019_2020.csv    광주지방기상청_2019_2020.csv
# 창원기상대_2019_2020.csv    부산지방기상청_2019_2020.csv
# 인천기상대_2019_2020.csv    강원지방기상청_2019_2020.csv
# 수도권기상청_2019_2020.csv  branch.xlsx

# %% [markdown]
# # 현재 진행 상황 확인용

# %%
# %cd "{CW_PATH}"
# !ls
# Out:
# /content/drive/.shortcut-targets-by-id/1TVtWvZ4DNn7V20Aj6JzSd5_iRdbjEXbG/Proj_WT
# Codes  DataSets  Papers

# %%
# %cd "{CODE_PATH}"
# !ls
# Out:
# /content/drive/.shortcut-targets-by-id/1TVtWvZ4DNn7V20Aj6JzSd5_iRdbjEXbG/Proj_WT/Codes
# cowork_baseline.ipynb

# %%
# %cd "{PAPER_PATH}"
# !ls
# Out:
# /content/drive/.shortcut-targets-by-id/1TVtWvZ4DNn7V20Aj6JzSd5_iRdbjEXbG/Proj_WT/Papers
# '해외방문관광객의 목적지 선택에 대한 기후의 영향 (1).pdf'
#  논문_리뷰.ipynb
# '한국형 관광기후지수(KTCI)의 개발에 관한 연구.gdoc'
# '한국형 관광기후지수(KTCI)의 개발에 관한 연구.pdf'
# '날씨 및 요일 특성이 관광정보시스템 이용에 미치는 영향에 관한 연구.rtf'
# '기후인자가 관광수요에 미치는 영향 패널데이터 모형의 적용.rtf'

# %%
# %cd "{DATA_PATH}"
# !ls
# Out:
# /content/drive/.shortcut-targets-by-id/1TVtWvZ4DNn7V20Aj6JzSd5_iRdbjEXbG/Proj_WT/DataSets
# 기상청_관광코스별_관광지_상세날씨  DataLabService_api.ipynb
# api활용_참고_문서		   locgoRegnVisitrDDList
# 기상청_일별_지상_종관_ASOS	   metcoRegnVisitrDDList
# AsosDalyInfoService_api.ipynb	   openapi_baseline.ipynb
# check.ipynb			   TourStnInfoService_api.ipynb

# %%
# 참고문서 폴더
#REP = join(DATA_PATH, "api활용_참고_문서")
# files = join(DATA_PATH, "한국문화관광연구원 관광산업통계서비스 활용가이드_v1.2.docx")
# !mv "{files}" "{REP}"
# !cp TourStnInfoService_api.ipynb
# %cd "{REP}"
# !ls

# 참고문서 업로드
# from google.colab import files
# files.upload()

# 참고문서 다운로드
# files.download("f{}_api.ipynb")
# Out:
# /content/drive/.shortcut-targets-by-id/1TVtWvZ4DNn7V20Aj6JzSd5_iRdbjEXbG/Proj_WT/DataSets
#      <input type="file" id="files-e271a49a-3dc2-4f31-8930-177c2178b2b2" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-e271a49a-3dc2-4f31-8930-177c2178b2b2">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
#  기상청27_관광코스별_관광지_상세_날씨_조회서비스_오픈API활용가이드.docx
# '31. 한국도로공사+OpenAPI+활용가이드(실시간 소통 데이터).docx'
#  locgoRegnVisitrDDList_api.ipynb
#  metcoRegnVisitrDDList_21_04.csv
#  metcoRegnVisitrDDList_21_05.csv
#  metcoRegnVisitrDDList_21_06.csv
#  metcoRegnVisitrDDList_api.ipynb
#  openapi_baseline.ipynb
# 'TourAPI_Guide_(DataLab)v1.0_20210527'
# '한국문화관광연구원 관광실태조사서비스 활용가이드_v1.1.docx'
# '한국문화관광연구원 관광자원통계서비스 활용가이드_v1.1.docx'
# '한국문화관광연구원 관광산업통계서비스 활용가이드_v1.2.docx'

# %%
# !pip install python-docx
# Out:
# Collecting python-docx
#   Downloading https://files.pythonhosted.org/packages/8b/a0/52729ce4aa026f31b74cc877be1d11e4ddeaa361dc7aebec148171644b33/python-docx-0.8.11.tar.gz (5.6MB)
#      |████████████████████████████████| 5.6MB 5.4MB/s
# Requirement already satisfied: lxml>=2.3.2 in /usr/local/lib/python3.7/dist-packages (from python-docx) (4.2.6)
# Building wheels for collected packages: python-docx
#   Building wheel for python-docx (setup.py) ... done
#   Created wheel for python-docx: filename=python_docx-0.8.11-cp37-none-any.whl size=184508 sha256=2926ac4651861b6104eab5de3c1b6eb48dfc4bb02e2b9a22f446adef632fd7b6
#   Stored in directory: /root/.cache/pip/wheels/a6/90/f1/a7cb70b38633ae04e7fb963b1c70f63fd6fc01c075b8230adc
# Successfully built python-docx
# Installing collected packages: python-docx
# Successfully installed python-docx-0.8.11

# %%
# import docx
# file_name = "기상청27_관광코스별_관광지_상세_날씨_조회서비스_오픈API활용가이드.docx"
# FN = join(DATA_PATH, file_name)

# doc = docx.Document(FN)

# %% [markdown]
# docx 파일을 보면서 파라미터 수정하는 데에 활용
#
# 자세한 방법은 우선 데이터부터 모으고 나중에 생각하겠습니다~

# %% [markdown]
# # 관련 라이브러리

# %%
# !pip install xmltodict
# Out:
# Collecting xmltodict
#   Downloading https://files.pythonhosted.org/packages/28/fd/30d5c1d3ac29ce229f6bdc40bbc20b28f716e8b363140c26eff19122d8a5/xmltodict-0.12.0-py2.py3-none-any.whl
# Installing collected packages: xmltodict
# Successfully installed xmltodict-0.12.0

# %%
import sys
import re
import random
import time
from datetime import datetime, timedelta

import math
import ast
from ast import literal_eval

import csv
import numpy as np
import pandas as pd

import json
import requests
import xmltodict
import urllib
import urllib.request
import xml.dom.minidom
from xml.etree.ElementTree import parse
from urllib.request import urlopen
from urllib.parse import urlencode, unquote, quote_plus

# %%
# %cd "{SV}"
# !ls
# Out:
# [Errno 2] No such file or directory: '{SV}'
# /content/drive/MyDrive/Proj_WT/DataSets
# 기상청_관광코스별_관광지_상세날씨  DataLabService_api.ipynb
# 한국관광공사_관광빅데이터	   JungguSmartDB_api.ipynb
# api활용_참고_문서		   openapi_baseline.ipynb
# 기상청_일별_지상_종관_ASOS	   TourismResourceStatsService_api.ipynb
# AsosDalyInfoService_api.ipynb	   TourStnInfoService_api.ipynb
# check.ipynb

# %% [markdown]
# # 기상청_지상(종관, ASOS) 일자료 조회서비스

# %% [markdown]
# * 종관기상관측 장비로 관측한 일 기상자료를 조회하는 서비스
# * 수시(전일(D-1)) 자료까지 제공, 전일 자료 제공시간 11시~

# %% [markdown]
# ## 기본 파라미터

# %%
SERVICE = "AsosDalyInfoService"
STYPE = "getWthrDataList"
# KEY = ""  #서비스키
KEY = "yRxjHtUyF3aadfyII7o4rlbGO0QK4kY2Uf46AoDzfvoCgVT6wHHceyMx%2Be1DZvcYHLAl4h2ANO02EFyWxkd%2FHA%3D%3D" #서비스키
PG_NO = "1"
NoRows = "10"
Dtype = ["XML", "JSON"]
DCd = "ASOS"
DtCd = "DAY"

# %%
import requests
# url = f"https://www.data.go.kr/data/15067236/openapi.do"
url = f"http://smarttour.junggu.seoul.kr//junggu/openapi/culture.do"
# req = requests.get(url)
# print(req)
req = urllib.request.Request(url)
print(req, '\n', type(req))
resp = urlopen(req).read().decode("UTF-8")
print(resp, '\n', type(resp))
# time.sleep(random.randint(2,10))
origin = resp.json()
# xml_parse = xmltodict.parse(urlopen(req).read().decode("UTF-8")) #xml to json dict
print(origin, '\n', type(origin))
# origin = json.loads(json.dumps(xml_parse))
# print(origin)
# Out:
# <urllib.request.Request object at 0x7efc29764d50>
#  <class 'urllib.request.Request'>
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# /usr/lib/python3.7/urllib/request.py in do_open(self, http_class, req, **http_conn_args)
#    1349                 h.request(req.get_method(), req.selector, req.data, headers,
# -> 1350                           encode_chunked=req.has_header('Transfer-encoding'))
#    1351             except OSError as err: # timeout error
#
# /usr/lib/python3.7/http/client.py in request(self, method, url, body, headers, encode_chunked)
#    1276         """Send a complete request to the server."""
# -> 1277         self._send_request(method, url, body, headers, encode_chunked)
#    1278
#
# /usr/lib/python3.7/http/client.py in _send_request(self, method, url, body, headers, encode_chunked)
#    1322             body = _encode(body, 'body')
# -> 1323         self.endheaders(body, encode_chunked=encode_chunked)
#    1324
#
# /usr/lib/python3.7/http/client.py in endheaders(self, message_body, encode_chunked)
#    1271             raise CannotSendHeader()
# -> 1272         self._send_output(message_body, encode_chunked=encode_chunked)
#    1273
#
# /usr/lib/python3.7/http/client.py in _send_output(self, message_body, encode_chunked)
#    1031         del self._buffer[:]
# -> 1032         self.send(msg)
#    1033
#
# /usr/lib/python3.7/http/client.py in send(self, data)
#     971             if self.auto_open:
# --> 972                 self.connect()
#     973             else:
#
# /usr/lib/python3.7/http/client.py in connect(self)
#     943         self.sock = self._create_connection(
# --> 944             (self.host,self.port), self.timeout, self.source_address)
#     945         self.sock.setsockopt(socket.IPPROTO_TCP, socket.TCP_NODELAY, 1)
#
# /usr/lib/python3.7/socket.py in create_connection(address, timeout, source_address)
#     706     err = None
# --> 707     for res in getaddrinfo(host, port, 0, SOCK_STREAM):
#     708         af, socktype, proto, canonname, sa = res
#
# /usr/lib/python3.7/socket.py in getaddrinfo(host, port, family, type, proto, flags)
#     751     addrlist = []
# --> 752     for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
#     753         af, socktype, proto, canonname, sa = res
#
# gaierror: [Errno -3] Temporary failure in name resolution
#
# During handling of the above exception, another exception occurred:
#
# URLError                                  Traceback (most recent call last)
# <ipython-input-28-57a4dd7dddac> in <module>()
#       6 req = urllib.request.Request(url)
#       7 print(req, '\n', type(req))
# ----> 8 resp = urlopen(req).read().decode("UTF-8")
#       9 print(resp, '\n', type(resp))
#      10 # time.sleep(random.randint(2,10))
#
# /usr/lib/python3.7/urllib/request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     220     else:
#     221         opener = _opener
# --> 222     return opener.open(url, data, timeout)
#     223
#     224 def install_opener(opener):
#
# /usr/lib/python3.7/urllib/request.py in open(self, fullurl, data, timeout)
#     523             req = meth(req)
#     524
# --> 525         response = self._open(req, data)
#     526
#     527         # post-process response
#
# /usr/lib/python3.7/urllib/request.py in _open(self, req, data)
#     541         protocol = req.type
#     542         result = self._call_chain(self.handle_open, protocol, protocol +
# --> 543                                   '_open', req)
#     544         if result:
#     545             return result
#
# /usr/lib/python3.7/urllib/request.py in _call_chain(self, chain, kind, meth_name, *args)
#     501         for handler in handlers:
#     502             func = getattr(handler, meth_name)
# --> 503             result = func(*args)
#     504             if result is not None:
#     505                 return result
#
# /usr/lib/python3.7/urllib/request.py in http_open(self, req)
#    1376
#    1377     def http_open(self, req):
# -> 1378         return self.do_open(http.client.HTTPConnection, req)
#    1379
#    1380     http_request = AbstractHTTPHandler.do_request_
#
# /usr/lib/python3.7/urllib/request.py in do_open(self, http_class, req, **http_conn_args)
#    1350                           encode_chunked=req.has_header('Transfer-encoding'))
#    1351             except OSError as err: # timeout error
# -> 1352                 raise URLError(err)
#    1353             r = h.getresponse()
#    1354         except:
#
# URLError: <urlopen error [Errno -3] Temporary failure in name resolution>

# %% [markdown]
# ## 2015~2016

# %%
StDt = "20150101"
EdDt = "20170101"

# %% [markdown]
# ### 2017~2018

# %%
# #2017
# StDt = "20170101"
# EdDt = "20180101"

# # dt17 = pd.read_csv(f'{SV}/시군구별관광기후지수_2017.csv')
# # ct17 = dt17['시도'].unique()
# # day17 = [d[:10] for d in dt17['예보시각'].unique()]

# # print(f'17년도 진행 상황 : \n\t{ct17}\n\t{day17}')
# # for tm in dt17.iloc[:,0]:
# #   if tm[:4]!="2017":
# #     print(tm[:4])

# %%
# #2018
# StDt = "20180101"
# EdDt = "20190101"

# # dt18 = pd.read_csv(f'{SV}/시군구별관광기후지수_2018.csv')
# # ct18 = dt18['시도'].unique()
# # day18 = [d[:10] for d in dt18['예보시각'].unique()]

# # print(f'18년도 진행 상황 : \n\t{ct18}\n\t{day18}')

# %% [markdown]
# ### 2019~2020

# %%
#2019
# StDt = "20190101"
# EdDt = "20200101"

# dt19 = pd.read_csv(f'{SV}/시군구별관광기후지수_2019.csv')
# ct19 = dt19['시도'].unique()
# day19 = [d[:10] for d in dt19['예보시각'].unique()]

# print(f'19년도 진행 상황 : \n\t{ct19}\n\t{day19}')

# %%
#2020
StDt = "20200101"
EdDt = "20210101"

# dt20 = pd.read_csv(f'{SV}/시군구별관광기후지수_2020.csv')
# ct20 = dt20['시도'].unique()
# day20 = [d[:10] for d in dt20['예보시각'].unique()]

# print(f'20년도 진행 상황 : \n\t{ct20}\n\t{day20}')

# %% [markdown]
# ### 2021 실시간

# %%
# #2021
# StDt = "20210101"
# now=datetime.now()
# EdDt = now.strftime('%Y%m%d')

# # dt21 = pd.read_csv(f'{SV}/시군구별관광기후지수_2021.csv')
# # ct21 = dt21['시도'].unique()
# # day21 = [d[:10] for d in dt21['예보시각'].unique()]

# # print(f'21년도 진행 상황 : \n\t{ct21}\n\t{day21}')

# %%
# url = f"http://apis.data.go.kr/1360000/{AsosDalyInfoService}/{STYPE}?serviceKey={KEY}&pageNo={PG_NO}&numOfRows={NoRows}&dataType={Dtype[1]}&dataCd={DCd}&dateCd={DtCd}&startDt={StDt}&endDt={EdDt}&stnIds={area}"

# %% [markdown]
# ### 지점 코드 정보

# %%
data = pd.read_excel(f'{SV}/branch.xlsx')
data['지점'] = data['지점'].astype('str')
office = data['관리관서'].unique()
print(office)
branch = []
for j in office:
  KMA = {}
  for i in data.index:
    if data.loc[i,'관리관서'] == j:
      KMA[data.loc[i,'지점명']] = data.loc[i,'지점']
  branch.append(KMA)
# Out:
# ['강원지방기상청' '춘천기상대' '수도권기상청' '대구지방기상청' '청주기상지청' '홍성기상대' '안동기상대' '대전지방기상청'
#  '전주기상지청' '울산기상대' '창원기상대' '광주지방기상청' '부산지방기상청' '목포기상대' '제주지방기상청' '인천기상대']

# %%
for of, br in zip(office, branch):
  print(of, br)
  for name, code in br.items():
    print(name, code)
# Out:
# 강원지방기상청 {'속초': '90', '철원': '95', '대관령': '100', '북강릉': '104', '강릉': '105', '동해': '106', '원주': '114', '영월': '121', '인제': '211', '태백': '216', '정선군': '217'}
# 속초 90
# 철원 95
# 대관령 100
# 북강릉 104
# 강릉 105
# 동해 106
# 원주 114
# 영월 121
# 인제 211
# 태백 216
# 정선군 217
# 춘천기상대 {'북춘천': '93', '춘천': '101', '홍천': '212'}
# 북춘천 93
# 춘천 101
# 홍천 212
# 수도권기상청 {'동두천': '98', '파주': '99', '백령도': '102', '서울': '108', '인천': '112', '수원': '119', '양평': '202', '이천': '203'}
# 동두천 98
# 파주 99
# 백령도 102
# 서울 108
# 인천 112
# 수원 119
# 양평 202
# 이천 203
# 대구지방기상청 {'울릉도': '115', '상주': '137', '포항': '138', '대구': '143', '봉화': '271', '청송군': '276', '영덕': '277', '의성': '278', '구미': '279', '영천': '281', '경주시': '283'}
# 울릉도 115
# 상주 137
# 포항 138
# 대구 143
# 봉화 271
# 청송군 276
# 영덕 277
# 의성 278
# 구미 279
# 영천 281
# 경주시 283
# 청주기상지청 {'충주': '127', '청주': '131', '추풍령': '135', '제천': '221', '보은': '226'}
# 충주 127
# 청주 131
# 추풍령 135
# 제천 221
# 보은 226
# 홍성기상대 {'서산': '129', '홍성': '177'}
# 서산 129
# 홍성 177
# 안동기상대 {'울진': '130', '안동': '136', '영주': '272', '문경': '273'}
# 울진 130
# 안동 136
# 영주 272
# 문경 273
# 대전지방기상청 {'대전': '133', '천안': '232', '보령': '235', '부여': '236', '금산': '238', '세종': '239'}
# 대전 133
# 천안 232
# 보령 235
# 부여 236
# 금산 238
# 세종 239
# 전주기상지청 {'군산': '140', '전주': '146', '고창': '172', '부안': '243', '임실': '244', '정읍': '245', '남원': '247', '장수': '248', '고창군': '251', '순창군': '254'}
# 군산 140
# 전주 146
# 고창 172
# 부안 243
# 임실 244
# 정읍 245
# 남원 247
# 장수 248
# 고창군 251
# 순창군 254
# 울산기상대 {'울산': '152', '양산시': '257', '거창': '284', '합천': '285', '밀양': '288'}
# 울산 152
# 양산시 257
# 거창 284
# 합천 285
# 밀양 288
# 창원기상대 {'창원': '155', '진주': '192', '북창원': '255', '의령군': '263', '함양군': '264', '산청': '289'}
# 창원 155
# 진주 192
# 북창원 255
# 의령군 263
# 함양군 264
# 산청 289
# 광주지방기상청 {'광주': '156', '여수': '168', '흑산도': '169', '순천': '174', '영광군': '252', '보성군': '258', '고흥': '262', '광양시': '266'}
# 광주 156
# 여수 168
# 흑산도 169
# 순천 174
# 영광군 252
# 보성군 258
# 고흥 262
# 광양시 266
# 부산지방기상청 {'부산': '159', '통영': '162', '김해시': '253', '거제': '294', '남해': '295'}
# 부산 159
# 통영 162
# 김해시 253
# 거제 294
# 남해 295
# 목포기상대 {'목포': '165', '완도': '170', '강진군': '259', '장흥': '260', '해남': '261', '진도군': '268'}
# 목포 165
# 완도 170
# 강진군 259
# 장흥 260
# 해남 261
# 진도군 268
# 제주지방기상청 {'제주': '184', '고산': '185', '성산': '188', '서귀포': '189'}
# 제주 184
# 고산 185
# 성산 188
# 서귀포 189
# 인천기상대 {'강화': '201'}
# 강화 201

# %% [markdown]
# * 20210620
#
# 데이터가 너무 커서 우선은 1개년씩 불러오는 중
#
# 각각의 데이터는
#
#
# ```
# for of, br in zip(office, branch):
#     locals()[f'{of}_df'] = pd.DataFrame()
#     locals()[f'{of}_NoData'] = []
#     for name, code in br.items():
#         ~>
#
# ```
#
# 반복문을 활용해서 관리기관별 데이터프레임에 저장되도록 만듦
#
#
# 정열님께서는 2017~2018
#
# 나는 2019~2020을 맡아 수집 중

# %%
len(office[:16])
# Out:
# 16

# %%
len(branch)
# Out:
# 16

# %% [markdown]
# ## 한번에 불러오기

# %% [markdown]
# ### xml

# %%
for of, br in zip(office, branch):
    print(f'{StDt[:4]}년도 {of} 데이터 수집을 시작합니다.')
    locals()[f'{of}_df'] = pd.DataFrame()
    locals()[f'{of}_NoData'] = []
    for name, code in br.items():
        try:
            url = f"http://apis.data.go.kr/1360000/{SERVICE}/{STYPE}?serviceKey={KEY}&pageNo={PG_NO}&numOfRows={NoRows}&dataType={Dtype[0]}&dataCd={DCd}&dateCd={DtCd}&startDt={StDt}&endDt={EdDt}&stnIds={code}"
            print(f'\t지점 {name} 데이터 수집을 시작합니다.')
            req = urllib.request.Request(url)
            time.sleep(random.randint(2,10))
            xml_parse = xmltodict.parse(urlopen(req).read().decode("UTF-8")) #xml to json dict
            origin = json.loads(json.dumps(xml_parse))

            if origin['response']['body']['totalCount']=="0":
                print(f"They don't have Data at {name}")
                locals()[f'{of}_NoData'].append(name)

            else:
                NoRows = origin['response']['body']['totalCount']
                url = f"http://apis.data.go.kr/1360000/{SERVICE}/{STYPE}?serviceKey={KEY}&pageNo={PG_NO}&numOfRows={NoRows}&dataType={Dtype[0]}&dataCd={DCd}&dateCd={DtCd}&startDt={StDt}&endDt={EdDt}&stnIds={code}"
                req = urllib.request.Request(url)
                time.sleep(random.randint(3,15))
                xml_parse = xmltodict.parse(urlopen(req).read().decode("UTF-8")) #xml to json dict
                origin = json.loads(json.dumps(xml_parse))
                locals()[f'{of}_df'] = pd.concat([locals()[f'{of}_df'], pd.json_normalize(origin['response']['body']['items']['item'])])

                print(f'\t지점 {name} 데이터 수집이 완료되었습니다.')

        except:
            pass
    print(f'{EdDt[:4]}년도 {of} 데이터 수집이 완료되었습니다')

# %% [markdown]
# ### json

# %% [markdown]
# * [:6]
# * [6:11]
# * [11:]
#
# 데이터 커서 3구역으로 나눠서 자동화 돌림
#
#
# ```
# # locals()[f'{of}_df'] = pd.DataFrame()
# # locals()[f'{of}_NoData'] = []
# ```
#
# 반복문 안에 이 부분은 년별로 불러올 때, 처음 초기화 작업에만 사용하고 runtime 초기화를 한 게 아니면 주석처리해서 계속 쌓을 수 있음

# %%
for of, br in zip(office, branch):
    print(f'{StDt[:4]}년도 {of} 데이터 수집을 시작합니다.')
    locals()[f'{of}_df'] = pd.DataFrame()
    locals()[f'{of}_NoData'] = []
    for name, code in br.items():
        try:
            url = f"http://apis.data.go.kr/1360000/{SERVICE}/{STYPE}?serviceKey={KEY}&pageNo={PG_NO}&numOfRows={NoRows}&dataType={Dtype[1]}&dataCd={DCd}&dateCd={DtCd}&startDt={StDt}&endDt={EdDt}&stnIds={code}"
            print(f'\t지점 {name} 데이터 수집을 시작합니다.')
            resp = requests.get(url)
            time.sleep(random.randint(2,10))
            origin = resp.json()

            if origin['response']['body']['totalCount']=="0":
                print(f"They don't have Data at {name}")
                locals()[f'{of}_NoData'].append(name)

            else:
                NoRows = origin['response']['body']['totalCount']
                url = f"http://apis.data.go.kr/1360000/{SERVICE}/{STYPE}?serviceKey={KEY}&pageNo={PG_NO}&numOfRows={NoRows}&dataType={Dtype[1]}&dataCd={DCd}&dateCd={DtCd}&startDt={StDt}&endDt={EdDt}&stnIds={code}"
                resp = requests.get(url)
                time.sleep(random.randint(2,15))
                origin = resp.json()
                locals()[f'{of}_df'] = pd.concat([locals()[f'{of}_df'], pd.json_normalize(origin['response']['body']['items']['item'])])

                print(f'\t지점 {name} 데이터 수집이 완료되었습니다.')

        except:
            pass
    print(f'{int(EdDt[:4])-1}년도 {of} 데이터 수집이 완료되었습니다')
# Out:
# 2015년도 강원지방기상청 데이터 수집을 시작합니다.
# 	지점 속초 데이터 수집을 시작합니다.
# 	지점 속초 데이터 수집이 완료되었습니다.
# 	지점 철원 데이터 수집을 시작합니다.
# 	지점 철원 데이터 수집이 완료되었습니다.
# 	지점 대관령 데이터 수집을 시작합니다.
# 	지점 대관령 데이터 수집이 완료되었습니다.
# 	지점 북강릉 데이터 수집을 시작합니다.
# 	지점 북강릉 데이터 수집이 완료되었습니다.
# 	지점 강릉 데이터 수집을 시작합니다.
# 	지점 강릉 데이터 수집이 완료되었습니다.
# 	지점 동해 데이터 수집을 시작합니다.
# 	지점 동해 데이터 수집이 완료되었습니다.
# 	지점 원주 데이터 수집을 시작합니다.
# 	지점 원주 데이터 수집이 완료되었습니다.
# 	지점 영월 데이터 수집을 시작합니다.
# 	지점 영월 데이터 수집이 완료되었습니다.
# 	지점 인제 데이터 수집을 시작합니다.
# 	지점 인제 데이터 수집이 완료되었습니다.
# 	지점 태백 데이터 수집을 시작합니다.
# 	지점 태백 데이터 수집이 완료되었습니다.
# 	지점 정선군 데이터 수집을 시작합니다.
# 	지점 정선군 데이터 수집이 완료되었습니다.
# 2016년도 강원지방기상청 데이터 수집이 완료되었습니다
# 2015년도 춘천기상대 데이터 수집을 시작합니다.
# 	지점 북춘천 데이터 수집을 시작합니다.
# 	지점 북춘천 데이터 수집이 완료되었습니다.
# 	지점 춘천 데이터 수집을 시작합니다.
# 	지점 춘천 데이터 수집이 완료되었습니다.
# 	지점 홍천 데이터 수집을 시작합니다.
# 	지점 홍천 데이터 수집이 완료되었습니다.
# 2016년도 춘천기상대 데이터 수집이 완료되었습니다
# 2015년도 수도권기상청 데이터 수집을 시작합니다.
# 	지점 동두천 데이터 수집을 시작합니다.
# 	지점 동두천 데이터 수집이 완료되었습니다.
# 	지점 파주 데이터 수집을 시작합니다.
# 	지점 파주 데이터 수집이 완료되었습니다.
# 	지점 백령도 데이터 수집을 시작합니다.
# 	지점 백령도 데이터 수집이 완료되었습니다.
# 	지점 서울 데이터 수집을 시작합니다.
# 	지점 서울 데이터 수집이 완료되었습니다.
# 	지점 인천 데이터 수집을 시작합니다.
# 	지점 인천 데이터 수집이 완료되었습니다.
# 	지점 수원 데이터 수집을 시작합니다.
# 	지점 수원 데이터 수집이 완료되었습니다.
# 	지점 양평 데이터 수집을 시작합니다.
# 	지점 양평 데이터 수집이 완료되었습니다.
# 	지점 이천 데이터 수집을 시작합니다.
# 	지점 이천 데이터 수집이 완료되었습니다.
# 2016년도 수도권기상청 데이터 수집이 완료되었습니다
# 2015년도 대구지방기상청 데이터 수집을 시작합니다.
# 	지점 울릉도 데이터 수집을 시작합니다.
# 	지점 울릉도 데이터 수집이 완료되었습니다.
# 	지점 상주 데이터 수집을 시작합니다.
# 	지점 상주 데이터 수집이 완료되었습니다.
# 	지점 포항 데이터 수집을 시작합니다.
# 	지점 포항 데이터 수집이 완료되었습니다.
# 	지점 대구 데이터 수집을 시작합니다.
# 	지점 대구 데이터 수집이 완료되었습니다.
# 	지점 봉화 데이터 수집을 시작합니다.
# 	지점 봉화 데이터 수집이 완료되었습니다.
# 	지점 청송군 데이터 수집을 시작합니다.
# 	지점 청송군 데이터 수집이 완료되었습니다.
# 	지점 영덕 데이터 수집을 시작합니다.
# 	지점 영덕 데이터 수집이 완료되었습니다.
# 	지점 의성 데이터 수집을 시작합니다.
# 	지점 의성 데이터 수집이 완료되었습니다.
# 	지점 구미 데이터 수집을 시작합니다.
# 	지점 구미 데이터 수집이 완료되었습니다.
# 	지점 영천 데이터 수집을 시작합니다.
# 	지점 영천 데이터 수집이 완료되었습니다.
# 	지점 경주시 데이터 수집을 시작합니다.
# 	지점 경주시 데이터 수집이 완료되었습니다.
# 2016년도 대구지방기상청 데이터 수집이 완료되었습니다
# 2015년도 청주기상지청 데이터 수집을 시작합니다.
# 	지점 충주 데이터 수집을 시작합니다.
# 	지점 충주 데이터 수집이 완료되었습니다.
# 	지점 청주 데이터 수집을 시작합니다.
# 	지점 청주 데이터 수집이 완료되었습니다.
# 	지점 추풍령 데이터 수집을 시작합니다.
# 	지점 추풍령 데이터 수집이 완료되었습니다.
# 	지점 제천 데이터 수집을 시작합니다.
# 	지점 제천 데이터 수집이 완료되었습니다.
# 	지점 보은 데이터 수집을 시작합니다.
# 	지점 보은 데이터 수집이 완료되었습니다.
# 2016년도 청주기상지청 데이터 수집이 완료되었습니다
# 2015년도 홍성기상대 데이터 수집을 시작합니다.
# 	지점 서산 데이터 수집을 시작합니다.
# 	지점 서산 데이터 수집이 완료되었습니다.
# 	지점 홍성 데이터 수집을 시작합니다.
# 	지점 홍성 데이터 수집이 완료되었습니다.
# 2016년도 홍성기상대 데이터 수집이 완료되었습니다
# 2015년도 안동기상대 데이터 수집을 시작합니다.
# 	지점 울진 데이터 수집을 시작합니다.
# 	지점 울진 데이터 수집이 완료되었습니다.
# 	지점 안동 데이터 수집을 시작합니다.
# 	지점 안동 데이터 수집이 완료되었습니다.
# 	지점 영주 데이터 수집을 시작합니다.
# 	지점 영주 데이터 수집이 완료되었습니다.
# 	지점 문경 데이터 수집을 시작합니다.
# 	지점 문경 데이터 수집이 완료되었습니다.
# 2016년도 안동기상대 데이터 수집이 완료되었습니다
# 2015년도 대전지방기상청 데이터 수집을 시작합니다.
# 	지점 대전 데이터 수집을 시작합니다.
# 	지점 대전 데이터 수집이 완료되었습니다.
# 	지점 천안 데이터 수집을 시작합니다.
# 	지점 천안 데이터 수집이 완료되었습니다.
# 	지점 보령 데이터 수집을 시작합니다.
# 	지점 보령 데이터 수집이 완료되었습니다.
# 	지점 부여 데이터 수집을 시작합니다.
# 	지점 부여 데이터 수집이 완료되었습니다.
# 	지점 금산 데이터 수집을 시작합니다.
# 	지점 금산 데이터 수집이 완료되었습니다.
# 	지점 세종 데이터 수집을 시작합니다.
# 2016년도 대전지방기상청 데이터 수집이 완료되었습니다
# 2015년도 전주기상지청 데이터 수집을 시작합니다.
# 	지점 군산 데이터 수집을 시작합니다.
# 	지점 군산 데이터 수집이 완료되었습니다.
# 	지점 전주 데이터 수집을 시작합니다.
# 	지점 전주 데이터 수집이 완료되었습니다.
# 	지점 고창 데이터 수집을 시작합니다.
# 	지점 고창 데이터 수집이 완료되었습니다.
# 	지점 부안 데이터 수집을 시작합니다.
# 	지점 부안 데이터 수집이 완료되었습니다.
# 	지점 임실 데이터 수집을 시작합니다.
# 	지점 임실 데이터 수집이 완료되었습니다.
# 	지점 정읍 데이터 수집을 시작합니다.
# 	지점 정읍 데이터 수집이 완료되었습니다.
# 	지점 남원 데이터 수집을 시작합니다.
# 	지점 남원 데이터 수집이 완료되었습니다.
# 	지점 장수 데이터 수집을 시작합니다.
# 	지점 장수 데이터 수집이 완료되었습니다.
# 	지점 고창군 데이터 수집을 시작합니다.
# 	지점 고창군 데이터 수집이 완료되었습니다.
# 	지점 순창군 데이터 수집을 시작합니다.
# 	지점 순창군 데이터 수집이 완료되었습니다.
# 2016년도 전주기상지청 데이터 수집이 완료되었습니다
# 2015년도 울산기상대 데이터 수집을 시작합니다.
# 	지점 울산 데이터 수집을 시작합니다.
# 	지점 울산 데이터 수집이 완료되었습니다.
# 	지점 양산시 데이터 수집을 시작합니다.
# 	지점 양산시 데이터 수집이 완료되었습니다.
# 	지점 거창 데이터 수집을 시작합니다.
# 	지점 거창 데이터 수집이 완료되었습니다.
# 	지점 합천 데이터 수집을 시작합니다.
# 	지점 합천 데이터 수집이 완료되었습니다.
# 	지점 밀양 데이터 수집을 시작합니다.
# 	지점 밀양 데이터 수집이 완료되었습니다.
# 2016년도 울산기상대 데이터 수집이 완료되었습니다
# 2015년도 창원기상대 데이터 수집을 시작합니다.
# 	지점 창원 데이터 수집을 시작합니다.
# 	지점 창원 데이터 수집이 완료되었습니다.
# 	지점 진주 데이터 수집을 시작합니다.
# 	지점 진주 데이터 수집이 완료되었습니다.
# 	지점 북창원 데이터 수집을 시작합니다.
# 	지점 북창원 데이터 수집이 완료되었습니다.
# 	지점 의령군 데이터 수집을 시작합니다.
# 	지점 의령군 데이터 수집이 완료되었습니다.
# 	지점 함양군 데이터 수집을 시작합니다.
# 	지점 함양군 데이터 수집이 완료되었습니다.
# 	지점 산청 데이터 수집을 시작합니다.
# 	지점 산청 데이터 수집이 완료되었습니다.
# 2016년도 창원기상대 데이터 수집이 완료되었습니다
# 2015년도 광주지방기상청 데이터 수집을 시작합니다.
# 	지점 광주 데이터 수집을 시작합니다.
# 	지점 광주 데이터 수집이 완료되었습니다.
# 	지점 여수 데이터 수집을 시작합니다.
# 	지점 여수 데이터 수집이 완료되었습니다.
# 	지점 흑산도 데이터 수집을 시작합니다.
# 	지점 흑산도 데이터 수집이 완료되었습니다.
# 	지점 순천 데이터 수집을 시작합니다.
# 	지점 순천 데이터 수집이 완료되었습니다.
# 	지점 영광군 데이터 수집을 시작합니다.
# 	지점 영광군 데이터 수집이 완료되었습니다.
# 	지점 보성군 데이터 수집을 시작합니다.
# 	지점 보성군 데이터 수집이 완료되었습니다.
# 	지점 고흥 데이터 수집을 시작합니다.
# 	지점 고흥 데이터 수집이 완료되었습니다.
# 	지점 광양시 데이터 수집을 시작합니다.
# 	지점 광양시 데이터 수집이 완료되었습니다.
# 2016년도 광주지방기상청 데이터 수집이 완료되었습니다
# 2015년도 부산지방기상청 데이터 수집을 시작합니다.
# 	지점 부산 데이터 수집을 시작합니다.
# 	지점 부산 데이터 수집이 완료되었습니다.
# 	지점 통영 데이터 수집을 시작합니다.
# 	지점 통영 데이터 수집이 완료되었습니다.
# 	지점 김해시 데이터 수집을 시작합니다.
# 	지점 김해시 데이터 수집이 완료되었습니다.
# 	지점 거제 데이터 수집을 시작합니다.
# 	지점 거제 데이터 수집이 완료되었습니다.
# 	지점 남해 데이터 수집을 시작합니다.
# 	지점 남해 데이터 수집이 완료되었습니다.
# 2016년도 부산지방기상청 데이터 수집이 완료되었습니다
# 2015년도 목포기상대 데이터 수집을 시작합니다.
# 	지점 목포 데이터 수집을 시작합니다.
# 	지점 목포 데이터 수집이 완료되었습니다.
# 	지점 완도 데이터 수집을 시작합니다.
# 	지점 완도 데이터 수집이 완료되었습니다.
# 	지점 강진군 데이터 수집을 시작합니다.
# 	지점 강진군 데이터 수집이 완료되었습니다.
# 	지점 장흥 데이터 수집을 시작합니다.
# 	지점 장흥 데이터 수집이 완료되었습니다.
# 	지점 해남 데이터 수집을 시작합니다.
# 	지점 해남 데이터 수집이 완료되었습니다.
# 	지점 진도군 데이터 수집을 시작합니다.
# 	지점 진도군 데이터 수집이 완료되었습니다.
# 2016년도 목포기상대 데이터 수집이 완료되었습니다
# 2015년도 제주지방기상청 데이터 수집을 시작합니다.
# 	지점 제주 데이터 수집을 시작합니다.
# 	지점 제주 데이터 수집이 완료되었습니다.
# 	지점 고산 데이터 수집을 시작합니다.
# 	지점 고산 데이터 수집이 완료되었습니다.
# 	지점 성산 데이터 수집을 시작합니다.
# 	지점 성산 데이터 수집이 완료되었습니다.
# 	지점 서귀포 데이터 수집을 시작합니다.
# 	지점 서귀포 데이터 수집이 완료되었습니다.
# 2016년도 제주지방기상청 데이터 수집이 완료되었습니다
# 2015년도 인천기상대 데이터 수집을 시작합니다.
# 	지점 강화 데이터 수집을 시작합니다.
# 	지점 강화 데이터 수집이 완료되었습니다.
# 2016년도 인천기상대 데이터 수집이 완료되었습니다

# %% [markdown]
# ## 데이터 확인 후 더하기

# %% [markdown]
# 2015~2016년도(한 번에 구동하니까 28분 53초 소요)
# * 강원지방기상청
# (8052, 62)
# * 춘천기상대
# (1557, 62)
# * 수도권기상청
# (5856, 62)
# * 대구지방기상청
# (8051, 62)
# * 청주기상지청
# (3660, 62)
# * 홍성기상대
# (1159, 62)
# * 안동기상대
# (2928, 62)
# * 대전지방기상청
# (3660, 62)
# * 전주기상지청
# (7320, 62)
# * 울산기상대
# (3660, 62)
# * 창원기상대
# (4392, 62)
# * 광주지방기상청
# (5856, 62)
# * 부산지방기상청
# (3660, 62)
# * 목포기상대
# (4392, 62)
# * 제주지방기상청
# (2928, 62)
# * 인천기상대
# (732, 62)

# %% [markdown]
# 2019년도
#
# * 강원지방기상청
# (4026, 62)
# * 춘천기상대
# (1098, 62)
# * 수도권기상청
# (2928, 62)
# * 대구지방기상청
# (4026, 62)
# * 청주기상지청
# (1830, 62)
# * 홍성기상대
# (732, 62)
# * 안동기상대
# (1464, 62)
# * 대전지방기상청
# (2046, 62)
# * 전주기상지청
# (3660, 62)
# * 울산기상대
# (1830, 62)
# * 창원기상대
# (2196, 62)
# * 광주지방기상청
# (2928, 62)
# * 부산지방기상청
# (1830, 62)
# * 목포기상대
# (2196, 62)
# * 제주지방기상청
# (1464, 62)
# * 인천기상대
# (366, 62)

# %% [markdown]
# 2020년도(추가한 데이터)
# * 강원지방기상청
# (8063, 62)
# * 춘천기상대
# (2199, 62)
# * 수도권기상청
# (5864, 62)
# * 대구지방기상청
# (8063, 62)
# * 청주기상지청
# (3665, 62)
# * 홍성기상대
# (1466, 62)
# * 안동기상대
# (2932, 62)
# * 대전지방기상청
# (4248, 62)
# * 전주기상지청
# (7330, 62)
# * 울산기상대
# (3665, 62)
# * 창원기상대
# (4398, 62)
# * 광주지방기상청
# (5864, 62)
# * 부산지방기상청
# (3665, 62)
# * 목포기상대
# (4398, 62)
# * 제주지방기상청
# (2932, 62)
# * 인천기상대
# (733, 62)

# %%
for check in office:
  print(check)
  print(locals()[f'{check}_df'].shape)
# Out:
# 강원지방기상청
# (8052, 62)
# 춘천기상대
# (1557, 62)
# 수도권기상청
# (5856, 62)
# 대구지방기상청
# (8051, 62)
# 청주기상지청
# (3660, 62)
# 홍성기상대
# (1159, 62)
# 안동기상대
# (2928, 62)
# 대전지방기상청
# (3660, 62)
# 전주기상지청
# (7320, 62)
# 울산기상대
# (3660, 62)
# 창원기상대
# (4392, 62)
# 광주지방기상청
# (5856, 62)
# 부산지방기상청
# (3660, 62)
# 목포기상대
# (4392, 62)
# 제주지방기상청
# (2928, 62)
# 인천기상대
# (732, 62)

# %% [markdown]
# ### 영문 칼럼명 -> 국문 칼럼명

# %%
kcol = ["지점 번호", "지점명", "일시", "평균 기온(°C)", "최저 기온(°C)", "최저 기온 시각(hhmi)", "최고 기온(°C)", "최고 기온 시각(hhmi)", 
        "강수 계속시간(hr)", "10분 최다강수량(mm)", "10분 최다강수량 시각(hhmi)", "1시간 최다강수량(mm)", "1시간 최다강수량 시각(hhmi)", 
        "일강수량(mm)", "최대 순간풍속(m/s)", "최대 순간풍속 풍향(16방위)", "최대 순간풍속 시각(hhmi)", "최대 풍속(m/s)", "최대 풍속 풍향(16방위)", 
        "최대 풍속 시각(hhmi)", "평균 풍속(m/s)", "풍정합(100m)", "최다 풍향(16방위)", "평균 이슬점온도(°C)", "최소 상대습도(%)", 
        "평균 상대습도 시각(hhmi)", "평균 상대습도(%)", "평균 중기압(hPa)", "평균 현지기압(hPa)", "최고 해면 기압(hPa)", "최고 해면기압 시각(hhmi)", 
        "최저 해면기압(hPa)", "최저 해면기압 시각(hhmi)", "평균 해면기압(hPa)", "가조시간(hr)", "합계 일조 시간(hr)", "1시간 최다 일사 시각(hhmi)", 
        "1시간 최다 일사량(MJ/m2)", "합계 일사량(MJ/m2)", "일 최심신적설(cm)", "일 최심신적설 시각(hhmi)", "일 최심적설(cm)", "일 최심적설 시각(hhmi)", 
        "합계 3시간 신적설(cm)", "평균 전운량(10분위)", "평균 중하층운량(10분위)", "평균 지면온도(°C)", "최저 초상온도(°C)", "평균 5cm 지중온도(°C)", 
        "평균 10cm 지중온도(°C)", "평균 20cm 지중온도(°C)", "평균 30cm 지중온도(°C)", "0.5m 지중온도(°C)", "1.0cm 지중온도(°C)", "1.5cm 지중온도(°C)",
        "3.0cm 지중온도(°C)", "5.0cm 지중온도(°C)", "합계 대형증발량(mm)", "합계 소형증발량(mm)", "9-9강수(mm)", "일기현상", "안개 계속 시간(hr)"] 
        #docx를 참고해서 작성한 한글 칼럼명
len(kcol)
# Out:
# 62

# %%
for chk in office:
  ocol = [col for col in locals()[f'{chk}_df'].columns]
  ncol = {}

  for o, k in zip(ocol, kcol):
    ncol[o]=k
  
  locals()[f'{chk}_df'].rename(columns=ncol, inplace=True)
  locals()[f'{chk}_df'].reset_index(drop=True, inplace=True)

# %% [markdown]
# * 풍향(지상-풍향별 코드번호)
#
# "00":"CALM"
# "99":"변화가 많음"
# "20":"NNE"
# "50":"NE"
# "70":"ENE"
# "90":"E"
# "110":"ESE"
# "140":"SE"
# "160":"SSE"
# "180":"S"
# "200":"SSW"
# "230":"SW"
# "250":"WSW"
# "270":"W"
# "290":"WNW"
# "320":"NW"
# "340":"NNW"
# "360":"N"

# %% [markdown]
# ### 지점코드 오타로 데이터가 추가되지 않은 경우는 없는지 확인

# %%
for chk in office:
  # print(locals()[f'{chk}_df'].head())
  print(locals()[f'{chk}_NoData'])
# Out:
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []

# %% [markdown]
# ### 드라이브에 저장

# %%
# %cd "{SV}"
# Out:
# /content/drive/MyDrive/Proj_WT/DataSets/기상청_일별_지상_종관_ASOS

# %%
# !ls
# Out:
# 데이터			      목포기상대_2019_2020.csv
# 목포기상대_2015_2016.csv      춘천기상대_2019_2020.csv
# 춘천기상대_2015_2016.csv      홍성기상대_2019_2020.csv
# 홍성기상대_2015_2016.csv      안동기상대_2019_2020.csv
# 안동기상대_2015_2016.csv      울산기상대_2019_2020.csv
# 울산기상대_2015_2016.csv      창원기상대_2019_2020.csv
# 창원기상대_2015_2016.csv      인천기상대_2019_2020.csv
# 인천기상대_2015_2016.csv      수도권기상청_2019_2020.csv
# 수도권기상청_2015_2016.csv    청주기상지청_2019_2020.csv
# 청주기상지청_2015_2016.csv    전주기상지청_2019_2020.csv
# 전주기상지청_2015_2016.csv    대구지방기상청_2019_2020.csv
# 대구지방기상청_2015_2016.csv  제주지방기상청_2019_2020.csv
# 제주지방기상청_2015_2016.csv  대전지방기상청_2019_2020.csv
# 대전지방기상청_2015_2016.csv  광주지방기상청_2019_2020.csv
# 광주지방기상청_2015_2016.csv  부산지방기상청_2019_2020.csv
# 부산지방기상청_2015_2016.csv  강원지방기상청_2019_2020.csv
# 강원지방기상청_2015_2016.csv  branch.xlsx

# %%
# 조회 년도에 따라 csv파일 드라이브에 저장
for name in office:
  try : 
    locals()[f'{name}_df'].to_csv(f'{SV}/{name}_2015_2016.csv', index=False)
  except:
    pass

# %% [markdown]
# * Q) 월별로 csv를 생성하는 게 나은지, 년별로 csv를 생성하는 게 나은지?
#
# 일단 어차피 불러와야 할 csv라면 년별로 csv를 생성하는 게 분석 시에 편할 것 같은데...우선 코드부터 다 작성 후에 데이터 크기보고 결정

# %% [markdown]
# # copy files__카피한 뒤 사용하는 경우

# %%
# %cd "{DATA_PATH}"
# !ls
# Out:
# [Errno 2] No such file or directory: '/content/drive/MyDrive/Proj_WT/DataSets'
# /content
# drive  sample_data

# %%
api = "_api.ipynb"
origin = "TourStnInfoService"+api
copy = "AsosDalyInfoService"+api
chk = "ㅓㅕ"
http://smarttour.junggu.seoul.kr//junggu/openapi/culture.do
# !cp "{copy}" "{chk}"
