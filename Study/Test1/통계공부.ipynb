# %% [markdown]
# #통계공부
#
#
# - 2021년 7월 9일

# %% [markdown]
# 귀무가설
# --
#
# 기존에 존재하던 가설, 차이가 없거나 영향도 없음, 분석가의 주장과 반대 가설

# %% [markdown]
# 대립가설
# --
#
# 분석가가 새롭게 제시한 가설, 차이가 있거나 영향도 있음. 분석가가 채택하고 싶은 가설

# %% [markdown]
# p-value < 0.05는 귀무가설 기각 (통상적으로 p-value < 0.05 -> 대립가설 채택)
#
#
# 예시)
#
# 귀무가설: 데이터 셋이 정귝분포를 따른다.
#
# 대립가설: 데이터 셋이 정규분포를 따르지 않는다.

# %% [markdown]
# p-value
# --
#
# 귀무가설이 참이라고 했을 때, 표본데이터가 수집될 확률
#
# P-value가 낮을 수록, 대립가설 채택
#
# 통상적으로 p-value < 0.05면 대립가설 채택
#
# 이때, 0.05를 유의 수준이라고 하며, 대게 0.05 또는 0.01 중 선택

# %% [markdown]
# F통계량
# --
#
# F통계량 = 집단 간 오차/(집단 개수 - 1)  / 집단 내 오차/(전체데이터수 - 집단 갯수)

# %% [markdown]
# 카이제곱 통계량
# --
#
# (관측값 - 기대값)^2 / 기대값

# %% [markdown]
# 통계적 검정
# --
#
# 표본집단의 통계량을 기반으로 모집단에 대한 가설의 진위여부를 판단하는 것으로 통계적 가설 검정이라고 함.
#
# - 귀무가설 H0: 대립가설의 반대 가설
#
# - 대립가설 H1: 검증하고자 하는 가설

# %% [markdown]
# 단측 검정 (좌측 검정)
#
# H1: u < u0 (u는 평균)
#
# H1: u > u0 (우측 검정)
#
# 양측 검정
#
# H1: u != u0 (양측검정)

# %% [markdown]
# 통계적 검정
# --
#
# 검정 통계량의 값을 기준으로 귀무가설을 채택 or 기가함으로써 대립가설을 검증함.
#
# 검정 통계량: 귀무가설 하에서 표본집단의 통계량을 기반으로 계산하는 값
#
# 기각역: 유의 수준 a(알파)에서 귀무가설을 기각하는 통계량의 영역
#
# 꼬리부분을 기각역(a)락고 하고, 꼬리부분 나머지를 채택역(1-a)라고 한다.
#
# 통계량 값이 채택역에 있으면, 귀무가설(H0)을 채택하고, 대립가설(H1)을 기각한다.
#
# 통계량 값이 기각역에 있으면, 귀무가설(H0)를 기각하고, 대립가설(H1)을 채택한다.

# %% [markdown]
# MLE (Maximum Likelihood Estimation)
# --

# %% [markdown]
# MLE는 모수(parameter)가 미지의 세타인 확률분포에서 뽑은 표본 x를 바탕으로 표본의 likelihood를 최대화 하는 방법을 통해 세타를 추정하는 기법

# %% [markdown]
# Likelihood
# --

# %% [markdown]
# 이미 주어진 표본적 증거에 비추어 보았을 때, 모집단에 관해 어떠한 통계적 추정이 그럴듯한 정도

# %% [markdown]
# 확률 분포 함수 vs 가능도/우도 함수
# --

# %% [markdown]
# ![fk.PNG](data:image/png;base64,...)

# %% [markdown]
# 위 함수가 있을 때, u(평균)가 0, 시그마^2(분산)이 1인 정규분포를 따르는
# 확률변수 x의 함수

# %% [markdown]
# 확률 분포 함수 vs 가능도 / 우도 함수
# --

# %% [markdown]
# < 가능도/우도 함수>
#
# 미지의 u와 시그마^2의 정규분포를 따르는 표본 x1=1, x2=2, x3=3 에 대한 모수 u의 함수

# %% [markdown]
# Maximum Likelihood Estimation
# --

# %% [markdown]
# < MLE를 활용한 모수 추정>
#
# 미지의 u와 시그마제곱=1의 정규분포를 따르는 표본 x1=1, x2=2, x3=3을 기반으로 모수 u를 추정함.
#
# Likelihood와 log likelihood를 최대화하는 u가 동일하므로, 계산이 용이한 log likelihood로 변환하여 MLE를 진행함.
#
# < MLE를 활용한 모수 추정 >
#
# Log likelihood의 극대점 == 미분 값이 0인 지점

# %% [markdown]
# R^2 (결정계수)
# --
#
# 출처:  https://neocarus.tistory.com/entry/%EC%84%A0%ED%98%95%ED%9A%8C%EA%B7%80%EC%9D%98-%EC%A0%81%ED%95%A9%EC%84%B1-%ED%8F%89%EA%B0%80%EB%B0%A9%EB%B2%95

# %% [markdown]
# R^2 = 1- SSE/SST = SSR/SST
#
# 선형회귀 예측 y_hat이 y_bar 대비 얼마나 실제값 y를 잘 설명하는지를 의미함.
#
# R^2이 1에 가까울 수록 선형회귀 모형의 설명력이 높다는 것을 뜻함. (0~1의 범위를 가짐)

# %% [markdown]
# ![321123.PNG](data:image/png;base64,...)

# %% [markdown]
# SST는 total sum of squares 약자로 regerence인 y_bar 대비 출력 변수 Y의 총 변동을 의미
#
# SSR은 regression sum of squares의 약자로 SST 중에서 예측 y_hat이 y를 설명 못하는 변동 부분을 의미
#
# SSE는 error sum of squares 약자로 SST 중에서 예측 y_hat이 y를 설명 못하는 변동 부분을 의미

# %% [markdown]
# adj.R^2 (모형에 사용된 입력 변수 수만큼 penalty를 주는 지표
# ---

# %% [markdown]
# ![987.PNG](data:image/png;base64,...)

# %% [markdown]
# - 기존 결정계수는 유의하지 않은 변수가 추가 되어도 항상 증가하는 문제가 존재하므로 이러한 문제점을 보완하기 위한 수정 결정계수를 통해 보다 정확하게 회귀 모형의 적합도를 평가함.
#
# - 변수의 개수에 대한 penalty를 추가해 유의하지 않은 변수가 추가 될 경우 결정계수가 증가하지 않도록 함. (분모에 p+1만믐을 빼주기 때문 n- (p+1))

# %% [markdown]
# 선형 회귀 모델의 기본 가정
# --

# %% [markdown]
# 회귀 분석에서는 잔차에 대한 아래 3가지 가정이 존재함.
#
# 잔차분석을 통해 적합된 회귀 모델이 해당 가정을 잘 만족하는지 확인함.

# %% [markdown]
# 정규성: 잔차의 분포가 평균이 0인 정규분포를 따름
#
# 독립성: 잔차는 서로 독립적임
#
# 등분산성: 잔차의 분산이 동일함

# %% [markdown]
# 선형 회귀 분석의 진단
# --

# %% [markdown]
# 일반적으로 잔차 plot, Q-Q plot, residual vs fitted plot를 이용하여 잔차의 가정을 진단하며, 기본 가정이 위배된 경우 변수 변환을 통해 문제를 완화함

# %% [markdown]
# 다중공선성
# --

# %% [markdown]
# 다중공선성은 일부 설명 변수가 다른 설명 변수와 상관관계 정도가 높아 회귀 분석시 부정적인 영향을 미치는 현상
#
# 독립변수 사이의 강한 상관관계 때문에 독립변수가 종속변수를 설명하는 변동성이 겹쳐서 다중공선성이 발생함
#
# y를 설명하는 x1의 변동성과
#
# y를 설명하는 x2의 변동성과
#
# y를 설명하는 x3의 변동성이 겹치면서
#
# 잘못된 변수 해석으로 인해 예측 정확도가 하락한다.

# %% [markdown]
# 다중공선성 진단
# --
#
# 방법 1: Variance Inflation Factor(VIF)
#
# VIF는 다른 변수의 선형 결합을 통해 특정 설명 변수를 설명할 수 있는 정도를 나타냄.
#
# step1. xi를 종속변수, 나머지 변수들을 독립변수로 하여 회귀 모형을 적합
#
# step2. 회귀 모형의 결정계수 R^2를 기반으로 VIF 산출
#
# VIF = 1 / (1-R^2)
#
# 일반적으로 VIF가 10이상인 경우 다중공선성이 있는 변수라고 판단함.

# %% [markdown]
# 성능 평가 지표
# --

# %% [markdown]
# 1. Average Error: 실제 값에 대한 예측 값의 과대/과소 추정 정도
#
# 2. Mean Absolute Error ( MAE): 실제 값과 예측 값 사이의 절대적인 오차의 평균
#
# 3. Mean Absolute Percetage Error (MAPE): 실제 값 대비 실제 값과 예측 값 사이의 절대적인 오차의 평균. 상대적인 오차를 추정하기 위해 주로 사용됨.
#
# 4. Mean Squared Error (MSE): 실제 값과 예측 값 사이의 오차 제곱의 평균
#
# 5. Root Mean Squared Error (RMSE): MSE에 root를 취한 값

# %% [markdown]
# 변수 선택법
# --

# %% [markdown]
# 1. 전진 선택법
#
# 설명 변수가 하나도 없는 모델에서부터 시작하여 가장 유의미한 변수를 하나씩 추가해 나가면서 최적의 변수 조합을 찾는 방법
#
# [종료 시점] 어떠한 변수를 추가해도 변수 선택 지표의 향상이 없는 시점
#
# 2. 후진 소거법
#
# 모든 설명 변수를 사용하여 구축한 모델에서부터 시작하여 가장 유의미하지 않은 변수를 하나씩 제거해 나가면서 최적의 변수 조합을 찾는 방법
#
# [종료 시점] 어떠한 변수를 제거해도 변수 선택 지표의 향상이 없는 시점
#
# 3. 단계적 선택법
#
# 설명 변수가 하나도 없는 모델에서부터 시작하여 전진 선택법과 후진 소거법을 번갈아가며 수행하면서 최적의 변수 조합을 찾는 방법

# %% [markdown]
# 변수 선택 평가 지표
# --

# %% [markdown]
# 1. Akaike Information Criteria(AIC): AIC = n ln (SSE/n) + 2p
#
# 2. Bayesian Information Criteria(BIC): BIC = n ln (SSE/n) + 2(p+2)n시그마^2 / SSE - 2n^2시그마^4/SSE^2
#
# 3. 수정 결정계수: R^2 adj = 1 - [n-1/n-(p+1)] SSE/SST

# %% [markdown]
# 여러가지 평가 개념
# --

# %% [markdown]
# 정확도(Accuracy) = TP+TN/(TP+FP+FN+TN)
#
# 에러율(Error rate) = FP + FN / (TP+FP+FN+TN)
#
# 민감도(Sensitivity Recall) = TP / TP + FN
#
# False Positive Rate; FP / FP + TN
#
# 정밀도(Precision) = TP / TP + FP
#
# 예측이 True인데, 실제도 True = TP
#
# 예측이 True인데, 실제가 False = FP
#
# 예측이 False인데, 실제가 True = FN
#
# 예측이 False이고, 실제가 False = TN

# %% [markdown]
# 표준화 및 MinMax 스케일
# --

# %% [markdown]
# 표준화 = 원 데이터 - 평균 / 표준편차
#
# (평균 0, 표준편차 1)
#
# MinMax 스케일 = 원 데이터 - min(데이터) / max(데이터) - min(데이터)
#
# (0과 1사이로 데이터 위치)

# %% [markdown]
# ROC 커브 (Receiver Operating Characteristic,  수신자 조작특성)
#
# x축(0-1범위): FPR
#
# y축(0-1범위): 민감도(Sensitivity, Recall)
#
# AUC = Area Under ROC curve
#
# ROC 곡선 아래의 면적(AUC)이 넓을 수록 좋은 모델
#
# (1에 가까울 수록 좋음)
