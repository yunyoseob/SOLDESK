# %% [markdown]
# # SQL_Tutorials
#
# LINK $\Rightarrow$ [SQL_Tutorials](https://www.kaggle.com/learn/intro-to-sql)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Lessons 1 : Getting Started With SQL and BigQuery
#
# Link $\Rightarrow$  [Getting Started With SQL and BigQuery](https://www.kaggle.com/dansbecker/getting-started-with-sql-and-bigquery)

# %%
from google.cloud import bigquery

# %%
# Create a "Client" object
client=bigquery.Client()
# Out:
# ---------------------------------------------------------------------------
# DefaultCredentialsError                   Traceback (most recent call last)
# <ipython-input-4-90c830694957> in <module>()
#       1 # Create a "Client" object
# ----> 2 client=bigquery.Client()
#
# /usr/local/lib/python3.7/dist-packages/google/cloud/bigquery/client.py in __init__(self, project, credentials, _http, location, default_query_job_config, client_info, client_options)
#     174     ):
#     175         super(Client, self).__init__(
# --> 176             project=project, credentials=credentials, _http=_http
#     177         )
#     178
#
# /usr/local/lib/python3.7/dist-packages/google/cloud/client.py in __init__(self, project, credentials, _http)
#     224
#     225     def __init__(self, project=None, credentials=None, _http=None):
# --> 226         _ClientProjectMixin.__init__(self, project=project)
#     227         Client.__init__(self, credentials=credentials, _http=_http)
#
# ...
