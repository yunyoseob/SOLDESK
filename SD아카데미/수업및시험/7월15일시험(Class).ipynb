# %% [markdown]
# 클래스 시험
# --

# %% [markdown]
# 1번 문제
# --

# %% [markdown]
# (하)class로 작성하시오.
#
# 주사위 클래스 Dice를 설계하는데 메소드에는 roll()을 구현하여 주사위를 던져 나온 숫자를 화면에 출력하는 프로그램을 작성하시오. -단, 난수의 발생은 다음을 이용하라.
#
# - face = random.randint(1, 6)

# %%
import numpy as np

class dice:
    def set_number(throw):
        self.throw=throw
    def roll(throw):
        print("주사위를 던져서 나온 결과")
        face=np.random.randint(1,6)
        return face

# %%
dice.roll("thorw")
# Out:
# 주사위를 던져서 나온 결과
# 3

# %% [markdown]
# 2번 문제
# --

# %% [markdown]
# (상) 배스킨라빈스 31게임.
#
# 게의 참여자들은 차례를 정해 1부터 31까지의 수를 순차적으로 부른다. 한번에 1~3개까지 수를 연달아 부를 수 있으며, 마지막 31을 부른 사람이 진다.

# %%
class baskinrobbins_31:
    def start():
        print("게임을 시작하고 싶다면 시작을 입력하세요.")
        print("게임 규칙: 31을 부르면 집니다. 최대 3개의 숫자까지 반드시 1,2,3 이렇게 작성해주시기 바랍니다.")
        print("그렇지 않으면 게임이 종료됩니다.")
        print("*경고* 컴퓨터: 만약 규칙을 안 지키시면 저는 에러를 뿜을 것 입니다.")
        start=input()
        start="컴퓨터 먼저 시작합니다. 컴퓨터:"
        start_1=1
        start_2=2
        return start,start_1,start_2

    def game_result(x):
        x=x
        if x==1:
            result="computer 승"
        elif x==0:
            result="person 승"
        else:
            result="규칙을 지키지 않았습니다. 게임을 종료합니다."
        return result

# %%
k=[1,2,3]
k[-1]
# Out:
# 3

# %% [markdown]
# 배스킨라빈스 31: 사람이 먼저 하는 버전

# %%
class baskinrobbins_31:
    def start():
        print("게임을 시작하고 싶다면 시작을 입력하세요.")
        print("게임 규칙: 31을 부르면 집니다. 최대 3개의 숫자까지 부를 수 있습니다. ex: 1,2,3")
        print("*경고* 컴퓨터: 만약 규칙을 안 지키시면 저는 에러를 뿜을 것 입니다.")
        start=input()
        start="컴퓨터 먼저 시작합니다. 컴퓨터:"
        return start
    
    def game_start():
        start_game=baskinrobbins_31.start()

        for i in range(a,32,4):
            print("귀엽고 깜찍하게 써리원~ 숫자를 최대 3개까지 입력하세요.")
            Number=input()
            print("당신이 입력한 숫자: ", Number)
            Num1=list(Number)
            Num2=Num1[-2:]
            if len(Num2)==1:
                Num3=str(Num2[0])
                Num4=int(Num3)
                computer=list(range(Num4+1,i+1))
                for j in computer:
                    print("컴퓨터가 입력한 숫자: ", j)
                
            else:
                Num3=str(Num2[0]+Num2[1])
                Num4=Num3.replace(",",'')
                Num5=int(Num4)
                computer=list(range(Num5+1,i+1))
                for j in computer:
                    print("컴퓨터가 입력한 숫자: ", j)
               
        winner="컴퓨터 승리, 설마 절 이길 수 있을 것이라고 생각했습니까? 휴먼?"
        return winner

# %%
Number=input()
print("당신이 입력한 숫자: ", Number)
Num1=list(Number)
Num2=Num1[-2:]
if len(Num2)==1:
    Num3=str(Num2[0])
    Num4=int(Num3)
    if Num4!=5:
        computer=list(range(Num4+1,7))
        for j in computer:
            print("컴퓨터가 입력한 숫자: ", j)
    else:
        print("컴퓨터가 입력한 숫자", Num4+1)
# Out:
# 5,6,7
# 당신이 입력한 숫자:  5,6,7

# %%
n=8
4*n-2
# Out:
# 30

# %%
Number=input()
print("당신이 입력한 숫자: ", Number)
Num1=list(Number)
Num2=Num1[-2:]
if len(Num2)==1:
    Num3=str(Num2[0])
    Num4=int(Num3)

print(Num4)
# Out:
# 5,6
# 당신이 입력한 숫자:  5,6
# 5

# %%
def game_start():
    start_game=baskinrobbins_31.start()
    print(start_game)
    
    try:
        for i in range(6,32):
            k=[1,2]
            k1=k[-1]
            print("귀엽고 깜찍하게 써리원~ 숫자를 최대 3개까지 입력하세요.")
            Number=input()
            print("당신이 입력한 숫자: ", Number)
            Num1=list(Number)
            Num2=Num1[:2]
            Num3=Num1[-2:]
            if len(Num2)==1:
                if len(NUm3)==1:
                    Num4=str(Num3[0])
                    Num5=int(Num4)
                if Num4>k1:
                    computer=list(range(Num4+1,i+1))
                    for j in computer:
                        k.append(j)
                        print("컴퓨터가 입력한 숫자: ", j)
                        x=1
                        i+=4   
                else:
                    x=2
                    i+=4000000000000        
            else:
                Num3=str(Num2[0]+Num2[1])
                Num4=Num3.replace(",",'')
                Num5=int(Num4)
                computer=list(range(Num5+1,i+1))
                for j in computer:
                    k.append(j)
                    print("컴퓨터가 입력한 숫자: ", j)
                    x=1
                    i+=4  

        result=baskinrobbins_31.game_result(x)
    except:
        x=2
        result=baskinrobbins_31.game_result(x)
        
    return result

# %%
Number=input()
print("당신이 입력한 숫자: ", Number)
Num1=list(Number)
Num2=Num1[-2:]
# Out:
# 6,7,8
# 당신이 입력한 숫자:  6,7,8

# %%
Num1
# Out:
# ['6', ',', '7', ',', '8']

# %%
Num1[:2]
# Out:
# ['6', ',']

# %%
Num2[-2:]
# Out:
# [',', '8']

# %%
game_start()
# Out:
# 게임을 시작하고 싶다면 시작을 입력하세요.
# 게임 규칙: 31을 부르면 집니다. 최대 3개의 숫자까지 반드시 1,2,3 이렇게 작성해주시기 바랍니다.
# 그렇지 않으면 게임이 종료됩니다.
# *경고* 컴퓨터: 만약 규칙을 안 지키시면 저는 에러를 뿜을 것 입니다.
# 시작
# ('컴퓨터 먼저 시작합니다. 컴퓨터:', 1, 2)
# 귀엽고 깜찍하게 써리원~ 숫자를 최대 3개까지 입력하세요.
# 3,4
# 당신이 입력한 숫자:  3,4
# 컴퓨터가 입력한 숫자:  5
# 컴퓨터가 입력한 숫자:  6
# 귀엽고 깜찍하게 써리원~ 숫자를 최대 3개까지 입력하세요.
# 7,8,9
# 당신이 입력한 숫자:  7,8,9
# 귀엽고 깜찍하게 써리원~ 숫자를 최대 3개까지 입력하세요.
# '규칙을 지키지 않았습니다. 게임을 종료합니다.'

# %%
Num2[-1]
# Out:
# '4'

# %%
game_start()
# Out:
# 게임을 시작하고 싶다면 시작을 입력하세요.
# 게임 규칙: 31을 부르면 집니다. 최대 3개의 숫자까지 반드시 1,2,3 이렇게 작성해주시기 바랍니다.
# 그렇지 않으면 게임이 종료됩니다.
# *경고* 컴퓨터: 만약 규칙을 안 지키시면 저는 에러를 뿜을 것 입니다.
# 시작
# ('컴퓨터 먼저 시작합니다. 컴퓨터:', 1, 2)
# 귀엽고 깜찍하게 써리원~ 숫자를 최대 3개까지 입력하세요.
# 3,4,5
# 당신이 입력한 숫자:  3,4,5
# '규칙을 지키지 않았습니다. 게임을 종료합니다.'

# %% [markdown]
# 3번 문제
# --

# %% [markdown]
# (중) 내용에 맞게 코드를 작성하시오. 괄호 문자열(Parenthesis String, PS)은 두 개의 괄호 기호인 ‘(’ 와 ‘)’ 만으로 구성되어 있는 문자열이다. 그 중에서 괄호의 모양이 바르게 구성된 문자열을 올바른 괄호 문자열(Valid PS, VPS)이라고 부른다. 한 쌍의 괄호 기호로 된 “( )” 문자열은 기본 VPS 이라고 부른다. 만일 x 가 VPS 라면 이것을 하나의 괄호에 넣은 새로운 문자열 “(x)”도 VPS 가 된다. 그리고 두 VPS x 와 y를 접합(concatenation)시킨 새로운 문자열 xy도 VPS 가 된다. 예를 들어 “(())()”와 “((()))” 는 VPS 이지만 “(()(”, “(())()))” , 그리고 “(()” 는 모두 VPS 가 아닌 문자열이다. 여러분은 입력으로 주어진 괄호 문자열이 VPS 인지 아닌지를 판단해서 그 결과를 YES 와 NO 로 나타내어야 한다.
#
# VPS 구분
#
# "()": VPS
#
# "(내용)": VPS
#
# "((a))(b)": VPS
#
# "(((a)))": VPS
#
# "(()(", "(())()))", "((): NOT VPS

# %%
class vps_test:
    def make_list(text):
        text=list(text)
        test=[ x for x in text if x=='(' or x==')']
        return test
    def vps_notvps(text):
        test=vps_test.make_list(text)
        len_test=len(test)%2

        if len_test==0:
            len2=len(test)/2
            len2=int(len2)
            for i in range(1,len2+1):
                if test[i]=='(':
                    if test[-i]==')':
                        print("yes")
                    else:
                        print("no")
                else:
                    print("no")
        else:
            len2==(len(test)/2)+0.5
            len2=int(len2)
            for i in range(1,len2+1):
                if test[i]=='(':
                    if test[-i]==')':
                        print("yes")
                    else:
                        print("no")
                else:
                    print("no")

# %%
vps_test.vps_notvps("((()())()()()()()()()()()()()()())()))))")

# %% [markdown]
# 4번 문제
# --

# %% [markdown]
# 사칙연산은 Class로 작성하시오. 주의) 내장함수를 사용하면 copy(0점)로 간주.
#
# - 생성자도 호출하시오.

# %%
class fourchickyeonmountain:
    def setdata(self, a, b):
        self.a=a
        self.b=b
    def add(self):
        add=self.a+self.b
        return add
    def minus(self):
        minus=self.a-self.b
        return minus
    def multiply(self):
        multiply=self.a*self.b
        return multiply
    def division(self):
        division=self.a/self.b
        return division

# %%
생성자=fourchickyeonmountain()

# %%
생성자.setdata(3,4)

# %%
생성자.add()
# Out:
# 7

# %%
생성자.minus()
# Out:
# -1

# %%
생성자.multiply()
# Out:
# 12

# %%
생성자.division()
# Out:
# 0.75

# %% [markdown]
# 5번 문제
# --

# %% [markdown]
# [중] 업다운 게임을 작성하시오
#
# - 소주 병뚜껑에서 1-50까지의 숫자를 말하면 Up또는 Down을 알려주는 코드를 작성하시오.
#
# - 5번안에 맞추지 않으면 Game over도 출력하시오.

# %%
i=0

while i <= 5:
    Num=input()
    Num=int(Num)
    Val_Num=25

    if 50>=Num>=1:
        if Val_Num==Num:
            print("정답입니다. 벌칙주를 드세요.")
            i+=10000000000000000
        elif i==4:
            print("Game over")
            i+=100000000000000000
        elif Val_Num<Num:
            print("Down")
            i+=1
        elif Val_Num>Num:
            print("Up")
            i+=1
        else:
            print("값 똑바로 넣으세요. 게임을 종료합니다.")
            i+=1
    else:
        print("값 똑바로 넣으세요. 게임을 종료합니다.")
        i+=1000000000000000000
# Out:
# 1
# Up
# 49
# Down
# 8
# Up
# 32
# Down
# 21
# Game over
