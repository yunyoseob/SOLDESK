# %% [markdown]
# # 드라이브 연동

# %%
import os

from google.colab import drive  
ROOT = "/content/drive" #구글 드라이브 연동
drive.mount(ROOT)

from os.path import join  
CO_WORK = "MyDrive/Proj_WT" 
CW_PATH = join(ROOT, CO_WORK) #공유 폴더로 접근 경로

# CODES = "Codes" #코드/마크다운 공유 및 에러 해결 목적
# CODE_PATH = join(CW_PATH, CODES)
# # !mkdir "{CODE_PATH}"

PAPERS = "Papers" #논문 공유 폴더
PAPER_PATH = join(CW_PATH, PAPERS)
# !mkdir "{PAPER_PATH}"

DATAS = "DataSets"  #데이터 공유 폴더
DATA_PATH = join(CW_PATH, DATAS)
# !mkdir "{DATA_PATH}"

# %cd "{DATA_PATH}"
# !ls
# Out:
# Mounted at /content/drive
# /content/drive/.shortcut-targets-by-id/1TVtWvZ4DNn7V20Aj6JzSd5_iRdbjEXbG/Proj_WT/DataSets
#  기상청_관광코스별_관광지_상세날씨
#  한국관광공사_관광빅데이터
# '서울시 코로나19 확진자 현황.csv'
# '서울 주요관광지점 입장객 2011 2019.xls'
#  2017년부터2021년까지서울기후데이터.csv
#  api활용_참고_문서
#  기상청_일별_지상_종관_ASOS
#  기상청_일별_지상종관_ASOS_api.ipynb
#  check.ipynb
#  Codes
#  DataLabService_api.ipynb
#  JungguSmartDB_api.ipynb
#  openapi_baseline.ipynb
#  TourismResourceStatsService_api.ipynb
#  TourStnInfoService_api.ipynb

# %%
SV = join(DATA_PATH, "기상청_관광코스별_관광지_상세날씨")
# !mkdir "{SV}"
# %cd "{SV}"
# !ls
# Out:
# /content/drive/.shortcut-targets-by-id/1TVtWvZ4DNn7V20Aj6JzSd5_iRdbjEXbG/Proj_WT/DataSets/기상청_관광코스별_관광지_상세날씨
# 시군구별관광기후지수_2017.csv  시군구별관광기후지수_2020.csv
# 시군구별관광기후지수_2018.csv  시군구별관광기후지수_2021.csv
# 시군구별관광기후지수_2019.csv  시군구별관광기후지수.csv

# %% [markdown]
# # 현재 진행 상황 확인용

# %%
# %cd "{CW_PATH}"
# !ls
# Out:
# /content/drive/.shortcut-targets-by-id/1TVtWvZ4DNn7V20Aj6JzSd5_iRdbjEXbG/Proj_WT
#  Analysis  '공유폴더 내 데이터 활용해서 모델 분석할 때 편한 방법.ipynb'
#  DataSets   Papers

# %%
# %cd "{CODE_PATH}"
# !ls
# Out:
# [Errno 2] No such file or directory: '{CODE_PATH}'
# /content/drive/.shortcut-targets-by-id/1TVtWvZ4DNn7V20Aj6JzSd5_iRdbjEXbG/Proj_WT
#  Analysis  '공유폴더 내 데이터 활용해서 모델 분석할 때 편한 방법.ipynb'
#  DataSets   Papers

# %%
# %cd "{PAPER_PATH}"
# !ls
# Out:
# /content/drive/.shortcut-targets-by-id/1TVtWvZ4DNn7V20Aj6JzSd5_iRdbjEXbG/Proj_WT/Papers
# '해외방문관광객의 목적지 선택에 대한 기후의 영향 (1).pdf'
# '빅데이터 기반 관광지 추천 시스템 구현.hwp'
#  논문_리뷰.ipynb
# '한국형 관광기후지수(KTCI)의 개발에 관한 연구.gdoc'
# '한국형 관광기후지수(KTCI)의 개발에 관한 연구.pdf'
#  빅데이터기반관광지추천시스템구현한국관광공사LOD를중심으로.pdf
#  관광업체관광지추천유형정리.pptx
# '날씨 및 요일 특성이 관광정보시스템 이용에 미치는 영향에 관한 연구.rtf'
# '기후인자가 관광수요에 미치는 영향 패널데이터 모형의 적용.rtf'
# 'Weather Go ( 웨더고) 초기 회의록(20210621).hwp'
# 'Weather Go (웨더고) 두번째 회의록.pptx'

# %%
# %cd "{DATA_PATH}"
# !ls
# Out:
# /content/drive/.shortcut-targets-by-id/1TVtWvZ4DNn7V20Aj6JzSd5_iRdbjEXbG/Proj_WT/DataSets
#  기상청_관광코스별_관광지_상세날씨
#  한국관광공사_관광빅데이터
# '서울시 코로나19 확진자 현황.csv'
# '서울 주요관광지점 입장객 2011 2019.xls'
#  2017년부터2021년까지서울기후데이터.csv
#  api활용_참고_문서
#  기상청_일별_지상_종관_ASOS
#  기상청_일별_지상종관_ASOS_api.ipynb
#  check.ipynb
#  Codes
#  DataLabService_api.ipynb
#  JungguSmartDB_api.ipynb
#  openapi_baseline.ipynb
#  TourismResourceStatsService_api.ipynb
#  TourStnInfoService_api.ipynb

# %%
# !mv locgoRegnVisitrDDList_api.ipynb TourStnInfoService_api.ipynb
# !cp TourStnInfoService_api.ipynb

# %%
# 참고문서 업로드
# %cd "{DATA_PATH}"
# from google.colab import files
# files.upload()
# !ls
# 참고문서 다운로드
# files.download("f{}_api.ipynb")
# Out:
# /content/drive/.shortcut-targets-by-id/1TVtWvZ4DNn7V20Aj6JzSd5_iRdbjEXbG/Proj_WT/DataSets
#  기상청_관광코스별_관광지_상세날씨
#  한국관광공사_관광빅데이터
# '서울시 코로나19 확진자 현황.csv'
# '서울 주요관광지점 입장객 2011 2019.xls'
#  2017년부터2021년까지서울기후데이터.csv
#  api활용_참고_문서
#  기상청_일별_지상_종관_ASOS
#  기상청_일별_지상종관_ASOS_api.ipynb
#  check.ipynb
#  Codes
#  DataLabService_api.ipynb
#  JungguSmartDB_api.ipynb
#  openapi_baseline.ipynb
#  TourismResourceStatsService_api.ipynb
#  TourStnInfoService_api.ipynb

# %%
# !pip install python-docx

# %%
# import docx
# file_name = "기상청27_관광코스별_관광지_상세_날씨_조회서비스_오픈API활용가이드.docx"
# FN = join(DATA_PATH, file_name)

# doc = docx.Document(FN)

# %% [markdown]
# docx 파일을 보면서 파라미터 수정하는 데에 활용
#
# 자세한 방법은 우선 데이터부터 모으고 나중에 생각하겠습니다~

# %% [markdown]
# # xml to json 관련 라이브러리

# %%
# !pip install xmltodict

# %%
import sys
import re
import time
from datetime import datetime, timedelta

import math
import ast
from ast import literal_eval

import csv
import numpy as np
import pandas as pd

import json
import requests
import xmltodict
import urllib
import urllib.request
import xml.dom.minidom
from xml.etree.ElementTree import parse
from urllib.request import urlopen
from urllib.parse import urlencode, unquote, quote_plus

# %%
# %cd "{SV}"
# !ls
# Out:
# /content/drive/.shortcut-targets-by-id/1TVtWvZ4DNn7V20Aj6JzSd5_iRdbjEXbG/Proj_WT/DataSets/기상청_관광코스별_관광지_상세날씨
# 시군구별관광기후지수_2017.csv  시군구별관광기후지수_2020.csv
# 시군구별관광기후지수_2018.csv  시군구별관광기후지수_2021.csv
# 시군구별관광기후지수_2019.csv  시군구별관광기후지수.csv

# %% [markdown]
# # 기상청_관광코스별 관광지 상세 날씨 조회서비스(시군구별 관광기후지수조회)

# %% [markdown]
# 2017~2020 데이터 수집 완료
# 2021년 6월 20일까지 데이터 업데이트 완료

# %% [markdown]
# ## 기본 파라미터

# %%
SERVICE = "TourStnInfoService"
STYPE = ["getCityTourClmIdx", "getTourStnWthrIdx", "getTourStnVilageFcst"]
# KEY = ""  #서비스키
KEY = "yRxjHtUyF3aadfyII7o4rlbGO0QK4kY2Uf46AoDzfvoCgVT6wHHceyMx%2Be1DZvcYHLAl4h2ANO02EFyWxkd%2FHA%3D%3D" #서비스키
PG_NO = "1"
NoRows = "10"
Dtype = ["XML", "JSON"]

# %% [markdown]
# ### 2011~2020

# %%
# #2011
# stD = datetime(2011,1,1,hour=0, minute=0, second=0, microsecond=0)
# edD = datetime(2011,12,31,hour=23, minute=59, second=59, microsecond=0)
# CDate = stD.strftime('%Y%m%d%H')
# DAYs = (edD-stD).days

# dt11 = pd.read_csv(f'{SV}/시군구별관광기후지수_2011.csv')
# ct11 = dt11['시도'].unique()
# day11 = [d[:10] for d in dt11['예보시각'].unique()]

# print(f'11년도 진행 상황 : \n\t{ct11}\n\t{day11}')
# # for tm in dt11.iloc[:,0]:
# #   if tm[:4]!="2011":
# #     print(tm[:4])

# %% [markdown]
# 2011 데이터 없음

# %%
# #2012
# stD = datetime(2012,1,1,hour=0, minute=0, second=0, microsecond=0)
# edD = datetime(2012,12,31,hour=23, minute=59, second=59, microsecond=0)
# CDate = stD.strftime('%Y%m%d%H')
# DAYs = (edD-stD).days

# dt12 = pd.read_csv(f'{SV}/시군구별관광기후지수_2012.csv')
# ct12 = dt12['시도'].unique()
# day12 = [d[:10] for d in dt12['예보시각'].unique()]

# print(f'12년도 진행 상황 : \n\t{ct12}\n\t{day12}')
# # for tm in dt12.iloc[:,0]:
# #   if tm[:4]!="2012":
# #     print(tm[:4])

# %% [markdown]
# 2012 데이터 없음

# %%
#2013
stD = datetime(2013,1,1,hour=0, minute=0, second=0, microsecond=0)
edD = datetime(2013,12,31,hour=23, minute=59, second=59, microsecond=0)
CDate = stD.strftime('%Y%m%d%H')
DAYs = (edD-stD).days

# dt13 = pd.read_csv(f'{SV}/시군구별관광기후지수_2013.csv')
# ct13 = dt13['시도'].unique()
# day13 = [d[:10] for d in dt13['예보시각'].unique()]

# print(f'13년도 진행 상황 : \n\t{ct13}\n\t{day13}')
# # for tm in dt13.iloc[:,0]:
# #   if tm[:4]!="2013":
# #     print(tm[:4])

# %%
# #2014
# stD = datetime(2014,1,1,hour=0, minute=0, second=0, microsecond=0)
# edD = datetime(2014,12,31,hour=23, minute=59, second=59, microsecond=0)
# CDate = stD.strftime('%Y%m%d%H')
# DAYs = (edD-stD).days

# dt14 = pd.read_csv(f'{SV}/시군구별관광기후지수_2014.csv')
# ct14 = dt14['시도'].unique()
# day14 = [d[:10] for d in dt14['예보시각'].unique()]

# print(f'14년도 진행 상황 : \n\t{ct14}\n\t{day14}')
# # for tm in dt14.iloc[:,0]:
# #   if tm[:4]!="2014":
# #     print(tm[:4])

# %%
# #2015
# stD = datetime(2015,1,1,hour=0, minute=0, second=0, microsecond=0)
# edD = datetime(2015,12,31,hour=23, minute=59, second=59, microsecond=0)
# CDate = stD.strftime('%Y%m%d%H')
# DAYs = (edD-stD).days

# dt15 = pd.read_csv(f'{SV}/시군구별관광기후지수_2015.csv')
# ct15 = dt15['시도'].unique()
# day15 = [d[:10] for d in dt15['예보시각'].unique()]

# print(f'15년도 진행 상황 : \n\t{ct15}\n\t{day15}')
# # for tm in dt15.iloc[:,0]:
# #   if tm[:4]!="2015":
# #     print(tm[:4])

# %%
# #2016
# stD = datetime(2016,1,1,hour=0, minute=0, second=0, microsecond=0)
# edD = datetime(2016,12,31,hour=23, minute=59, second=59, microsecond=0)
# CDate = stD.strftime('%Y%m%d%H')
# DAYs = (edD-stD).days

# dt16 = pd.read_csv(f'{SV}/시군구별관광기후지수_2016.csv')
# ct16 = dt16['시도'].unique()
# day16 = [d[:10] for d in dt16['예보시각'].unique()]

# print(f'17년도 진행 상황 : \n\t{ct17}\n\t{day17}')
# # for tm in dt17.iloc[:,0]:
# #   if tm[:4]!="2017":
# #     print(tm[:4])

# %% [markdown]
# 2017부터는 되어 있음

# %%
# #2017
# stD = datetime(2017,1,1,hour=0, minute=0, second=0, microsecond=0)
# edD = datetime(2017,12,31,hour=23, minute=59, second=59, microsecond=0)
# CDate = stD.strftime('%Y%m%d%H')
# DAYs = (edD-stD).days

# dt17 = pd.read_csv(f'{SV}/시군구별관광기후지수_2017.csv')
# ct17 = dt17['시도'].unique()
# day17 = [d[:10] for d in dt17['예보시각'].unique()]

# print(f'17년도 진행 상황 : \n\t{ct17}\n\t{day17}')
# # for tm in dt17.iloc[:,0]:
# #   if tm[:4]!="2017":
# #     print(tm[:4])
# Out:
# 17년도 진행 상황 :
# 	['서울' '부산' '인천' '대구' '대전' '울산' '광주' '세종' '제주' '경기' '강원' '충북' '충남' '전북'
#  '전남' '경북' '경남']
# ...

# %%
# #2018
# stD = datetime(2018,1,1,hour=0, minute=0, second=0, microsecond=0)
# edD = datetime(2018,12,31,hour=23, minute=59, second=59, microsecond=0)
# CDate = stD.strftime('%Y%m%d%H')
# DAYs = (edD-stD).days

# dt18 = pd.read_csv(f'{SV}/시군구별관광기후지수_2018.csv')
# ct18 = dt18['시도'].unique()
# day18 = [d[:10] for d in dt18['예보시각'].unique()]

# print(f'18년도 진행 상황 : \n\t{ct18}\n\t{day18}')
# Out:
# 18년도 진행 상황 :
# 	['서울' '부산' '인천' '대구' '대전' '울산' '광주' '세종' '제주' '경기' '강원' '충북' '충남' '전북'
#  '전남' '경북' '경남']
# ...

# %%
# #2019
# stD = datetime(2019,1,1,hour=0, minute=0, second=0, microsecond=0)
# edD = datetime(2019,12,31,hour=23, minute=59, second=59, microsecond=0)
# CDate = stD.strftime('%Y%m%d%H')
# DAYs = (edD-stD).days

# dt19 = pd.read_csv(f'{SV}/시군구별관광기후지수_2019.csv')
# ct19 = dt19['시도'].unique()
# day19 = [d[:10] for d in dt19['예보시각'].unique()]

# print(f'19년도 진행 상황 : \n\t{ct19}\n\t{day19}')
# Out:
# 19년도 진행 상황 :
# 	['서울' '부산' '인천' '대구' '대전' '울산' '광주' '세종' '제주' '경기' '강원' '충북' '충남' '전북'
#  '전남' '경북' '경남']
# ...

# %%
# #2020
# stD = datetime(2020,1,1,hour=0, minute=0, second=0, microsecond=0)
# edD = datetime(2020,12,31,hour=23, minute=59, second=59, microsecond=0)
# CDate = stD.strftime('%Y%m%d%H')
# DAYs = (edD-stD).days

# dt20 = pd.read_csv(f'{SV}/시군구별관광기후지수_2020.csv')
# ct20 = dt20['시도'].unique()
# day20 = [d[:10] for d in dt20['예보시각'].unique()]

# print(f'20년도 진행 상황 : \n\t{ct20}\n\t{day20}')
# Out:
# 20년도 진행 상황 :
# 	['서울' '부산' '인천' '대구' '대전' '울산' '광주' '세종' '제주' '경기' '강원' '충북' '충남' '전북'
#  '전남' '경북' '경남']
# ...

# %% [markdown]
# ### 2021 실시간

# %%
#2021
now=datetime.now()
check = datetime(2021,1,1,hour=0, minute=0, second=0, microsecond=0)
CDate = check.strftime('%Y%m%d%H')
DAYs = (now-check).days  #3일 후

dt21 = pd.read_csv(f'{SV}/시군구별관광기후지수_2021.csv')
ct21 = dt21['시도'].unique()
day21 = [d[:10] for d in dt21['예보시각'].unique()]

print(f'21년도 진행 상황 : \n\t{ct21}\n\t{day21}')
# Out:
# 21년도 진행 상황 :
# 	['서울' '부산' '인천' '대구' '대전' '울산' '광주' '세종' '제주' '경기' '강원' '충북' '충남' '전북'
#  '전남' '경북' '경남']
# ...

# %% [markdown]
# ### 시군구 코드 정보

# %%
#서울
Seoul_ID = {"서울 강남구":"1168000000", "서울 강동구":"1174000000", "서울 강북구":"1130500000", "서울 강서구":"1150000000",
            "서울 관악구":"1162000000", "서울 광진구":"1121500000", "서울 구로구":"1153000000", "서울 금천구":"1154500000",
            "서울 노원구":"1135000000", "서울 도봉구":"1132000000", "서울 동대문구":"1123000000", "서울 동작구":"1159000000",
            "서울 마포구":"1144000000", "서울 서대문구":"1141000000", "서울 서초구":"1165000000", "서울 성동구":"1120000000",
            "서울 성북구":"1129000000", "서울 송파구":"1171000000", "서울 양천구":"1147000000", "서울 영등포구":"1156000000", 
            "서울 용산구":"1117000000", "서울 은평구":"1138000000", "서울 종로구":"1111000000", "서울 중구":"1114000000",
            "서울 중랑구":"1126000000"}
#부산
BuSan_ID = {"부산 강서구":"2644000000", "부산 금정구":"2641000000", "부산 기장군":"2671000000",
            "부산 남구":"2629000000", "부산 동구":"2617000000", "부산 동래구":"2626000000",
            "부산 부산진구":"2623000000", "부산 북구":"2632000000", "부산 사상구":"2653000000",
            "부산 사하구":"2638000000", "부산 서구":"2614000000", "부산 수영구":"2650000000",
            "부산 연제구":"2647000000", "부산 영도구":"2620000000", "부산 중구":"2611000000",
            "부산 해운대구":"2635000000"}
#인천
InCheon_ID = {"인천 강화군":"2871000000","인천 계양구":"2824500000", "인천 남구":"2817000000",
              "인천 남동구":"2820000000", "인천 동구":"2814000000", "인천 부평구":"2823700000",
              "인천 서구":"2826000000", "인천 연수구":"2818500000", "인천 옹진구":"2872000000",
              "인천 중구":"2811000000"}
#대구
DaeGu_ID = {"대구 서구":"2717000000", "대구 수성구":"2726000000", "대구 중구":"2711000000",
            "대구 남구":"2720000000", "대구 달서구":"2729000000", "대구 동구":"2714000000",
            "대구 북구":"2723000000", "대구 달성군":"2771000000"}        
#대전
DaeJeon_ID = {"대전 대덕구":"3023000000", "대전 동구":"3011000000", "대전 서구":"3017000000",
              "대전 유성구":"3020000000", "대전 중구":"3014000000"}
#울산
UlSan_ID = {"울산 남구":"3114000000", "울산 동구":"3117000000", "울산 북구":"3020000000",
            "울산 울주군":"3171000000", "울산 중구":"3111000000"}
#광주
GuangJu_ID = {"광구 광산구":"2920000000", "광주 남구":"2915500000", "광주 동구":"2911000000", 
              "광주 북구":"2917000000", "광주 서구":"2914000000"}
#세종시
SeJong = {"세종 세종시":"3611031000"}

#제주도
JeJu = {"제주 서귀포시":"5013000000", "제주 제주시":"5011000000"}

#경기
GyeongGi_ID = {"경기 가평군":"4182000000", "경기 고양시":"4128100000", "경기 과천시":"4129000000", "경기 광명시":"4121000000",
               "경기 광주시":"4161000000", "경기 구리시":"4131000000", "경기 군포시":"4141000000", "경기 김포시":"4157000000",
               "경기 남양주시":"4136000000", "경기 동두천시":"4125000000", "경기 부천시":"4119500000", "경기 성남시":"4113100000",
               "경기 수원시":"4111100000", "경기 시흥시":"4139000000", "경기 안산시":"4127100000", "경기 안성시":"4155000000",
               "경기 안양시":"4117100000", "경기 양주시":"4163000000", "경기 양평군":"4183000000", "경기 여주시":"4167000000",
               "경기 연천군":"4180000000", "경기 오산시":"4137000000", "경기 용인시":"4146100000", "경기 의왕시":"4143000000",
               "경기 의정부시":"4115000000", "경기 이천시":"4150000000", "경기 파주시":"4148000000","경기 평택시":"4122000000",
               "경기 포천시":"4165000000", "경기 하남시":"4145000000", "경기 화성시":"4159000000"}

#강원
GangWon_ID = {"강원 강릉시":"4215000000", "강원 고성군":"4282000000", "강원 동해시":"4217000000", "강원 삼척시":"4223000000",
              "강원 속초시":"4221000000", "강원 양구군":"4280000000", "강원 양양군":"4283000000", "강원 영월군":"4275000000",
              "강원 원주시":"4213000000", "강원 인제군":"4281000000", "강원 정선군":"4277000000", "강원 철원군":"4278000000",
              "강원 춘천시":"4211000000", "강원 태백시":"4219000000", "강원 평창군":"4276000000", "강원 홍천군":"4272000000",
              "강원 화천군":"4279000000", "강원 횡성군":"4274000000"}

#충북
ChungBuk_ID = {"충북 괴산군":"4376000000", "충북 단양군":"4380000000", "충북 보은군":"4372000000", "충북 영동군":"4374000000",
               "충북 옥천군":"4373000000", "충북 음성군":"4377000000", "충북 제천시":"4315000000", "충북 증평군":"4374500000",
               "충북 진천군":"4375000000", "충북 청주시":"4311100000", "충북 충주시":"4313000000", "충북 청원군":"4311400000"}

#충남
ChungNam_ID = {"충남 계룡시":"4425000000", "충남 공주시":"4415000000", "충남 금산군":"4471000000", "충남 논산시":"4423000000",
               "충남 당진시":"4427000000", "충남 보령시":"4418000000", "충남 부여군":"4476000000", "충남 서산시":"4421000000",
               "충남 서천군":"4477000000", "충남 아산시":"4420000000", "충남 예산군":"4481000000", "충남 천안시":"4413100000",
               "충남 청양군":"4479000000", "충남 태안군":"4482500000", "충남 홍성군":"4480000000"}

#전북
JeonBuk_ID = {"전북 고창군":"4579000000", "전북 군산시":"4513000000", "전북 김제시":"4521000000", "전북 남원시":"4519000000",
              "전북 무주군":"4573000000", "전북 부안군":"4580000000", "전북 순창군":"4577000000", "전북 완주군":"4571000000",
              "전북 익산시":"4514000000", "전북 임실군":"4575000000", "전북 장수군":"4574000000", "전북 전주시":"4511100000",
              "전북 정읍시":"4518000000", "전북 진안군":"4572000000"}

#전남
JeonNam_ID = {"전남 강진군":"4681000000", "전남 고흥군":"4677000000", "전남 곡성군":"4672000000", "전남 광양시":"4623000000",
              "전남 구례군":"4673000000", "전남 나주시":"4617000000", "전남 담양군":"4671000000", "전남 목포시":"4611000000",
              "전남 무안군":"4684000000", "전남 보성군":"4678000000", "전남 순천시":"4615000000", "전남 신안군":"4691000000",
              "전남 여수시":"4613000000", "전남 영광군":"4687000000", "전남 영암군":"4683000000", "전남 완도군":"4689000000",
              "전남 장성군":"4688000000", "전남 장흥군":"4680000000", "전남 진도군":"4690000000", "전남 함평군":"4686000000",
              "전남 해남군":"4682000000", "전남 화순군":"4679000000"}

#경북
GyeongBuk_ID = {"경북 경산시":"4729000000", "경북 경주시":"4713000000", "경북 고령군":"4783000000", "경국 구미시":"4719000000",
                "경북 군위군":"4772000000", "경북 김천시":"4715000000", "경북 문경시":"4728000000", "경북 봉화군":"4792000000",
                "경북 상주시":"4725000000", "경북 성주군":"4784000000", "경북 안동시":"4717000000", "경북 영덕군":"4777000000",
                "경북 영양군":"4776000000", "경북 영주시":"4721000000", "경북 영천시":"4723000000", "경북 예천군":"4790000000",
                "경북 울릉군":"4794000000", "경북 울진군":"4793000000", "경북 의성군":"4773000000", "경북 청도군":"4782000000",
                "경북 청송군":"4775000000", "경북 칠곡군":"4785000000", "경북 포항시":"4711100000"}

#경남
GyeongNam_ID = {"경남 거제시":"4831000000", "경남 거창군":"4888000000", "경남 고성군":"4882000000", "경남 김해시":"4825000000",
                "경남 남해군":"4884000000", "경남 밀양시":"4827000000", "경남 사천시":"4824000000", "경남 산청군":"4886000000",
                "경남 양산시":"4833000000", "경남 의령군":"4872000000", "경남 진주시":"4817000000", "경남 창녕군":"4874000000",
                "경남 창원시":"4812100000", "경남 통영시":"4822000000", "경남 하동군":"4885000000", "경남 함안군":"4873000000",
                "경남 함양군":"4887000000", "경남 합천군":"4889000000"}

# CT_AREA_ID = "5013000000"

# %%
# #경기
# GyeongGi_ID = {"경기 가평군":"4182000000", "경기 고양시":"4128100000", "경기 과천시":"4129000000", "경기 광명시":"4121000000",
#                "경기 광주시":"4161000000", "경기 구리시":"4131000000", "경기 군포시":"4141000000", "경기 김포시":"4157000000",
#                "경기 남양주시":"4136000000", "경기 동두천시":"4125000000", "경기 부천시":"4119500000", "경기 성남시":"4113100000",
#                "경기 수원시":"4111100000", "경기 시흥시":"4139000000", "경기 안산시":"4127100000", "경기 안성시":"4155000000",
#                "경기 안양시":"4117100000", "경기 양주시":"4163000000", "경기 양평군":"4183000000", "경기 여주시":"4167000000",
#                "경기 연천군":"4180000000", "경기 오산시":"4137000000", "경기 용인시":"4146100000", "경기 의왕시":"4143000000",
#                "경기 의정부시":"4115000000", "경기 이천시":"4150000000", "경기 파주시":"4148000000","경기 평택시":"4122000000",
#                "경기 포천시":"4165000000", "경기 하남시":"4145000000", "경기 화성시":"4159000000"}

# %%
# #강원
# GangWon_ID = {"강원 강릉시":"4215000000", "강원 고성군":"4282000000", "강원 동해시":"4217000000", "강원 삼척시":"4223000000",
#               "강원 속초시":"4221000000", "강원 양구군":"4280000000", "강원 양양군":"4283000000", "강원 영월군":"4275000000",
#               "강원 원주시":"4213000000", "강원 인제군":"4281000000", "강원 정선군":"4277000000", "강원 철원군":"4278000000",
#               "강원 춘천시":"4211000000", "강원 태백시":"4219000000", "강원 평창군":"4276000000", "강원 홍천군":"4272000000",
#               "강원 화천군":"4279000000", "강원 횡성군":"4274000000"}

# %%
# #충북
# ChungBuk_ID = {"충북 괴산군":"4376000000", "충북 단양군":"4380000000", "충북 보은군":"4372000000", "충북 영동군":"4374000000",
#                "충북 옥천군":"4373000000", "충북 음성군":"4377000000", "충북 제천시":"4315000000", "충북 증평군":"4374500000",
#                "충북 진천군":"4375000000", "충북 청주시":"4311100000", "충북 충주시":"4313000000", "충북 청원군":"4311400000"}
# #충남
# ChungNam_ID = {"충남 계룡시":"4425000000", "충남 공주시":"4415000000", "충남 금산군":"4471000000", "충남 논산시":"4423000000",
#                "충남 당진시":"4427000000", "충남 보령시":"4418000000", "충남 부여군":"4476000000", "충남 서산시":"4421000000",
#                "충남 서천군":"4477000000", "충남 아산시":"4420000000", "충남 예산군":"4481000000", "충남 천안시":"4413100000",
#                "충남 청양군":"4479000000", "충남 태안군":"4482500000", "충남 홍성군":"4480000000"}

# %%
# #전북
# JeonBuk_ID = {"전북 고창군":"4579000000", "전북 군산시":"4513000000", "전북 김제시":"4521000000", "전북 남원시":"4519000000",
#               "전북 무주군":"4573000000", "전북 부안군":"4580000000", "전북 순창군":"4577000000", "전북 완주군":"4571000000",
#               "전북 익산시":"4514000000", "전북 임실군":"4575000000", "전북 장수군":"4574000000", "전북 전주시":"4511100000",
#               "전북 정읍시":"4518000000", "전북 진안군":"4572000000"}
# #전남
# JeonNam_ID = {"전남 강진군":"4681000000", "전남 고흥군":"4677000000", "전남 곡성군":"4672000000", "전남 광양시":"4623000000",
#               "전남 구례군":"4673000000", "전남 나주시":"4617000000", "전남 담양군":"4671000000", "전남 목포시":"4611000000",
#               "전남 무안군":"4684000000", "전남 보성군":"4678000000", "전남 순천시":"4615000000", "전남 신안군":"4691000000",
#               "전남 여수시":"4613000000", "전남 영광군":"4687000000", "전남 영암군":"4683000000", "전남 완도군":"4689000000",
#               "전남 장성군":"4688000000", "전남 장흥군":"4680000000", "전남 진도군":"4690000000", "전남 함평군":"4686000000",
#               "전남 해남군":"4682000000", "전남 화순군":"4679000000"}

# %%
# #경북
# GyeongBuk_ID = {"경북 경산시":"4729000000", "경북 경주시":"4713000000", "경북 고령군":"4783000000", "경국 구미시":"4719000000",
#                 "경북 군위군":"4772000000", "경북 김천시":"4715000000", "경북 문경시":"4728000000", "경북 봉화군":"4792000000",
#                 "경북 상주시":"4725000000", "경북 성주군":"4784000000", "경북 안동시":"4717000000", "경북 영덕군":"4777000000",
#                 "경북 영양군":"4776000000", "경북 영주시":"4721000000", "경북 영천시":"4723000000", "경북 예천군":"4790000000",
#                 "경북 울릉군":"4794000000", "경북 울진군":"4793000000", "경북 의성군":"4773000000", "경북 청도군":"4782000000",
#                 "경북 청송군":"4775000000", "경북 칠곡군":"4785000000", "경북 포항시":"4711100000"}
# #경남
# GyeongNam_ID = {"경남 거제시":"4831000000", "경남 거창군":"4888000000", "경남 고성군":"4882000000", "경남 김해시":"4825000000",
#                 "경남 남해군":"4884000000", "경남 밀양시":"4827000000", "경남 사천시":"4824000000", "경남 산청군":"4886000000",
#                 "경남 양산시":"4833000000", "경남 의령군":"4872000000", "경남 진주시":"4817000000", "경남 창녕군":"4874000000",
#                 "경남 창원시":"4812100000", "경남 통영시":"4822000000", "경남 하동군":"4885000000", "경남 함안군":"4873000000",
#                 "경남 함양군":"4887000000", "경남 합천군":"4889000000"}

# # CT_AREA_ID = "5013000000"

# %% [markdown]
# ## 시군구별 코드가 하나밖에 없는 경우

# %% [markdown]
# ### json

# %%
# area = SeJong

# url = f"http://apis.data.go.kr/1360000/{SERVICE}/{STYPE[0]}?serviceKey={KEY}&pageNo={PG_NO}&numOfRows={NoRows}&dataType={Dtype[1]}&CURRENT_DATE={CDate}&DAY={DAYs}&CITY_AREA_ID={area}"
# resp = requests.get(url)
# origin = resp.json()

# if origin['response']['body']['totalCount']!="0":
#   NoRows = origin['response']['body']['totalCount']
#   url = f"http://apis.data.go.kr/1360000/{SERVICE}/{STYPE[0]}?serviceKey={KEY}&pageNo={PG_NO}&numOfRows={NoRows}&dataType={Dtype[1]}&CURRENT_DATE={CDate}&DAY={DAYs}&CITY_AREA_ID={area}"
#   resp = requests.get(url)
#   origin = resp.json()
#   WSGG_df = pd.json_normalize(origin['response']['body']['items']['item'])

# %% [markdown]
# ### xml

# %%
# area = Sejong

# url = f"http://apis.data.go.kr/1360000/{SERVICE}/{STYPE[0]}?serviceKey={KEY}&pageNo={PG_NO}&numOfRows={NoRows}&dataType={Dtype[1]}&CURRENT_DATE={CDate}&DAY={DAYs}&CITY_AREA_ID={area}"
# req = urllib.request.Request(url)
# xml_parse = xmltodict.parse(urlopen(req).read().decode("UTF-8")) #xml to json dict
# origin = json.loads(json.dumps(xml_parse))

# if origin['response']['body']['totalCount']!="0":
#   NoRows = origin['response']['body']['totalCount']
#   url = f"http://apis.data.go.kr/1360000/{SERVICE}/{STYPE[0]}?serviceKey={KEY}&pageNo={PG_NO}&numOfRows={NoRows}&dataType={Dtype[1]}&CURRENT_DATE={CDate}&DAY={DAYs}&CITY_AREA_ID={area}"
#   req = urllib.request.Request(url)
#   xml_parse = xmltodict.parse(urlopen(req).read().decode("UTF-8")) #xml to json dict
#   origin = json.loads(json.dumps(xml_parse))
#   WSGG_df = pd.json_normalize(origin['response']['body']['items']['item'])

# %% [markdown]
# ## 시군구별 코드가 하나 이상인 경우

# %% [markdown]
# ### xml

# %%
# WSGG_df = pd.DataFrame()
# NoData = []

# for name, area in GyeongGi_ID.items():
#   try:
#     url = f"http://apis.data.go.kr/1360000/{SERVICE}/{STYPE[0]}?serviceKey={KEY}&pageNo={PG_NO}&numOfRows={NoRows}&dataType={Dtype[0]}&CURRENT_DATE={CDate}&DAY={DAYs}&CITY_AREA_ID={area}"
#     req = urllib.request.Request(url)
#     xml_parse = xmltodict.parse(urlopen(req).read().decode("UTF-8")) #xml to json dict
#     origin = json.loads(json.dumps(xml_parse))

#     if origin['response']['body']['totalCount']=="0":
#       print(f"They don't have Data at {name}")
#       NoData.append(name)

#     else:
#       NoRows = origin['response']['body']['totalCount']
#       url = f"http://apis.data.go.kr/1360000/{SERVICE}/{STYPE[0]}?serviceKey={KEY}&pageNo={PG_NO}&numOfRows={NoRows}&dataType={Dtype[0]}&CURRENT_DATE={CDate}&DAY={DAYs}&CITY_AREA_ID={area}"
#       req = urllib.request.Request(url)
#       xml_parse = xmltodict.parse(urlopen(req).read().decode("UTF-8")) #xml to json dict
#       origin = json.loads(json.dumps(xml_parse))
#       WSGG_df = pd.concat([WSGG_df, pd.json_normalize(origin['response']['body']['items']['item'])])

#   except:
#     pass
# Out:
# They don't have Data at 경기 의왕시

# %%
WSGG_df
# Out:
#                    tm totalCityName doName  ...  cityAreaId kmaTci  TCI_GRADE
# 0    2018-12-31 00:00        서울 강남구     서울  ...  1168000000  47.12         보통
# 1    2018-12-30 00:00        서울 강남구     서울  ...  1168000000  41.46         보통
# 2    2018-12-29 00:00        서울 강남구     서울  ...  1168000000  31.10         나쁨
# 3    2018-12-28 00:00        서울 강남구     서울  ...  1168000000  31.10         나쁨
# 4    2018-12-27 00:00        서울 강남구     서울  ...  1168000000  31.10         나쁨
# ..                ...           ...    ...  ...         ...    ...        ...
# 360  2018-01-05 00:00        세종 세종시     세종  ...  3611031000  48.73         보통
# 361  2018-01-04 00:00        세종 세종시     세종  ...  3611031000  35.52         나쁨
# 362  2018-01-03 00:00        세종 세종시     세종  ...  3611031000  43.03         보통
# 363  2018-01-02 00:00        세종 세종시     세종  ...  3611031000  53.14         보통
# 364  2018-01-01 00:00        세종 세종시     세종  ...  3611031000  55.69         보통
#
# [27372 rows x 7 columns]

# %% [markdown]
# ### json

# %%
# WSGG_df = pd.DataFrame()
# NoData = []

# for name, area in JeJu.items():
#   try:
#     url = f"http://apis.data.go.kr/1360000/{SERVICE}/{STYPE[0]}?serviceKey={KEY}&pageNo={PG_NO}&numOfRows={NoRows}&dataType={Dtype[1]}&CURRENT_DATE={CDate}&DAY={DAYs}&CITY_AREA_ID={area}"
#     resp = requests.get(url)
#     origin = resp.json()

#     if origin['response']['body']['totalCount']=="0":
#       print(f"They don't have Data at {name}")
#       NoData.append(name)

#     else:
#       NoRows = origin['response']['body']['totalCount']
#       url = f"http://apis.data.go.kr/1360000/{SERVICE}/{STYPE[0]}?serviceKey={KEY}&pageNo={PG_NO}&numOfRows={NoRows}&dataType={Dtype[1]}&CURRENT_DATE={CDate}&DAY={DAYs}&CITY_AREA_ID={area}"
#       resp = requests.get(url)
#       origin = resp.json()
#       WSGG_df = pd.concat([WSGG_df, pd.json_normalize(origin['response']['body']['items']['item'])])

#   except:
#     pass

# %% [markdown]
# ## 한번에 불러오기

# %%
ID = [Seoul_ID, BuSan_ID, InCheon_ID, DaeGu_ID, DaeJeon_ID, UlSan_ID, GuangJu_ID, 
      SeJong, JeJu, GyeongGi_ID, GangWon_ID, ChungBuk_ID, ChungNam_ID, JeonBuk_ID, 
      JeonNam_ID, GyeongBuk_ID, GyeongNam_ID]

WSGG_df = pd.DataFrame()
NoData = []

# %%
for id in ID:
  for name, area in id.items():
    try:
      url = f"http://apis.data.go.kr/1360000/{SERVICE}/{STYPE[0]}?serviceKey={KEY}&pageNo={PG_NO}&numOfRows={NoRows}&dataType={Dtype[1]}&CURRENT_DATE={CDate}&DAY={DAYs}&CITY_AREA_ID={area}"
      resp = requests.get(url)
      origin = resp.json()

      if origin['response']['body']['totalCount']=="0":
        print(f"They don't have Data at {name}")
        NoData.append(name)

      else:
        NoRows = origin['response']['body']['totalCount']
        url = f"http://apis.data.go.kr/1360000/{SERVICE}/{STYPE[0]}?serviceKey={KEY}&pageNo={PG_NO}&numOfRows={NoRows}&dataType={Dtype[1]}&CURRENT_DATE={CDate}&DAY={DAYs}&CITY_AREA_ID={area}"
        resp = requests.get(url)
        origin = resp.json()
        WSGG_df = pd.concat([WSGG_df, pd.json_normalize(origin['response']['body']['items']['item'])])

    except:
      pass

# %%
WSGG_df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# 2011데이터 없음

# %% [markdown]
# ## 데이터 확인 후 더하기

# %%
ocol = [col for col in WSGG_df.columns]

# %%
ocol
# Out:
# []

# %%
kcol = ['예보시각', "전체 도시 이름", "시도", "시군구", "시군구코드", "관광기후지수", "관광기후지수등급"]

# %%
ncol = {}

for o, k in zip(ocol, kcol):
  ncol[o]=k

ncol
# Out:
# {}

# %%
WSGG_df.rename(columns=ncol, inplace=True)
WSGG_df
# Out:
#                  예보시각 전체 도시 이름  시도  시군구       시군구코드  관광기후지수 관광기후지수등급
# 0    2020-12-31 00:00   서울 강남구  서울  강남구  1168000000   -0.81       나쁨
# 1    2020-12-30 00:00   서울 강남구  서울  강남구  1168000000   -0.62       나쁨
# 2    2020-12-29 00:00   서울 강남구  서울  강남구  1168000000   -0.79       나쁨
# 3    2020-12-28 00:00   서울 강남구  서울  강남구  1168000000   -0.22       보통
# 4    2020-12-27 00:00   서울 강남구  서울  강남구  1168000000   -0.45       나쁨
# ..                ...      ...  ..  ...         ...     ...      ...
# 356  2020-01-05 00:00   경남 합천군  경남  합천군  4889000000   -0.05       보통
# 357  2020-01-04 00:00   경남 합천군  경남  합천군  4889000000   -0.05       보통
# 358  2020-01-03 00:00   경남 합천군  경남  합천군  4889000000    0.03       보통
# 359  2020-01-02 00:00   경남 합천군  경남  합천군  4889000000   -0.01       보통
# 360  2020-01-01 00:00   경남 합천군  경남  합천군  4889000000   -0.14       나쁨
#
# [82669 rows x 7 columns]

# %%
NoData
# Out:
# []

# %%
# !ls
# Out:
#  기상청_관광코스별_관광지_상세날씨
#  기상청27_관광코스별_관광지_상세_날씨_조회서비스_오픈API활용가이드.docx
# '31. 한국도로공사+OpenAPI+활용가이드(실시간 소통 데이터).docx'
#  기상청_일별_지상_종관_ASOS
#  AsosDalyInfoService_api.ipynb
#  DataLabService_api.ipynb
#  locgoRegnVisitrDDList
#  metcoRegnVisitrDDList
#  openapi_baseline.ipynb
# 'TourAPI_Guide_(DataLab)v1.0_20210527'
#  TourStnInfoService_api.ipynb
# '한국문화관광연구원 관광실태조사서비스 활용가이드_v1.1.docx'
# '한국문화관광연구원 관광자원통계서비스 활용가이드_v1.1.docx'
# '한국문화관광연구원 관광산업통계서비스 활용가이드_v1.2.docx'

# %%
# data = pd.read_csv(f'{SV}/시군구별관광기후지수_2021.csv')
# # data.rename(columns=ncol, inplace=True)
# data
# Out:
#                    예보시각 전체 도시 이름  시도  시군구      관광기후지수  관광기후지수등급 TCI_GRADE
# 0      2020-12-31 00:00   서울 강남구  서울  강남구  1168000000     -0.81        나쁨
# 1      2020-12-30 00:00   서울 강남구  서울  강남구  1168000000     -0.62        나쁨
# 2      2020-12-29 00:00   서울 강남구  서울  강남구  1168000000     -0.79        나쁨
# 3      2020-12-28 00:00   서울 강남구  서울  강남구  1168000000     -0.22        보통
# 4      2020-12-27 00:00   서울 강남구  서울  강남구  1168000000     -0.45        나쁨
# ...                 ...      ...  ..  ...         ...       ...       ...
# 67863  2020-01-05 00:00   전남 화순군  전남  화순군  4679000000     -0.05        보통
# 67864  2020-01-04 00:00   전남 화순군  전남  화순군  4679000000     -0.28        나쁨
# 67865  2020-01-03 00:00   전남 화순군  전남  화순군  4679000000     -0.28        나쁨
# 67866  2020-01-02 00:00   전남 화순군  전남  화순군  4679000000     -0.39        나쁨
# 67867  2020-01-01 00:00   전남 화순군  전남  화순군  4679000000     -0.54        나쁨
#
# [67868 rows x 7 columns]

# %%
# WSGG_df = pd.concat([data, WSGG_df]).reset_index(drop=True)

# %%
WSGG_df.reset_index(drop=True, inplace=True)

# %%
# 조회 년도 조회 월에 따라 csv파일 드라이브에 저장
duration = CDate[:4]#+'_'+now.strftime('%Y%m%d')
WSGG_df.to_csv(f'{SV}/시군구별관광기후지수_{duration}.csv', index=False)

# %% [markdown]
# # 기상청_관광코스별 관광지 상세 날씨 조회서비스(기상지수예보조회)__데이터 수집 일단 보류

# %% [markdown]
# 일자별, 시간을 12, 24, 48 등으로 조절하며 달라지는 값과 중복되는 값이 존재해서 어떻게 활용해야 할 지 의문...일단 보류

# %%
SERVICE = "TourStnInfoService"
STYPE = ["getCityTourClmIdx", "getTourStnWthrIdx", "getTourStnVilageFcst"]
# KEY = ""  #서비스키
KEY = "yRxjHtUyF3aadfyII7o4rlbGO0QK4kY2Uf46AoDzfvoCgVT6wHHceyMx%2Be1DZvcYHLAl4h2ANO02EFyWxkd%2FHA%3D%3D" #서비스키
PG_NO = "1"
NoRows = "10"
Dtype = ["XML", "JSON"]

# %%
from datetime import datetime, timedelta
now=datetime.now()
check = datetime(2021,1,1,hour=0, minute=0, second=0, microsecond=0)
HRs = "24"

# %% [markdown]
# ## xml

# %%
WSGG_df = pd.DataFrame()
NoData = []

for cs in range(1, 439):
  for dys in range((now-check).days+1):
    try:
      CDate = (check+timedelta(days=dys)).strftime('%Y%m%d%H')
      url = f"http://apis.data.go.kr/1360000/{SERVICE}/{STYPE[1]}?serviceKey={KEY}&pageNo={PG_NO}&numOfRows={NoRows}&dataType={Dtype[0]}&CURRENT_DATE={CDate}&HOUR={HRs}&COURSE_ID={cs}"
      req = urllib.request.Request(url)
      xml_parse = xmltodict.parse(urlopen(req).read().decode("UTF-8"))
      origin = json.loads(json.dumps(xml_parse))
      if origin['response']['body']['totalCount']=="0":
        print(f"They don't have Data on {CDate}, {cs}")
        NoData.append(date)
      elif origin['response']['body']['totalCount']!="0":
        NoRows = origin['response']['body']['totalCount']
        url = f"http://apis.data.go.kr/1360000/{SERVICE}/{STYPE[1]}?serviceKey={KEY}&pageNo={PG_NO}&numOfRows={NoRows}&dataType={Dtype[0]}&CURRENT_DATE={CDate}&HOUR={HRs}&COURSE_ID={cs}"
        req = urllib.request.Request(url)
        xml_parse = xmltodict.parse(urlopen(req).read().decode("UTF-8")) #xml to json dict
        origin = json.loads(json.dumps(xml_parse))
        WSGG_df = pd.concat([WSGG_df, pd.json_normalize(origin['response']['body']['items']['item'])])
    except:
      pass

# %% [markdown]
# ## json

# %%
WSGG_df = pd.DataFrame()
NoData = []

for cs in range(1, 439):
  for dys in range((now-check).days+1):
    try:
      CDate = (check+timedelta(days=dys)).strftime('%Y%m%d%H')
      url = f"http://apis.data.go.kr/1360000/{SERVICE}/{STYPE[1]}?serviceKey={KEY}&pageNo={PG_NO}&numOfRows={NoRows}&dataType={Dtype[0]}&CURRENT_DATE={CDate}&HOUR={HRs}&COURSE_ID={cs}"
      resp = requests.get(url)
      origin = resp.json()

      if origin['response']['body']['totalCount']=="0":
        print(f"They don't have Data on {CDate}, {cs}")
        NoData.append(date)
      elif origin['response']['body']['totalCount']!="0":
        NoRows = origin['response']['body']['totalCount']
        url = f"http://apis.data.go.kr/1360000/{SERVICE}/{STYPE[1]}?serviceKey={KEY}&pageNo={PG_NO}&numOfRows={NoRows}&dataType={Dtype[0]}&CURRENT_DATE={CDate}&HOUR={HRs}&COURSE_ID={cs}"
        resp = requests.get(url)
        origin = resp.json()
        WSGG_df = pd.concat([WSGG_df, pd.json_normalize(origin['response']['body']['items']['item'])])
    except:
      pass

# %% [markdown]
# # 기상청_관광코스별 관광지 상세 날씨 조회서비스(동네예보조회)__데이터 수집 일단 보류

# %% [markdown]
# 상기와 비슷한 이유로 일단 데이터 수집 보류

# %%
SERVICE = "TourStnInfoService"
STYPE = ["getCityTourClmIdx", "getTourStnWthrIdx", "getTourStnVilageFcst"]
# KEY = ""  #서비스키
KEY = "yRxjHtUyF3aadfyII7o4rlbGO0QK4kY2Uf46AoDzfvoCgVT6wHHceyMx%2Be1DZvcYHLAl4h2ANO02EFyWxkd%2FHA%3D%3D" #서비스키
PG_NO = "1"
NoRows = "10"
Dtype = ["XML", "JSON"]

# %%
from datetime import datetime, timedelta
now=datetime.now()
check = datetime(2021,1,1,hour=0, minute=0, second=0, microsecond=0)
HRs = "24"
# CDate = check.strftime('%Y%m%d%H')
# HRs = ["12", "24", "48", "68"]

# %% [markdown]
# ## xml

# %%
WSGG_df = pd.DataFrame()
NoData = []

for cs in range(1, 439):
  for dys in range((now-check).days+1):
    try:
      CDate = (check+timedelta(days=dys)).strftime('%Y%m%d%H')
      url = f"http://apis.data.go.kr/1360000/{SERVICE}/{STYPE[2]}?serviceKey={KEY}&pageNo={PG_NO}&numOfRows={NoRows}&dataType={Dtype[0]}&CURRENT_DATE={CDate}&HOUR={HRs}&COURSE_ID={cs}"
      req = urllib.request.Request(url)
      xml_parse = xmltodict.parse(urlopen(req).read().decode("UTF-8"))
      origin = json.loads(json.dumps(xml_parse))
      if origin['response']['body']['totalCount']=="0":
        print(f"They don't have Data on {CDate}, {cs}")
        NoData.append(date)
      elif origin['response']['body']['totalCount']!="0":
        NoRows = origin['response']['body']['totalCount']
        url = f"http://apis.data.go.kr/1360000/{SERVICE}/{STYPE[2]}?serviceKey={KEY}&pageNo={PG_NO}&numOfRows={NoRows}&dataType={Dtype[0]}&CURRENT_DATE={CDate}&HOUR={HRs}&COURSE_ID={cs}"
        req = urllib.request.Request(url)
        xml_parse = xmltodict.parse(urlopen(req).read().decode("UTF-8")) #xml to json dict
        origin = json.loads(json.dumps(xml_parse))
        WSGG_df = pd.concat([WSGG_df, pd.json_normalize(origin['response']['body']['items']['item'])])
    except:
      pass

# %% [markdown]
# ## json

# %%
WSGG_df = pd.DataFrame()
NoData = []

for cs in range(1, 439):
  for dys in range((now-check).days+1):
    try:
      CDate = (check+timedelta(days=dys)).strftime('%Y%m%d%H')
      url = f"http://apis.data.go.kr/1360000/{SERVICE}/{STYPE[2]}?serviceKey={KEY}&pageNo={PG_NO}&numOfRows={NoRows}&dataType={Dtype[0]}&CURRENT_DATE={CDate}&HOUR={HRs}&COURSE_ID={cs}"
      resp = requests.get(url)
      origin = resp.json()

      if origin['response']['body']['totalCount']=="0":
        print(f"They don't have Data on {CDate}, {cs}")
        NoData.append(date)
      elif origin['response']['body']['totalCount']!="0":
        NoRows = origin['response']['body']['totalCount']
        url = f"http://apis.data.go.kr/1360000/{SERVICE}/{STYPE[2]}?serviceKey={KEY}&pageNo={PG_NO}&numOfRows={NoRows}&dataType={Dtype[0]}&CURRENT_DATE={CDate}&HOUR={HRs}&COURSE_ID={cs}"
        resp = requests.get(url)
        origin = resp.json()
        WSGG_df = pd.concat([WSGG_df, pd.json_normalize(origin['response']['body']['items']['item'])])
    except:
      pass

# %% [markdown]
# # copy files__카피한 뒤 사용하는 경우

# %%
# %cd "{DATA_PATH}"
# !ls
# Out:
# /content/drive/.shortcut-targets-by-id/1TVtWvZ4DNn7V20Aj6JzSd5_iRdbjEXbG/Proj_WT/DataSets
#  기상청_관광코스별_관광지_상세날씨
#  기상청27_관광코스별_관광지_상세_날씨_조회서비스_오픈API활용가이드.docx
# '31. 한국도로공사+OpenAPI+활용가이드(실시간 소통 데이터).docx'
#  AsosDalyInfoService_api.ipynb
#  DataLabService_api.ipynb
#  locgoRegnVisitrDDList
#  metcoRegnVisitrDDList
#  openapi_baseline.ipynb
# 'TourAPI_Guide_(DataLab)v1.0_20210527'
#  TourStnInfoService_api.ipynb
# '한국문화관광연구원 관광실태조사서비스 활용가이드_v1.1.docx'
# '한국문화관광연구원 관광자원통계서비스 활용가이드_v1.1.docx'
# '한국문화관광연구원 관광산업통계서비스 활용가이드_v1.2.docx'

# %%
api = "_api.ipynb"
origin = "TourStnInfoService"+api
copy = "AsosDalyInfoService"+api

# !cp "{origin}" "{copy}"
